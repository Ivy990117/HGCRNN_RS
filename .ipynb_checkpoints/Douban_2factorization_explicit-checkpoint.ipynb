# %%
import os,sys,inspect
import os
import joblib
import tensorflow.compat.v1 as tf
import numpy as np
import h5py
import scipy.sparse.linalg as la
import scipy.sparse as sp
import scipy
import time
import os
import matplotlib.pyplot as plt
from sklearn.neighbors import kneighbors_graph

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
# %matplotlib inline

# %%
#for simplicity I start with the first split
#Douban
path_dataset = '/Users/liujiaoyang/tensorflow/HGCRNN_01867787/Data/Douban/Douban.mat'

# %%
# auxiliary functions:

# import matlab files in python
def load_matlab_file(path_file, name_field):
    """
    load '.mat' files
    inputs:
        path_file, string containing the file path
        name_field, string containig the field name (default='shape')
    warning:
        '.mat' files should be saved in the '-v7.3' format
    """
    db = h5py.File(path_file, 'r')
    ds = db[name_field]
    try:
        if 'ir' in ds.keys():
            data = np.asarray(ds['data'])
            ir   = np.asarray(ds['ir'])
            jc   = np.asarray(ds['jc'])
            out  = sp.csc_matrix((data, ir, jc)).astype(np.float32)
    except AttributeError:
        # Transpose in case is a dense matrix because of the row- vs column- major ordering between python and matlab
        out = np.asarray(ds).astype(np.float32).T

    db.close()

    return out

# %%
#loading of the required matrices
M = load_matlab_file(path_dataset, 'M')
Otraining = load_matlab_file(path_dataset, 'Otraining')
Otest = load_matlab_file(path_dataset, 'Otest')
Wrow = load_matlab_file(path_dataset, 'W_users') #sparse
Wcol = load_matlab_file(path_dataset, 'W_movies') #sparse


plt.figure(figsize=(20,10))
plt.imshow(M)
plt.title('Partially-Observed Matrix X (Douban)')
plt.colorbar()

plt.figure(figsize=(20,10))
plt.imshow(Otraining)
plt.title('Training Set (Douban)')
plt.colorbar()

plt.figure(figsize=(20,10))
plt.imshow(Otest)
plt.title('Test Set (Douban)')
plt.colorbar()

# %%
np.random.seed(0)
pos_tr_samples = np.where(Otraining)

num_tr_samples = len(pos_tr_samples[0])
list_idx = list(range(num_tr_samples))
np.random.shuffle(list_idx)
idx_data = list_idx[:num_tr_samples//2]
idx_train = list_idx[num_tr_samples//2:]

pos_data_samples = (pos_tr_samples[0][idx_data], pos_tr_samples[1][idx_data])
pos_tr_samples = (pos_tr_samples[0][idx_train], pos_tr_samples[1][idx_train])

Odata = np.zeros(M.shape)
Otraining = np.zeros(M.shape)

for k in range(len(pos_data_samples[0])):
    Odata[pos_data_samples[0][k], pos_data_samples[1][k]] = 1
    
for k in range(len(pos_tr_samples[0])):
    Otraining[pos_tr_samples[0][k], pos_tr_samples[1][k]] = 1
    
print ('Num data samples: %d' % (np.sum(Odata),))
print ('Num train samples: %d' % (np.sum(Otraining),))
print ('Num train+data samples: %d' % (np.sum(Odata+Otraining),))
# Out:
# Num data samples: 40000
# Num train samples: 40000
# Num train+data samples: 80000

# %%
#computation of the normalized laplacians
Lrow = sp.csgraph.laplacian(Wrow, normed=True)
Lcol = sp.csgraph.laplacian(Wcol, normed=True)

# %%
#apply SVD initially for detecting the main components of our initialization
U, s, V = np.linalg.svd(Odata*M, full_matrices=0)

print (U.shape)
print (s.shape)
print (V.shape)
# Out:
# (943, 943)
# (943,)
# (943, 1682)

# %%
rank_W_H = 10
partial_s = s[:rank_W_H]
partial_S_sqrt = np.diag(np.sqrt(partial_s))
initial_W = np.dot(U[:, :rank_W_H], partial_S_sqrt)
initial_H = np.dot(partial_S_sqrt, V[:rank_W_H, :]).T

print (initial_W.shape)
print (initial_H.shape)

plt.figure(figsize=(20,5))
plt.imshow(initial_W)
plt.title('Initial Factor U (Douban)')


plt.figure(figsize=(5,20))
plt.imshow(initial_H.T)
plt.title('Initial Factor I (Douban)')


plt.figure(figsize=(20,10))
plt.imshow(np.dot(initial_W, initial_H.T))
plt.title('Reconstructed low-rank training matrix (Douban)')
plt.colorbar()
# Out:
# (943, 10)
# (1682, 10)

# %%
print ('Original training matrix (MovieLens)')
plt.figure()
plt.imshow(Odata*M)
plt.colorbar()

print ('Reconstructed training matrix (MovieLens)')
plt.figure()
plt.imshow(np.dot(initial_W, initial_H.T))
plt.colorbar()
# Out:
# Original training matrix (MovieLens)
# Reconstructed training matrix (MovieLens)

# %%
class Train_test_matrix_completion:
    
    """
    The neural network model.
    """
    
    def frobenius_norm(self, tensor):
        square_tensor = tf.square(tensor)
        tensor_sum = tf.reduce_sum(square_tensor)
        frobenius_norm = tf.sqrt(tensor_sum)
        return frobenius_norm
    
    def mono_conv(self, list_lap, ord_conv, A, W, b):
        
        feat = []
        #collect features
        for k in range(ord_conv):
            c_lap = list_lap[k] 
                                                     
            #dense implementation
            c_feat = tf.matmul(c_lap, A, a_is_sparse=False)
            feat.append(c_feat)
            
        all_feat = tf.concat(feat, 1)
        conv_feat = tf.matmul(all_feat, W) + b
        conv_feat = tf.nn.relu(conv_feat)
        
        return conv_feat
               
    def compute_cheb_polynomials(self, L, ord_cheb, list_cheb):
        for k in range(ord_cheb):
            if (k==0):
                list_cheb.append(tf.cast(tf.diag(tf.ones([tf.shape(L)[0],])), 'float32'))
            elif (k==1):
                list_cheb.append(tf.cast(L, 'float32'))
            else:
                list_cheb.append(2*tf.matmul(L, list_cheb[k-1])  - list_cheb[k-2])
    
    def __init__(self, M, Lr, Lc, Odata, Otraining, Otest, initial_W, initial_H,
                 order_chebyshev_col = 5, order_chebyshev_row = 5,
                 num_iterations = 10, gamma=1.0, learning_rate=1e-4, idx_gpu = '/gpu:3'):
        
        #order of the spectral filters
        self.ord_col = order_chebyshev_col 
        self.ord_row = order_chebyshev_row
        self.num_iterations = num_iterations
        self.n_conv_feat = 32
        
        with tf.Graph().as_default() as g:
                tf.logging.set_verbosity(tf.logging.ERROR)
                self.graph = g
                tf.set_random_seed(0)
                with tf.device(idx_gpu):
                    
                        #loading of the laplacians
                        self.Lr = tf.constant(Lr.astype('float32'))
                        self.Lc = tf.constant(Lc.astype('float32'))
                        
                        self.norm_Lr = self.Lr - tf.diag(tf.ones([Lr.shape[0], ]))
                        self.norm_Lc = self.Lc - tf.diag(tf.ones([Lc.shape[0], ]))
                        
                        #compute all chebyshev polynomials a priori
                        self.list_row_cheb_pol = list()
                        self.compute_cheb_polynomials(self.norm_Lr, self.ord_row, self.list_row_cheb_pol)
                        self.list_col_cheb_pol = list()
                        self.compute_cheb_polynomials(self.norm_Lc, self.ord_col, self.list_col_cheb_pol)
                        
                        #definition of constant matrices
                        self.M = tf.constant(M, dtype=tf.float32)
                        self.Odata = tf.constant(Odata, dtype=tf.float32)
                        self.Otraining = tf.constant(Otraining, dtype=tf.float32) #training mask
                        self.Otest = tf.constant(Otest, dtype=tf.float32) #test mask
                         
                        ##################################definition of the NN variables#####################################
                        
                        #definition of the weights for extracting the global features
                        self.W_conv_W = tf.get_variable("W_conv_W", shape=[self.ord_col*initial_W.shape[1], self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.b_conv_W = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        self.W_conv_H = tf.get_variable("W_conv_H", shape=[self.ord_row*initial_W.shape[1], self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.b_conv_H = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        
                        #recurrent N parameters
                        self.W_f_u = tf.get_variable("W_f_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.W_i_u = tf.get_variable("W_i_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.W_o_u = tf.get_variable("W_o_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.W_c_u = tf.get_variable("W_c_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_f_u = tf.get_variable("U_f_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_i_u = tf.get_variable("U_i_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_o_u = tf.get_variable("U_o_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_c_u = tf.get_variable("U_c_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.b_f_u = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        self.b_i_u = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        self.b_o_u = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        self.b_c_u = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        
                        self.W_f_m = tf.get_variable("W_f_m", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.W_i_m = tf.get_variable("W_i_m", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.W_o_m = tf.get_variable("W_o_m", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.W_c_m = tf.get_variable("W_c_m", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_f_m = tf.get_variable("U_f_m", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_i_m = tf.get_variable("U_i_m", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_o_m = tf.get_variable("U_o_m", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_c_m = tf.get_variable("U_c_m", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.b_f_m = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        self.b_i_m = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        self.b_o_m = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        self.b_c_m = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        
                        #output parameters
                        self.W_out_W = tf.get_variable("W_out_W", shape=[self.n_conv_feat, initial_W.shape[1]], initializer=tf.glorot_uniform_initializer()) 
                        self.b_out_W = tf.Variable(tf.zeros([initial_W.shape[1],]))
                        self.W_out_H = tf.get_variable("W_out_H", shape=[self.n_conv_feat, initial_H.shape[1]], initializer=tf.glorot_uniform_initializer()) 
                        self.b_out_H = tf.Variable(tf.zeros([initial_H.shape[1],]))
                        
                        #########definition of the NN
                        #definition of W and H
                        self.W = tf.constant(initial_W.astype('float32'))
                        self.H = tf.constant(initial_H.astype('float32'))
                        
                        self.X = tf.matmul(self.W, self.H, transpose_b=True) #we may initialize it at random here
                        self.list_X = list()
                        self.list_X.append(tf.identity(self.X))
                        
                        #RNN
                        self.h_u = tf.zeros([M.shape[0], self.n_conv_feat])
                        self.c_u = tf.zeros([M.shape[0], self.n_conv_feat])
                        self.h_m = tf.zeros([M.shape[1], self.n_conv_feat])
                        self.c_m = tf.zeros([M.shape[1], self.n_conv_feat])
                        
                        
                        for k in range(self.num_iterations):
                            #extraction of global features vectors
                            self.final_feat_users = self.mono_conv(self.list_row_cheb_pol, self.ord_row, self.W, self.W_conv_W, self.b_conv_W)
                            self.final_feat_movies = self.mono_conv(self.list_col_cheb_pol, self.ord_col, self.H, self.W_conv_H, self.b_conv_H)
                            
                            #here we have to split the features between users and movies LSTMs
                            
                            #users RNN
                            self.f_u = tf.sigmoid(tf.matmul(self.final_feat_users, self.W_f_u) + tf.matmul(self.h_u, self.U_f_u) + self.b_f_u)
                            self.i_u = tf.sigmoid(tf.matmul(self.final_feat_users, self.W_i_u) + tf.matmul(self.h_u, self.U_i_u) + self.b_i_u)
                            self.o_u = tf.sigmoid(tf.matmul(self.final_feat_users, self.W_o_u) + tf.matmul(self.h_u, self.U_o_u) + self.b_o_u)
                            
                            self.update_c_u = tf.sigmoid(tf.matmul(self.final_feat_users, self.W_c_u) + tf.matmul(self.h_u, self.U_c_u) + self.b_c_u)
                            self.c_u = tf.multiply(self.f_u, self.c_u) + tf.multiply(self.i_u, self.update_c_u)
                            self.h_u = tf.multiply(self.o_u, tf.sigmoid(self.c_u))
                            
                            #movies RNN
                            self.f_m = tf.sigmoid(tf.matmul(self.final_feat_movies, self.W_f_m) + tf.matmul(self.h_m, self.U_f_m) + self.b_f_m)
                            self.i_m = tf.sigmoid(tf.matmul(self.final_feat_movies, self.W_i_m) + tf.matmul(self.h_m, self.U_i_m) + self.b_i_m)
                            self.o_m = tf.sigmoid(tf.matmul(self.final_feat_movies, self.W_o_m) + tf.matmul(self.h_m, self.U_o_m) + self.b_o_m)
                            
                            self.update_c_m = tf.sigmoid(tf.matmul(self.final_feat_movies, self.W_c_m) + tf.matmul(self.h_m, self.U_c_m) + self.b_c_m)
                            self.c_m = tf.multiply(self.f_m, self.c_m) + tf.multiply(self.i_m, self.update_c_m)
                            self.h_m = tf.multiply(self.o_m, tf.sigmoid(self.c_m))
                            
                            #compute update of matrix X
                            self.delta_W = tf.tanh(tf.matmul(self.c_u, self.W_out_W) + self.b_out_W) #N x rank_W_H
                            self.delta_H = tf.tanh(tf.matmul(self.c_m, self.W_out_H) + self.b_out_H) #M x rank_W_H
                            
                            self.W += self.delta_W
                            self.H += self.delta_H
                        
                            self.X = tf.matmul(self.W, self.H, transpose_b=True)
                            self.list_X.append(tf.identity(tf.reshape(self.X, [tf.shape(self.M)[0], tf.shape(self.M)[1]])))
                        self.X = tf.matmul(self.W, self.H, transpose_b=True)
                        #########loss definition
                        
                        #computation of the accuracy term
                        self.norm_X = 1+4*(self.X-tf.reduce_min(self.X))/(tf.reduce_max(self.X-tf.reduce_min(self.X)))
                        frob_tensor = tf.multiply(self.Otraining + self.Odata, self.norm_X - M)
                        self.loss_frob = tf.square(self.frobenius_norm(frob_tensor))/np.sum(Otraining+Odata)
                        
                        #computation of the regularization terms
                        trace_col_tensor = tf.matmul(tf.matmul(self.X, self.Lc), self.X, transpose_b=True)
                        self.loss_trace_col = tf.trace(trace_col_tensor)
                        trace_row_tensor = tf.matmul(tf.matmul(self.X, self.Lr, transpose_a=True), self.X)
                        self.loss_trace_row = tf.trace(trace_row_tensor)
                        
                        #training loss definition
                        self.loss = self.loss_frob + (gamma/2)*(self.loss_trace_col + self.loss_trace_row)
                        
                        #test loss definition
                        self.predictions = tf.multiply(self.Otest, self.norm_X - self.M)
                        self.predictions_error = self.frobenius_norm(self.predictions)

                        #definition of the solver
                        self.optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(self.loss)
                        
                        self.var_grad = tf.gradients(self.loss, tf.trainable_variables())
                        self.norm_grad = self.frobenius_norm(tf.concat([tf.reshape(g, [-1]) for g in self.var_grad], 0))

                        # Create a session for running Ops on the Graph.
                        config = tf.ConfigProto(allow_soft_placement = True)
                        config.gpu_options.allow_growth = True
                        self.session = tf.Session(config=config)

                        # Run the Op to initialize the variables.
                        init = tf.initialize_all_variables()
                        self.session.run(init)

# %%
ord_col = 5
ord_row = 5

learning_obj = Train_test_matrix_completion(M, Lrow.toarray(), Lcol.toarray(), Odata, Otraining, Otest, 
                                            initial_W, initial_H,
                                            order_chebyshev_col = ord_col, 
                                            order_chebyshev_row = ord_row, 
                                            gamma=1e-10,
                                            learning_rate=1e-3)

num_iter_test = 10
num_total_iter_training = 8500

num_iter = 0

list_training_loss = list()
list_training_norm_grad = list()
list_test_pred_error = list()
list_predictions = list()
list_X = list()

list_training_times = list()
list_test_times = list()
list_grad_X = list()

list_X_evolutions = list()

# %%
num_iter = 0
for k in range(num_iter, num_total_iter_training):

    tic = time.time()
    _, current_training_loss, norm_grad, X_grad = learning_obj.session.run([learning_obj.optimizer, learning_obj.loss, 
                                                                                        learning_obj.norm_grad, learning_obj.var_grad]) 
    training_time = time.time() - tic

    list_training_loss.append(current_training_loss)
    list_training_norm_grad.append(norm_grad)
    list_training_times.append(training_time)

    if (np.mod(num_iter, num_iter_test)==0):
        msg = "[TRN] iter = %03i, cost = %3.2e, |grad| = %.2e (%3.2es)" \
                                    % (num_iter, list_training_loss[-1], list_training_norm_grad[-1], training_time)
        print (msg)
        
        #Test Code
        tic = time.time()
        pred_error, preds, X = learning_obj.session.run([learning_obj.predictions_error, learning_obj.predictions,
                                                                             learning_obj.norm_X]) 
        c_X_evolutions = learning_obj.session.run(learning_obj.list_X)
        list_X_evolutions.append(c_X_evolutions)

        test_time = time.time() - tic

        list_test_pred_error.append(pred_error)
        list_X.append(X)
        list_test_times.append(test_time)
            
        RMSE = np.sqrt(np.square(pred_error)/np.sum(Otest))
        msg =  "[TST] iter = %03i, cost = %3.2e, RMSE = %3.2e (%3.2es)" % (num_iter, list_test_pred_error[-1], RMSE, test_time)
        print (msg)
        
    num_iter += 1
# Out:
# [TRN] iter = 000, cost = 1.65e+00, |grad| = 7.09e+00 (4.78e+00s)
# [TST] iter = 000, cost = 1.74e+02, RMSE = 1.23e+00 (3.38e+00s)
# [TRN] iter = 010, cost = 1.32e+00, |grad| = 9.68e-01 (4.91e-01s)
# [TST] iter = 010, cost = 1.64e+02, RMSE = 1.16e+00 (3.26e-01s)
# [TRN] iter = 020, cost = 1.26e+00, |grad| = 5.73e-01 (4.34e-01s)
# [TST] iter = 020, cost = 1.61e+02, RMSE = 1.14e+00 (2.90e-01s)
# [TRN] iter = 030, cost = 1.22e+00, |grad| = 6.03e-01 (4.26e-01s)
# [TST] iter = 030, cost = 1.58e+02, RMSE = 1.12e+00 (2.97e-01s)
# [TRN] iter = 040, cost = 1.17e+00, |grad| = 3.84e-01 (4.42e-01s)
# [TST] iter = 040, cost = 1.55e+02, RMSE = 1.10e+00 (2.96e-01s)
# [TRN] iter = 050, cost = 1.14e+00, |grad| = 2.71e-01 (4.32e-01s)
# [TST] iter = 050, cost = 1.54e+02, RMSE = 1.09e+00 (2.98e-01s)
# [TRN] iter = 060, cost = 1.12e+00, |grad| = 3.38e-01 (4.50e-01s)
# [TST] iter = 060, cost = 1.52e+02, RMSE = 1.08e+00 (2.92e-01s)
# [TRN] iter = 070, cost = 1.10e+00, |grad| = 8.25e-01 (4.50e-01s)
# [TST] iter = 070, cost = 1.51e+02, RMSE = 1.07e+00 (3.13e-01s)
# [TRN] iter = 080, cost = 1.10e+00, |grad| = 3.15e+00 (4.33e-01s)
# [TST] iter = 080, cost = 1.51e+02, RMSE = 1.07e+00 (2.95e-01s)
# [TRN] iter = 090, cost = 1.08e+00, |grad| = 1.49e+00 (6.74e-01s)
# [TST] iter = 090, cost = 1.50e+02, RMSE = 1.06e+00 (4.59e-01s)
# [TRN] iter = 100, cost = 1.07e+00, |grad| = 1.03e+00 (4.48e-01s)
# [TST] iter = 100, cost = 1.50e+02, RMSE = 1.06e+00 (2.91e-01s)
# [TRN] iter = 110, cost = 1.06e+00, |grad| = 9.07e-01 (4.66e-01s)
# [TST] iter = 110, cost = 1.50e+02, RMSE = 1.06e+00 (3.01e-01s)
# [TRN] iter = 120, cost = 1.05e+00, |grad| = 1.43e+00 (4.97e-01s)
# [TST] iter = 120, cost = 1.50e+02, RMSE = 1.06e+00 (3.42e-01s)
# [TRN] iter = 130, cost = 1.06e+00, |grad| = 1.01e+00 (4.40e-01s)
# [TST] iter = 130, cost = 1.50e+02, RMSE = 1.06e+00 (3.00e-01s)
# [TRN] iter = 140, cost = 1.05e+00, |grad| = 5.33e-01 (5.50e-01s)
# [TST] iter = 140, cost = 1.49e+02, RMSE = 1.05e+00 (3.11e-01s)
# [TRN] iter = 150, cost = 1.04e+00, |grad| = 2.51e-01 (4.42e-01s)
# [TST] iter = 150, cost = 1.49e+02, RMSE = 1.05e+00 (3.09e-01s)
# [TRN] iter = 160, cost = 1.04e+00, |grad| = 3.44e-01 (4.54e-01s)
# [TST] iter = 160, cost = 1.48e+02, RMSE = 1.05e+00 (2.93e-01s)
# [TRN] iter = 170, cost = 1.03e+00, |grad| = 1.80e-01 (4.43e-01s)
# [TST] iter = 170, cost = 1.48e+02, RMSE = 1.05e+00 (3.01e-01s)
# [TRN] iter = 180, cost = 1.03e+00, |grad| = 7.26e-01 (4.40e-01s)
# [TST] iter = 180, cost = 1.48e+02, RMSE = 1.05e+00 (3.19e-01s)
# [TRN] iter = 190, cost = 1.03e+00, |grad| = 4.03e-01 (4.39e-01s)
# [TST] iter = 190, cost = 1.48e+02, RMSE = 1.04e+00 (3.29e-01s)
# [TRN] iter = 200, cost = 1.02e+00, |grad| = 7.10e-01 (4.43e-01s)
# [TST] iter = 200, cost = 1.48e+02, RMSE = 1.04e+00 (3.31e-01s)
# [TRN] iter = 210, cost = 1.02e+00, |grad| = 4.34e-01 (4.77e-01s)
# [TST] iter = 210, cost = 1.47e+02, RMSE = 1.04e+00 (3.18e-01s)
# [TRN] iter = 220, cost = 1.03e+00, |grad| = 3.82e+00 (4.69e-01s)
# [TST] iter = 220, cost = 1.47e+02, RMSE = 1.04e+00 (3.08e-01s)
# [TRN] iter = 230, cost = 1.02e+00, |grad| = 6.19e-01 (4.72e-01s)
# [TST] iter = 230, cost = 1.47e+02, RMSE = 1.04e+00 (3.09e-01s)
# [TRN] iter = 240, cost = 1.02e+00, |grad| = 7.14e-01 (4.76e-01s)
# [TST] iter = 240, cost = 1.47e+02, RMSE = 1.04e+00 (3.41e-01s)
# [TRN] iter = 250, cost = 1.02e+00, |grad| = 1.55e+00 (4.77e-01s)
# [TST] iter = 250, cost = 1.47e+02, RMSE = 1.04e+00 (3.18e-01s)
# [TRN] iter = 260, cost = 1.01e+00, |grad| = 1.19e+00 (4.51e-01s)
# [TST] iter = 260, cost = 1.47e+02, RMSE = 1.04e+00 (3.14e-01s)
# [TRN] iter = 270, cost = 1.00e+00, |grad| = 5.85e-01 (4.83e-01s)
# [TST] iter = 270, cost = 1.47e+02, RMSE = 1.04e+00 (3.26e-01s)
# [TRN] iter = 280, cost = 1.00e+00, |grad| = 3.00e-01 (4.61e-01s)
# [TST] iter = 280, cost = 1.46e+02, RMSE = 1.03e+00 (3.33e-01s)
# [TRN] iter = 290, cost = 1.00e+00, |grad| = 9.83e-01 (4.63e-01s)
# [TST] iter = 290, cost = 1.47e+02, RMSE = 1.04e+00 (3.20e-01s)
# [TRN] iter = 300, cost = 1.01e+00, |grad| = 1.80e+00 (4.66e-01s)
# [TST] iter = 300, cost = 1.47e+02, RMSE = 1.04e+00 (3.36e-01s)
# [TRN] iter = 310, cost = 1.00e+00, |grad| = 9.06e-01 (4.61e-01s)
# [TST] iter = 310, cost = 1.46e+02, RMSE = 1.03e+00 (3.49e-01s)
# [TRN] iter = 320, cost = 9.96e-01, |grad| = 9.22e-01 (4.58e-01s)
# [TST] iter = 320, cost = 1.46e+02, RMSE = 1.03e+00 (3.13e-01s)
# [TRN] iter = 330, cost = 9.93e-01, |grad| = 2.37e+00 (4.50e-01s)
# [TST] iter = 330, cost = 1.46e+02, RMSE = 1.03e+00 (3.33e-01s)
# [TRN] iter = 340, cost = 9.92e-01, |grad| = 8.44e-01 (4.94e-01s)
# [TST] iter = 340, cost = 1.46e+02, RMSE = 1.03e+00 (3.62e-01s)
# [TRN] iter = 350, cost = 1.01e+00, |grad| = 2.71e+00 (4.58e-01s)
# [TST] iter = 350, cost = 1.46e+02, RMSE = 1.03e+00 (3.08e-01s)
# [TRN] iter = 360, cost = 9.87e-01, |grad| = 1.38e+00 (4.72e-01s)
# [TST] iter = 360, cost = 1.46e+02, RMSE = 1.03e+00 (3.85e-01s)
# [TRN] iter = 370, cost = 9.85e-01, |grad| = 8.41e-01 (4.73e-01s)
# [TST] iter = 370, cost = 1.45e+02, RMSE = 1.03e+00 (3.35e-01s)
# [TRN] iter = 380, cost = 9.83e-01, |grad| = 5.34e-01 (5.00e-01s)
# [TST] iter = 380, cost = 1.45e+02, RMSE = 1.03e+00 (3.33e-01s)
# [TRN] iter = 390, cost = 9.81e-01, |grad| = 1.80e+00 (5.12e-01s)
# [TST] iter = 390, cost = 1.45e+02, RMSE = 1.03e+00 (2.98e-01s)
# [TRN] iter = 400, cost = 9.76e-01, |grad| = 5.73e-01 (5.29e-01s)
# [TST] iter = 400, cost = 1.45e+02, RMSE = 1.02e+00 (3.72e-01s)
# [TRN] iter = 410, cost = 9.79e-01, |grad| = 1.10e+00 (4.85e-01s)
# [TST] iter = 410, cost = 1.45e+02, RMSE = 1.02e+00 (3.35e-01s)
# [TRN] iter = 420, cost = 9.75e-01, |grad| = 6.64e-01 (4.79e-01s)
# [TST] iter = 420, cost = 1.45e+02, RMSE = 1.02e+00 (3.18e-01s)
# [TRN] iter = 430, cost = 9.77e-01, |grad| = 1.18e+00 (4.76e-01s)
# [TST] iter = 430, cost = 1.45e+02, RMSE = 1.02e+00 (3.10e-01s)
# [TRN] iter = 440, cost = 9.74e-01, |grad| = 1.05e+00 (4.83e-01s)
# [TST] iter = 440, cost = 1.45e+02, RMSE = 1.02e+00 (3.11e-01s)
# [TRN] iter = 450, cost = 9.71e-01, |grad| = 9.38e-01 (4.52e-01s)
# [TST] iter = 450, cost = 1.44e+02, RMSE = 1.02e+00 (3.25e-01s)
# [TRN] iter = 460, cost = 9.66e-01, |grad| = 1.17e+00 (4.82e-01s)
# [TST] iter = 460, cost = 1.44e+02, RMSE = 1.02e+00 (3.20e-01s)
# [TRN] iter = 470, cost = 9.64e-01, |grad| = 5.22e-01 (4.66e-01s)
# [TST] iter = 470, cost = 1.44e+02, RMSE = 1.02e+00 (3.09e-01s)
# [TRN] iter = 480, cost = 9.68e-01, |grad| = 1.55e+00 (4.67e-01s)
# [TST] iter = 480, cost = 1.44e+02, RMSE = 1.02e+00 (3.27e-01s)
# [TRN] iter = 490, cost = 9.80e-01, |grad| = 2.45e+00 (5.14e-01s)
# [TST] iter = 490, cost = 1.44e+02, RMSE = 1.02e+00 (3.29e-01s)
# [TRN] iter = 500, cost = 9.66e-01, |grad| = 1.22e+00 (4.52e-01s)
# [TST] iter = 500, cost = 1.45e+02, RMSE = 1.02e+00 (3.36e-01s)
# [TRN] iter = 510, cost = 9.67e-01, |grad| = 6.94e-01 (4.50e-01s)
# [TST] iter = 510, cost = 1.44e+02, RMSE = 1.02e+00 (3.01e-01s)
# [TRN] iter = 520, cost = 9.59e-01, |grad| = 6.85e-01 (4.44e-01s)
# [TST] iter = 520, cost = 1.44e+02, RMSE = 1.01e+00 (2.98e-01s)
# [TRN] iter = 530, cost = 9.57e-01, |grad| = 4.31e-01 (5.21e-01s)
# [TST] iter = 530, cost = 1.44e+02, RMSE = 1.02e+00 (3.01e-01s)
# [TRN] iter = 540, cost = 9.54e-01, |grad| = 7.83e-01 (4.34e-01s)
# [TST] iter = 540, cost = 1.43e+02, RMSE = 1.01e+00 (2.91e-01s)
# [TRN] iter = 550, cost = 9.51e-01, |grad| = 7.91e-01 (4.89e-01s)
# [TST] iter = 550, cost = 1.43e+02, RMSE = 1.01e+00 (3.03e-01s)
# [TRN] iter = 560, cost = 9.49e-01, |grad| = 5.93e-01 (4.57e-01s)
# [TST] iter = 560, cost = 1.43e+02, RMSE = 1.01e+00 (3.09e-01s)
# [TRN] iter = 570, cost = 9.52e-01, |grad| = 1.11e+00 (4.97e-01s)
# [TST] iter = 570, cost = 1.43e+02, RMSE = 1.01e+00 (3.23e-01s)
# [TRN] iter = 580, cost = 9.65e-01, |grad| = 1.80e+00 (4.57e-01s)
# [TST] iter = 580, cost = 1.44e+02, RMSE = 1.02e+00 (3.22e-01s)
# [TRN] iter = 590, cost = 9.79e-01, |grad| = 9.57e-01 (4.53e-01s)
# [TST] iter = 590, cost = 1.44e+02, RMSE = 1.02e+00 (3.04e-01s)
# [TRN] iter = 600, cost = 9.56e-01, |grad| = 1.16e+00 (4.67e-01s)
# [TST] iter = 600, cost = 1.43e+02, RMSE = 1.01e+00 (3.33e-01s)
# [TRN] iter = 610, cost = 9.65e-01, |grad| = 3.04e+00 (4.65e-01s)
# [TST] iter = 610, cost = 1.44e+02, RMSE = 1.02e+00 (3.07e-01s)
# [TRN] iter = 620, cost = 9.56e-01, |grad| = 2.42e+00 (4.54e-01s)
# [TST] iter = 620, cost = 1.43e+02, RMSE = 1.01e+00 (3.01e-01s)
# [TRN] iter = 630, cost = 9.47e-01, |grad| = 1.05e+00 (4.50e-01s)
# [TST] iter = 630, cost = 1.43e+02, RMSE = 1.01e+00 (3.00e-01s)
# [TRN] iter = 640, cost = 9.42e-01, |grad| = 5.52e-01 (4.52e-01s)
# [TST] iter = 640, cost = 1.42e+02, RMSE = 1.01e+00 (3.06e-01s)
# [TRN] iter = 650, cost = 9.44e-01, |grad| = 2.40e+00 (4.98e-01s)
# [TST] iter = 650, cost = 1.42e+02, RMSE = 1.01e+00 (3.29e-01s)
# [TRN] iter = 660, cost = 9.60e-01, |grad| = 2.64e+00 (4.58e-01s)
# [TST] iter = 660, cost = 1.43e+02, RMSE = 1.01e+00 (3.01e-01s)
# [TRN] iter = 670, cost = 9.45e-01, |grad| = 1.28e+00 (4.64e-01s)
# [TST] iter = 670, cost = 1.43e+02, RMSE = 1.01e+00 (3.19e-01s)
# [TRN] iter = 680, cost = 9.42e-01, |grad| = 2.33e+00 (4.67e-01s)
# [TST] iter = 680, cost = 1.42e+02, RMSE = 1.01e+00 (2.92e-01s)
# [TRN] iter = 690, cost = 9.41e-01, |grad| = 9.33e-01 (4.65e-01s)
# [TST] iter = 690, cost = 1.42e+02, RMSE = 1.01e+00 (3.09e-01s)
# [TRN] iter = 700, cost = 9.68e-01, |grad| = 7.41e+00 (4.61e-01s)
# [TST] iter = 700, cost = 1.43e+02, RMSE = 1.01e+00 (3.25e-01s)
# [TRN] iter = 710, cost = 9.59e-01, |grad| = 1.34e+00 (4.48e-01s)
# [TST] iter = 710, cost = 1.43e+02, RMSE = 1.01e+00 (3.13e-01s)
# [TRN] iter = 720, cost = 9.44e-01, |grad| = 1.24e+00 (4.43e-01s)
# [TST] iter = 720, cost = 1.43e+02, RMSE = 1.01e+00 (3.17e-01s)
# [TRN] iter = 730, cost = 9.41e-01, |grad| = 1.12e+00 (4.74e-01s)
# [TST] iter = 730, cost = 1.42e+02, RMSE = 1.01e+00 (3.33e-01s)
# [TRN] iter = 740, cost = 9.35e-01, |grad| = 9.64e-01 (4.67e-01s)
# [TST] iter = 740, cost = 1.43e+02, RMSE = 1.01e+00 (3.20e-01s)
# [TRN] iter = 750, cost = 9.34e-01, |grad| = 6.87e-01 (4.74e-01s)
# [TST] iter = 750, cost = 1.42e+02, RMSE = 1.00e+00 (3.03e-01s)
# [TRN] iter = 760, cost = 9.42e-01, |grad| = 2.50e+00 (5.78e-01s)
# [TST] iter = 760, cost = 1.42e+02, RMSE = 1.01e+00 (3.02e-01s)
# [TRN] iter = 770, cost = 9.33e-01, |grad| = 9.87e-01 (4.86e-01s)
# [TST] iter = 770, cost = 1.42e+02, RMSE = 1.00e+00 (3.00e-01s)
# [TRN] iter = 780, cost = 9.51e-01, |grad| = 5.24e+00 (4.60e-01s)
# [TST] iter = 780, cost = 1.42e+02, RMSE = 1.01e+00 (3.32e-01s)
# [TRN] iter = 790, cost = 9.37e-01, |grad| = 1.28e+00 (4.55e-01s)
# [TST] iter = 790, cost = 1.42e+02, RMSE = 1.00e+00 (3.12e-01s)
# [TRN] iter = 800, cost = 9.29e-01, |grad| = 1.07e+00 (6.07e-01s)
# [TST] iter = 800, cost = 1.42e+02, RMSE = 1.00e+00 (3.28e-01s)
# [TRN] iter = 810, cost = 9.25e-01, |grad| = 9.77e-01 (6.59e-01s)
# [TST] iter = 810, cost = 1.41e+02, RMSE = 9.99e-01 (3.14e-01s)
# [TRN] iter = 820, cost = 9.23e-01, |grad| = 4.40e-01 (5.34e-01s)
# [TST] iter = 820, cost = 1.41e+02, RMSE = 9.99e-01 (3.52e-01s)
# [TRN] iter = 830, cost = 9.21e-01, |grad| = 6.34e-01 (6.69e-01s)
# [TST] iter = 830, cost = 1.41e+02, RMSE = 9.99e-01 (3.99e-01s)
# [TRN] iter = 840, cost = 9.23e-01, |grad| = 2.70e+00 (6.47e-01s)
# [TST] iter = 840, cost = 1.42e+02, RMSE = 1.00e+00 (3.58e-01s)
# [TRN] iter = 850, cost = 9.25e-01, |grad| = 1.22e+00 (4.47e-01s)
# [TST] iter = 850, cost = 1.41e+02, RMSE = 1.00e+00 (3.11e-01s)
# [TRN] iter = 860, cost = 9.37e-01, |grad| = 1.09e+00 (4.45e-01s)
# [TST] iter = 860, cost = 1.42e+02, RMSE = 1.00e+00 (3.01e-01s)
# [TRN] iter = 870, cost = 9.30e-01, |grad| = 8.06e-01 (5.54e-01s)
# [TST] iter = 870, cost = 1.41e+02, RMSE = 1.00e+00 (3.32e-01s)
# [TRN] iter = 880, cost = 9.28e-01, |grad| = 1.47e+00 (4.78e-01s)
# [TST] iter = 880, cost = 1.42e+02, RMSE = 1.00e+00 (3.01e-01s)
# [TRN] iter = 890, cost = 9.27e-01, |grad| = 7.46e-01 (4.99e-01s)
# [TST] iter = 890, cost = 1.41e+02, RMSE = 9.99e-01 (3.31e-01s)
# [TRN] iter = 900, cost = 9.23e-01, |grad| = 1.95e+00 (5.66e-01s)
# [TST] iter = 900, cost = 1.41e+02, RMSE = 9.99e-01 (3.02e-01s)
# [TRN] iter = 910, cost = 9.26e-01, |grad| = 1.35e+00 (4.61e-01s)
# [TST] iter = 910, cost = 1.41e+02, RMSE = 9.98e-01 (3.02e-01s)
# [TRN] iter = 920, cost = 9.29e-01, |grad| = 1.22e+00 (4.53e-01s)
# [TST] iter = 920, cost = 1.42e+02, RMSE = 1.01e+00 (3.09e-01s)
# [TRN] iter = 930, cost = 9.29e-01, |grad| = 9.27e-01 (4.51e-01s)
# [TST] iter = 930, cost = 1.42e+02, RMSE = 1.00e+00 (3.03e-01s)
# [TRN] iter = 940, cost = 9.20e-01, |grad| = 9.23e-01 (4.48e-01s)
# [TST] iter = 940, cost = 1.41e+02, RMSE = 9.98e-01 (2.90e-01s)
# [TRN] iter = 950, cost = 9.27e-01, |grad| = 1.07e+00 (4.39e-01s)
# [TST] iter = 950, cost = 1.41e+02, RMSE = 1.00e+00 (3.28e-01s)
# [TRN] iter = 960, cost = 9.32e-01, |grad| = 1.19e+00 (4.48e-01s)
# [TST] iter = 960, cost = 1.41e+02, RMSE = 9.96e-01 (2.91e-01s)
# [TRN] iter = 970, cost = 9.19e-01, |grad| = 9.39e-01 (4.42e-01s)
# [TST] iter = 970, cost = 1.41e+02, RMSE = 9.97e-01 (2.99e-01s)
# [TRN] iter = 980, cost = 9.13e-01, |grad| = 5.59e-01 (4.63e-01s)
# [TST] iter = 980, cost = 1.41e+02, RMSE = 9.94e-01 (3.17e-01s)
# [TRN] iter = 990, cost = 9.12e-01, |grad| = 8.31e-01 (4.60e-01s)
# [TST] iter = 990, cost = 1.41e+02, RMSE = 9.94e-01 (3.07e-01s)
# [TRN] iter = 1000, cost = 9.17e-01, |grad| = 1.45e+00 (5.43e-01s)
# [TST] iter = 1000, cost = 1.41e+02, RMSE = 9.95e-01 (3.18e-01s)
# [TRN] iter = 1010, cost = 9.13e-01, |grad| = 7.53e-01 (4.55e-01s)
# [TST] iter = 1010, cost = 1.41e+02, RMSE = 9.94e-01 (3.20e-01s)
# [TRN] iter = 1020, cost = 9.11e-01, |grad| = 1.09e+00 (4.60e-01s)
# [TST] iter = 1020, cost = 1.40e+02, RMSE = 9.93e-01 (3.44e-01s)
# [TRN] iter = 1030, cost = 9.09e-01, |grad| = 1.72e+00 (4.93e-01s)
# [TST] iter = 1030, cost = 1.40e+02, RMSE = 9.92e-01 (3.25e-01s)
# [TRN] iter = 1040, cost = 9.09e-01, |grad| = 9.10e-01 (4.74e-01s)
# [TST] iter = 1040, cost = 1.40e+02, RMSE = 9.92e-01 (3.58e-01s)
# [TRN] iter = 1050, cost = 9.11e-01, |grad| = 1.43e+00 (5.73e-01s)
# [TST] iter = 1050, cost = 1.40e+02, RMSE = 9.93e-01 (3.60e-01s)
# [TRN] iter = 1060, cost = 9.19e-01, |grad| = 1.19e+00 (4.90e-01s)
# [TST] iter = 1060, cost = 1.41e+02, RMSE = 9.94e-01 (3.34e-01s)
# [TRN] iter = 1070, cost = 9.12e-01, |grad| = 2.41e+00 (4.76e-01s)
# [TST] iter = 1070, cost = 1.44e+02, RMSE = 1.02e+00 (3.47e-01s)
# [TRN] iter = 1080, cost = 9.27e-01, |grad| = 1.61e+00 (5.09e-01s)
# [TST] iter = 1080, cost = 1.42e+02, RMSE = 1.00e+00 (3.33e-01s)
# [TRN] iter = 1090, cost = 9.22e-01, |grad| = 1.28e+00 (5.04e-01s)
# [TST] iter = 1090, cost = 1.41e+02, RMSE = 9.96e-01 (3.91e-01s)
# [TRN] iter = 1100, cost = 9.24e-01, |grad| = 1.35e+00 (5.54e-01s)
# [TST] iter = 1100, cost = 1.41e+02, RMSE = 9.96e-01 (3.38e-01s)
# [TRN] iter = 1110, cost = 9.17e-01, |grad| = 1.35e+00 (5.61e-01s)
# [TST] iter = 1110, cost = 1.41e+02, RMSE = 9.95e-01 (3.33e-01s)
# [TRN] iter = 1120, cost = 9.06e-01, |grad| = 6.45e-01 (5.69e-01s)
# [TST] iter = 1120, cost = 1.40e+02, RMSE = 9.90e-01 (4.01e-01s)
# [TRN] iter = 1130, cost = 9.02e-01, |grad| = 7.10e-01 (6.27e-01s)
# [TST] iter = 1130, cost = 1.40e+02, RMSE = 9.89e-01 (3.27e-01s)
# [TRN] iter = 1140, cost = 9.05e-01, |grad| = 1.72e+00 (4.64e-01s)
# [TST] iter = 1140, cost = 1.40e+02, RMSE = 9.89e-01 (3.34e-01s)
# [TRN] iter = 1150, cost = 9.02e-01, |grad| = 1.28e+00 (4.87e-01s)
# [TST] iter = 1150, cost = 1.41e+02, RMSE = 9.95e-01 (3.49e-01s)
# [TRN] iter = 1160, cost = 9.23e-01, |grad| = 3.00e+00 (4.60e-01s)
# [TST] iter = 1160, cost = 1.42e+02, RMSE = 1.00e+00 (3.16e-01s)
# [TRN] iter = 1170, cost = 9.11e-01, |grad| = 2.21e+00 (4.66e-01s)
# [TST] iter = 1170, cost = 1.43e+02, RMSE = 1.01e+00 (3.32e-01s)
# [TRN] iter = 1180, cost = 9.46e-01, |grad| = 3.99e+00 (5.70e-01s)
# [TST] iter = 1180, cost = 1.41e+02, RMSE = 1.00e+00 (4.47e-01s)
# [TRN] iter = 1190, cost = 9.42e-01, |grad| = 1.72e+00 (4.91e-01s)
# [TST] iter = 1190, cost = 1.42e+02, RMSE = 1.00e+00 (3.58e-01s)
# [TRN] iter = 1200, cost = 9.18e-01, |grad| = 7.24e-01 (5.28e-01s)
# [TST] iter = 1200, cost = 1.40e+02, RMSE = 9.92e-01 (3.52e-01s)
# [TRN] iter = 1210, cost = 9.10e-01, |grad| = 5.61e-01 (4.90e-01s)
# [TST] iter = 1210, cost = 1.40e+02, RMSE = 9.91e-01 (3.40e-01s)
# [TRN] iter = 1220, cost = 9.04e-01, |grad| = 8.72e-01 (9.24e-01s)
# [TST] iter = 1220, cost = 1.40e+02, RMSE = 9.89e-01 (5.37e-01s)
# [TRN] iter = 1230, cost = 8.99e-01, |grad| = 3.27e-01 (7.02e-01s)
# [TST] iter = 1230, cost = 1.40e+02, RMSE = 9.87e-01 (4.23e-01s)
# [TRN] iter = 1240, cost = 8.98e-01, |grad| = 5.67e-01 (5.06e-01s)
# [TST] iter = 1240, cost = 1.40e+02, RMSE = 9.87e-01 (3.36e-01s)
# [TRN] iter = 1250, cost = 9.09e-01, |grad| = 1.32e+00 (4.77e-01s)
# [TST] iter = 1250, cost = 1.40e+02, RMSE = 9.91e-01 (3.15e-01s)
# [TRN] iter = 1260, cost = 9.05e-01, |grad| = 7.62e-01 (5.18e-01s)
# [TST] iter = 1260, cost = 1.40e+02, RMSE = 9.91e-01 (4.68e-01s)
# [TRN] iter = 1270, cost = 8.99e-01, |grad| = 1.15e+00 (5.36e-01s)
# [TST] iter = 1270, cost = 1.40e+02, RMSE = 9.87e-01 (3.46e-01s)
# [TRN] iter = 1280, cost = 8.97e-01, |grad| = 1.07e+00 (4.79e-01s)
# [TST] iter = 1280, cost = 1.39e+02, RMSE = 9.86e-01 (3.19e-01s)
# [TRN] iter = 1290, cost = 8.94e-01, |grad| = 4.96e-01 (4.94e-01s)
# [TST] iter = 1290, cost = 1.39e+02, RMSE = 9.86e-01 (3.29e-01s)
# [TRN] iter = 1300, cost = 9.21e-01, |grad| = 2.45e+00 (4.81e-01s)
# [TST] iter = 1300, cost = 1.41e+02, RMSE = 9.94e-01 (3.49e-01s)
# [TRN] iter = 1310, cost = 9.03e-01, |grad| = 1.55e+00 (4.84e-01s)
# [TST] iter = 1310, cost = 1.40e+02, RMSE = 9.88e-01 (3.48e-01s)
# [TRN] iter = 1320, cost = 8.97e-01, |grad| = 7.40e-01 (4.94e-01s)
# [TST] iter = 1320, cost = 1.39e+02, RMSE = 9.86e-01 (3.38e-01s)
# [TRN] iter = 1330, cost = 9.01e-01, |grad| = 7.85e-01 (4.92e-01s)
# [TST] iter = 1330, cost = 1.40e+02, RMSE = 9.91e-01 (3.26e-01s)
# [TRN] iter = 1340, cost = 9.23e-01, |grad| = 3.94e+00 (4.62e-01s)
# [TST] iter = 1340, cost = 1.40e+02, RMSE = 9.88e-01 (3.44e-01s)
# [TRN] iter = 1350, cost = 9.29e-01, |grad| = 3.82e+00 (4.80e-01s)
# [TST] iter = 1350, cost = 1.41e+02, RMSE = 9.95e-01 (3.30e-01s)
# [TRN] iter = 1360, cost = 9.08e-01, |grad| = 1.38e+00 (5.02e-01s)
# [TST] iter = 1360, cost = 1.40e+02, RMSE = 9.90e-01 (3.38e-01s)
# [TRN] iter = 1370, cost = 8.99e-01, |grad| = 1.04e+00 (4.69e-01s)
# [TST] iter = 1370, cost = 1.39e+02, RMSE = 9.85e-01 (3.29e-01s)
# [TRN] iter = 1380, cost = 8.94e-01, |grad| = 1.04e+00 (4.77e-01s)
# [TST] iter = 1380, cost = 1.39e+02, RMSE = 9.86e-01 (3.51e-01s)
# [TRN] iter = 1390, cost = 8.95e-01, |grad| = 1.60e+00 (4.94e-01s)
# [TST] iter = 1390, cost = 1.40e+02, RMSE = 9.87e-01 (3.31e-01s)
# [TRN] iter = 1400, cost = 9.11e-01, |grad| = 3.62e+00 (4.73e-01s)
# [TST] iter = 1400, cost = 1.40e+02, RMSE = 9.88e-01 (3.32e-01s)
# [TRN] iter = 1410, cost = 9.12e-01, |grad| = 1.61e+00 (4.66e-01s)
# [TST] iter = 1410, cost = 1.40e+02, RMSE = 9.93e-01 (3.44e-01s)
# [TRN] iter = 1420, cost = 9.01e-01, |grad| = 3.45e+00 (4.81e-01s)
# [TST] iter = 1420, cost = 1.39e+02, RMSE = 9.85e-01 (3.47e-01s)
# [TRN] iter = 1430, cost = 8.92e-01, |grad| = 9.44e-01 (4.91e-01s)
# [TST] iter = 1430, cost = 1.39e+02, RMSE = 9.82e-01 (3.38e-01s)
# [TRN] iter = 1440, cost = 8.92e-01, |grad| = 9.23e-01 (4.77e-01s)
# [TST] iter = 1440, cost = 1.39e+02, RMSE = 9.82e-01 (3.27e-01s)
# [TRN] iter = 1450, cost = 8.88e-01, |grad| = 7.45e-01 (4.97e-01s)
# [TST] iter = 1450, cost = 1.39e+02, RMSE = 9.82e-01 (3.41e-01s)
# [TRN] iter = 1460, cost = 8.85e-01, |grad| = 4.90e-01 (4.74e-01s)
# [TST] iter = 1460, cost = 1.39e+02, RMSE = 9.80e-01 (3.25e-01s)
# [TRN] iter = 1470, cost = 8.84e-01, |grad| = 9.21e-01 (4.68e-01s)
# [TST] iter = 1470, cost = 1.39e+02, RMSE = 9.80e-01 (3.29e-01s)
# [TRN] iter = 1480, cost = 8.82e-01, |grad| = 7.68e-01 (4.84e-01s)
# [TST] iter = 1480, cost = 1.38e+02, RMSE = 9.79e-01 (3.26e-01s)
# [TRN] iter = 1490, cost = 8.83e-01, |grad| = 9.30e-01 (4.71e-01s)
# [TST] iter = 1490, cost = 1.38e+02, RMSE = 9.79e-01 (3.38e-01s)
# [TRN] iter = 1500, cost = 9.39e-01, |grad| = 2.47e+00 (4.88e-01s)
# [TST] iter = 1500, cost = 1.42e+02, RMSE = 1.00e+00 (3.25e-01s)
# [TRN] iter = 1510, cost = 9.06e-01, |grad| = 1.57e+00 (4.65e-01s)
# [TST] iter = 1510, cost = 1.39e+02, RMSE = 9.86e-01 (3.23e-01s)
# [TRN] iter = 1520, cost = 9.04e-01, |grad| = 1.43e+00 (4.98e-01s)
# [TST] iter = 1520, cost = 1.40e+02, RMSE = 9.89e-01 (3.39e-01s)
# [TRN] iter = 1530, cost = 8.92e-01, |grad| = 7.02e-01 (4.64e-01s)
# [TST] iter = 1530, cost = 1.39e+02, RMSE = 9.83e-01 (3.16e-01s)
# [TRN] iter = 1540, cost = 8.95e-01, |grad| = 1.70e+00 (4.61e-01s)
# [TST] iter = 1540, cost = 1.39e+02, RMSE = 9.82e-01 (3.28e-01s)
# [TRN] iter = 1550, cost = 9.12e-01, |grad| = 2.45e+00 (4.60e-01s)
# [TST] iter = 1550, cost = 1.40e+02, RMSE = 9.88e-01 (3.32e-01s)
# [TRN] iter = 1560, cost = 8.90e-01, |grad| = 2.71e+00 (4.78e-01s)
# [TST] iter = 1560, cost = 1.39e+02, RMSE = 9.85e-01 (3.29e-01s)
# [TRN] iter = 1570, cost = 8.87e-01, |grad| = 1.44e+00 (4.74e-01s)
# [TST] iter = 1570, cost = 1.38e+02, RMSE = 9.78e-01 (3.27e-01s)
# [TRN] iter = 1580, cost = 8.84e-01, |grad| = 1.49e+00 (4.96e-01s)
# [TST] iter = 1580, cost = 1.38e+02, RMSE = 9.79e-01 (3.46e-01s)
# [TRN] iter = 1590, cost = 8.92e-01, |grad| = 4.87e+00 (4.73e-01s)
# [TST] iter = 1590, cost = 1.40e+02, RMSE = 9.90e-01 (4.63e-01s)
# [TRN] iter = 1600, cost = 8.88e-01, |grad| = 1.09e+00 (4.83e-01s)
# [TST] iter = 1600, cost = 1.39e+02, RMSE = 9.81e-01 (3.45e-01s)
# [TRN] iter = 1610, cost = 8.88e-01, |grad| = 1.58e+00 (6.58e-01s)
# [TST] iter = 1610, cost = 1.39e+02, RMSE = 9.83e-01 (3.57e-01s)
# [TRN] iter = 1620, cost = 8.89e-01, |grad| = 1.29e+00 (5.68e-01s)
# [TST] iter = 1620, cost = 1.39e+02, RMSE = 9.80e-01 (4.00e-01s)
# [TRN] iter = 1630, cost = 8.91e-01, |grad| = 2.24e+00 (4.90e-01s)
# [TST] iter = 1630, cost = 1.39e+02, RMSE = 9.82e-01 (3.28e-01s)
# [TRN] iter = 1640, cost = 8.82e-01, |grad| = 6.36e-01 (4.67e-01s)
# [TST] iter = 1640, cost = 1.38e+02, RMSE = 9.79e-01 (3.25e-01s)
# [TRN] iter = 1650, cost = 8.80e-01, |grad| = 2.01e+00 (4.60e-01s)
# [TST] iter = 1650, cost = 1.38e+02, RMSE = 9.77e-01 (3.21e-01s)
# [TRN] iter = 1660, cost = 8.80e-01, |grad| = 1.72e+00 (4.63e-01s)
# [TST] iter = 1660, cost = 1.38e+02, RMSE = 9.78e-01 (3.31e-01s)
# [TRN] iter = 1670, cost = 8.77e-01, |grad| = 9.48e-01 (4.62e-01s)
# [TST] iter = 1670, cost = 1.38e+02, RMSE = 9.76e-01 (3.19e-01s)
# [TRN] iter = 1680, cost = 8.90e-01, |grad| = 1.12e+00 (4.70e-01s)
# [TST] iter = 1680, cost = 1.39e+02, RMSE = 9.82e-01 (3.36e-01s)
# [TRN] iter = 1690, cost = 8.95e-01, |grad| = 2.50e+00 (4.77e-01s)
# [TST] iter = 1690, cost = 1.39e+02, RMSE = 9.81e-01 (3.43e-01s)
# [TRN] iter = 1700, cost = 8.83e-01, |grad| = 8.54e-01 (5.59e-01s)
# [TST] iter = 1700, cost = 1.38e+02, RMSE = 9.79e-01 (4.53e-01s)
# [TRN] iter = 1710, cost = 8.79e-01, |grad| = 7.88e-01 (4.70e-01s)
# [TST] iter = 1710, cost = 1.38e+02, RMSE = 9.75e-01 (3.69e-01s)
# [TRN] iter = 1720, cost = 8.80e-01, |grad| = 1.73e+00 (4.93e-01s)
# [TST] iter = 1720, cost = 1.38e+02, RMSE = 9.78e-01 (3.60e-01s)
# [TRN] iter = 1730, cost = 8.86e-01, |grad| = 1.41e+00 (5.13e-01s)
# [TST] iter = 1730, cost = 1.39e+02, RMSE = 9.83e-01 (3.51e-01s)
# [TRN] iter = 1740, cost = 8.88e-01, |grad| = 3.01e+00 (5.13e-01s)
# [TST] iter = 1740, cost = 1.40e+02, RMSE = 9.87e-01 (3.44e-01s)
# [TRN] iter = 1750, cost = 8.94e-01, |grad| = 3.13e+00 (4.71e-01s)
# [TST] iter = 1750, cost = 1.38e+02, RMSE = 9.79e-01 (3.48e-01s)
# [TRN] iter = 1760, cost = 8.81e-01, |grad| = 8.08e-01 (4.90e-01s)
# [TST] iter = 1760, cost = 1.38e+02, RMSE = 9.78e-01 (3.50e-01s)
# [TRN] iter = 1770, cost = 8.77e-01, |grad| = 7.90e-01 (4.87e-01s)
# [TST] iter = 1770, cost = 1.38e+02, RMSE = 9.75e-01 (3.69e-01s)
# [TRN] iter = 1780, cost = 8.81e-01, |grad| = 2.65e+00 (4.87e-01s)
# [TST] iter = 1780, cost = 1.39e+02, RMSE = 9.80e-01 (3.54e-01s)
# [TRN] iter = 1790, cost = 8.75e-01, |grad| = 1.27e+00 (5.42e-01s)
# [TST] iter = 1790, cost = 1.38e+02, RMSE = 9.78e-01 (3.64e-01s)
# [TRN] iter = 1800, cost = 8.78e-01, |grad| = 2.41e+00 (5.66e-01s)
# [TST] iter = 1800, cost = 1.38e+02, RMSE = 9.73e-01 (3.41e-01s)
# [TRN] iter = 1810, cost = 8.76e-01, |grad| = 2.48e+00 (5.05e-01s)
# [TST] iter = 1810, cost = 1.38e+02, RMSE = 9.78e-01 (3.38e-01s)
# [TRN] iter = 1820, cost = 8.76e-01, |grad| = 1.28e+00 (5.19e-01s)
# [TST] iter = 1820, cost = 1.38e+02, RMSE = 9.76e-01 (3.47e-01s)
# [TRN] iter = 1830, cost = 8.78e-01, |grad| = 1.13e+00 (5.33e-01s)
# [TST] iter = 1830, cost = 1.38e+02, RMSE = 9.77e-01 (3.92e-01s)
# [TRN] iter = 1840, cost = 8.80e-01, |grad| = 1.51e+00 (5.04e-01s)
# [TST] iter = 1840, cost = 1.39e+02, RMSE = 9.81e-01 (3.28e-01s)
# [TRN] iter = 1850, cost = 8.81e-01, |grad| = 2.38e+00 (4.91e-01s)
# [TST] iter = 1850, cost = 1.39e+02, RMSE = 9.81e-01 (3.55e-01s)
# [TRN] iter = 1860, cost = 8.78e-01, |grad| = 1.15e+00 (4.79e-01s)
# [TST] iter = 1860, cost = 1.38e+02, RMSE = 9.76e-01 (3.40e-01s)
# [TRN] iter = 1870, cost = 8.79e-01, |grad| = 1.78e+00 (4.98e-01s)
# [TST] iter = 1870, cost = 1.38e+02, RMSE = 9.79e-01 (3.37e-01s)
# [TRN] iter = 1880, cost = 9.11e-01, |grad| = 1.49e+00 (5.16e-01s)
# [TST] iter = 1880, cost = 1.40e+02, RMSE = 9.91e-01 (3.31e-01s)
# [TRN] iter = 1890, cost = 8.85e-01, |grad| = 1.38e+00 (4.66e-01s)
# [TST] iter = 1890, cost = 1.39e+02, RMSE = 9.81e-01 (3.31e-01s)
# [TRN] iter = 1900, cost = 8.94e-01, |grad| = 1.65e+00 (4.71e-01s)
# [TST] iter = 1900, cost = 1.39e+02, RMSE = 9.83e-01 (3.31e-01s)
# [TRN] iter = 1910, cost = 8.84e-01, |grad| = 1.53e+00 (4.73e-01s)
# [TST] iter = 1910, cost = 1.38e+02, RMSE = 9.78e-01 (3.93e-01s)
# [TRN] iter = 1920, cost = 8.74e-01, |grad| = 4.81e-01 (5.15e-01s)
# [TST] iter = 1920, cost = 1.38e+02, RMSE = 9.73e-01 (3.45e-01s)
# [TRN] iter = 1930, cost = 8.78e-01, |grad| = 1.31e+00 (4.70e-01s)
# [TST] iter = 1930, cost = 1.38e+02, RMSE = 9.75e-01 (3.27e-01s)
# [TRN] iter = 1940, cost = 8.70e-01, |grad| = 6.78e-01 (5.23e-01s)
# [TST] iter = 1940, cost = 1.37e+02, RMSE = 9.72e-01 (3.39e-01s)
# [TRN] iter = 1950, cost = 8.71e-01, |grad| = 1.52e+00 (4.96e-01s)
# [TST] iter = 1950, cost = 1.38e+02, RMSE = 9.72e-01 (3.40e-01s)
# [TRN] iter = 1960, cost = 8.71e-01, |grad| = 1.36e+00 (4.79e-01s)
# [TST] iter = 1960, cost = 1.37e+02, RMSE = 9.72e-01 (3.56e-01s)
# [TRN] iter = 1970, cost = 8.96e-01, |grad| = 1.39e+00 (4.99e-01s)
# [TST] iter = 1970, cost = 1.39e+02, RMSE = 9.85e-01 (3.56e-01s)
# [TRN] iter = 1980, cost = 8.77e-01, |grad| = 8.78e-01 (4.89e-01s)
# [TST] iter = 1980, cost = 1.38e+02, RMSE = 9.74e-01 (3.82e-01s)
# [TRN] iter = 1990, cost = 8.71e-01, |grad| = 7.04e-01 (5.97e-01s)
# [TST] iter = 1990, cost = 1.37e+02, RMSE = 9.71e-01 (3.53e-01s)
# [TRN] iter = 2000, cost = 8.72e-01, |grad| = 1.50e+00 (5.21e-01s)
# [TST] iter = 2000, cost = 1.37e+02, RMSE = 9.72e-01 (3.39e-01s)
# [TRN] iter = 2010, cost = 8.94e-01, |grad| = 2.16e+00 (4.68e-01s)
# [TST] iter = 2010, cost = 1.39e+02, RMSE = 9.80e-01 (3.30e-01s)
# [TRN] iter = 2020, cost = 8.79e-01, |grad| = 9.42e-01 (4.75e-01s)
# [TST] iter = 2020, cost = 1.38e+02, RMSE = 9.74e-01 (3.28e-01s)
# [TRN] iter = 2030, cost = 8.75e-01, |grad| = 2.16e+00 (4.58e-01s)
# [TST] iter = 2030, cost = 1.37e+02, RMSE = 9.72e-01 (3.19e-01s)
# [TRN] iter = 2040, cost = 8.68e-01, |grad| = 7.82e-01 (5.65e-01s)
# [TST] iter = 2040, cost = 1.37e+02, RMSE = 9.71e-01 (3.32e-01s)
# [TRN] iter = 2050, cost = 8.70e-01, |grad| = 1.08e+00 (5.02e-01s)
# [TST] iter = 2050, cost = 1.38e+02, RMSE = 9.74e-01 (3.23e-01s)
# [TRN] iter = 2060, cost = 8.66e-01, |grad| = 6.30e-01 (4.77e-01s)
# [TST] iter = 2060, cost = 1.37e+02, RMSE = 9.70e-01 (3.70e-01s)
# [TRN] iter = 2070, cost = 8.64e-01, |grad| = 8.51e-01 (4.97e-01s)
# [TST] iter = 2070, cost = 1.37e+02, RMSE = 9.69e-01 (3.58e-01s)
# [TRN] iter = 2080, cost = 8.69e-01, |grad| = 2.27e+00 (5.02e-01s)
# [TST] iter = 2080, cost = 1.37e+02, RMSE = 9.71e-01 (3.47e-01s)
# [TRN] iter = 2090, cost = 8.79e-01, |grad| = 2.61e+00 (5.47e-01s)
# [TST] iter = 2090, cost = 1.38e+02, RMSE = 9.74e-01 (3.46e-01s)
# [TRN] iter = 2100, cost = 9.32e-01, |grad| = 1.51e+00 (4.98e-01s)
# [TST] iter = 2100, cost = 1.41e+02, RMSE = 9.97e-01 (3.69e-01s)
# [TRN] iter = 2110, cost = 9.02e-01, |grad| = 1.16e+00 (4.92e-01s)
# [TST] iter = 2110, cost = 1.39e+02, RMSE = 9.82e-01 (3.70e-01s)
# [TRN] iter = 2120, cost = 8.80e-01, |grad| = 6.42e-01 (5.19e-01s)
# [TST] iter = 2120, cost = 1.38e+02, RMSE = 9.74e-01 (3.38e-01s)
# [TRN] iter = 2130, cost = 8.69e-01, |grad| = 2.43e+00 (5.02e-01s)
# [TST] iter = 2130, cost = 1.37e+02, RMSE = 9.71e-01 (3.64e-01s)
# [TRN] iter = 2140, cost = 8.70e-01, |grad| = 7.71e-01 (4.77e-01s)
# [TST] iter = 2140, cost = 1.37e+02, RMSE = 9.72e-01 (3.73e-01s)
# [TRN] iter = 2150, cost = 8.65e-01, |grad| = 1.11e+00 (5.17e-01s)
# [TST] iter = 2150, cost = 1.37e+02, RMSE = 9.68e-01 (3.60e-01s)
# [TRN] iter = 2160, cost = 8.61e-01, |grad| = 3.70e-01 (4.75e-01s)
# [TST] iter = 2160, cost = 1.37e+02, RMSE = 9.68e-01 (3.32e-01s)
# [TRN] iter = 2170, cost = 8.61e-01, |grad| = 6.66e-01 (5.85e-01s)
# [TST] iter = 2170, cost = 1.37e+02, RMSE = 9.67e-01 (3.30e-01s)
# [TRN] iter = 2180, cost = 8.63e-01, |grad| = 3.24e+00 (4.97e-01s)
# [TST] iter = 2180, cost = 1.37e+02, RMSE = 9.71e-01 (3.32e-01s)
# [TRN] iter = 2190, cost = 8.75e-01, |grad| = 8.94e-01 (4.85e-01s)
# [TST] iter = 2190, cost = 1.38e+02, RMSE = 9.75e-01 (3.37e-01s)
# [TRN] iter = 2200, cost = 8.76e-01, |grad| = 2.31e+00 (4.70e-01s)
# [TST] iter = 2200, cost = 1.38e+02, RMSE = 9.75e-01 (3.34e-01s)
# [TRN] iter = 2210, cost = 8.67e-01, |grad| = 1.19e+00 (4.81e-01s)
# [TST] iter = 2210, cost = 1.37e+02, RMSE = 9.71e-01 (3.42e-01s)
# [TRN] iter = 2220, cost = 8.63e-01, |grad| = 8.79e-01 (4.69e-01s)
# [TST] iter = 2220, cost = 1.37e+02, RMSE = 9.68e-01 (3.38e-01s)
# [TRN] iter = 2230, cost = 8.59e-01, |grad| = 6.03e-01 (4.92e-01s)
# [TST] iter = 2230, cost = 1.37e+02, RMSE = 9.67e-01 (3.26e-01s)
# [TRN] iter = 2240, cost = 8.56e-01, |grad| = 6.08e-01 (4.93e-01s)
# [TST] iter = 2240, cost = 1.37e+02, RMSE = 9.67e-01 (3.20e-01s)
# [TRN] iter = 2250, cost = 8.56e-01, |grad| = 6.69e-01 (4.87e-01s)
# [TST] iter = 2250, cost = 1.37e+02, RMSE = 9.66e-01 (3.32e-01s)
# [TRN] iter = 2260, cost = 8.56e-01, |grad| = 9.70e-01 (4.74e-01s)
# [TST] iter = 2260, cost = 1.37e+02, RMSE = 9.68e-01 (3.35e-01s)
# [TRN] iter = 2270, cost = 8.57e-01, |grad| = 1.08e+00 (4.78e-01s)
# [TST] iter = 2270, cost = 1.37e+02, RMSE = 9.69e-01 (3.31e-01s)
# [TRN] iter = 2280, cost = 8.62e-01, |grad| = 2.44e+00 (5.18e-01s)
# [TST] iter = 2280, cost = 1.37e+02, RMSE = 9.71e-01 (3.42e-01s)
# [TRN] iter = 2290, cost = 8.64e-01, |grad| = 1.58e+00 (4.91e-01s)
# [TST] iter = 2290, cost = 1.39e+02, RMSE = 9.80e-01 (3.65e-01s)
# [TRN] iter = 2300, cost = 8.77e-01, |grad| = 3.05e+00 (4.86e-01s)
# [TST] iter = 2300, cost = 1.38e+02, RMSE = 9.78e-01 (3.43e-01s)
# [TRN] iter = 2310, cost = 8.97e-01, |grad| = 1.74e+00 (5.41e-01s)
# [TST] iter = 2310, cost = 1.38e+02, RMSE = 9.78e-01 (3.55e-01s)
# [TRN] iter = 2320, cost = 8.85e-01, |grad| = 1.45e+00 (4.97e-01s)
# [TST] iter = 2320, cost = 1.38e+02, RMSE = 9.78e-01 (3.53e-01s)
# [TRN] iter = 2330, cost = 8.72e-01, |grad| = 1.19e+00 (4.94e-01s)
# [TST] iter = 2330, cost = 1.38e+02, RMSE = 9.73e-01 (3.48e-01s)
# [TRN] iter = 2340, cost = 8.64e-01, |grad| = 1.32e+00 (5.59e-01s)
# [TST] iter = 2340, cost = 1.37e+02, RMSE = 9.70e-01 (3.37e-01s)
# [TRN] iter = 2350, cost = 8.81e-01, |grad| = 2.15e+00 (5.44e-01s)
# [TST] iter = 2350, cost = 1.37e+02, RMSE = 9.72e-01 (3.50e-01s)
# [TRN] iter = 2360, cost = 8.65e-01, |grad| = 1.06e+00 (5.23e-01s)
# [TST] iter = 2360, cost = 1.37e+02, RMSE = 9.70e-01 (3.41e-01s)
# [TRN] iter = 2370, cost = 8.59e-01, |grad| = 5.55e-01 (4.97e-01s)
# [TST] iter = 2370, cost = 1.37e+02, RMSE = 9.67e-01 (3.47e-01s)
# [TRN] iter = 2380, cost = 8.56e-01, |grad| = 5.83e-01 (4.74e-01s)
# [TST] iter = 2380, cost = 1.37e+02, RMSE = 9.65e-01 (3.59e-01s)
# [TRN] iter = 2390, cost = 8.53e-01, |grad| = 3.43e-01 (4.88e-01s)
# [TST] iter = 2390, cost = 1.36e+02, RMSE = 9.65e-01 (3.38e-01s)
# [TRN] iter = 2400, cost = 8.53e-01, |grad| = 5.54e-01 (5.05e-01s)
# [TST] iter = 2400, cost = 1.36e+02, RMSE = 9.64e-01 (3.45e-01s)
# [TRN] iter = 2410, cost = 8.53e-01, |grad| = 1.09e+00 (4.94e-01s)
# [TST] iter = 2410, cost = 1.37e+02, RMSE = 9.66e-01 (3.41e-01s)
# [TRN] iter = 2420, cost = 8.52e-01, |grad| = 5.51e-01 (4.85e-01s)
# [TST] iter = 2420, cost = 1.36e+02, RMSE = 9.65e-01 (3.74e-01s)
# [TRN] iter = 2430, cost = 8.51e-01, |grad| = 6.61e-01 (4.87e-01s)
# [TST] iter = 2430, cost = 1.36e+02, RMSE = 9.65e-01 (3.61e-01s)
# [TRN] iter = 2440, cost = 8.51e-01, |grad| = 5.86e-01 (6.56e-01s)
# [TST] iter = 2440, cost = 1.36e+02, RMSE = 9.65e-01 (3.89e-01s)
# [TRN] iter = 2450, cost = 8.52e-01, |grad| = 8.75e-01 (5.58e-01s)
# [TST] iter = 2450, cost = 1.37e+02, RMSE = 9.65e-01 (3.79e-01s)
# [TRN] iter = 2460, cost = 8.55e-01, |grad| = 2.29e+00 (5.81e-01s)
# [TST] iter = 2460, cost = 1.37e+02, RMSE = 9.66e-01 (3.34e-01s)
# [TRN] iter = 2470, cost = 8.54e-01, |grad| = 9.22e-01 (5.21e-01s)
# [TST] iter = 2470, cost = 1.37e+02, RMSE = 9.66e-01 (3.51e-01s)
# [TRN] iter = 2480, cost = 8.62e-01, |grad| = 2.76e+00 (4.64e-01s)
# [TST] iter = 2480, cost = 1.37e+02, RMSE = 9.67e-01 (3.26e-01s)
# [TRN] iter = 2490, cost = 8.59e-01, |grad| = 1.70e+00 (5.04e-01s)
# [TST] iter = 2490, cost = 1.37e+02, RMSE = 9.70e-01 (3.43e-01s)
# [TRN] iter = 2500, cost = 8.59e-01, |grad| = 1.31e+00 (5.04e-01s)
# [TST] iter = 2500, cost = 1.37e+02, RMSE = 9.68e-01 (3.45e-01s)
# [TRN] iter = 2510, cost = 8.62e-01, |grad| = 2.93e+00 (5.84e-01s)
# [TST] iter = 2510, cost = 1.37e+02, RMSE = 9.68e-01 (4.17e-01s)
# [TRN] iter = 2520, cost = 9.61e-01, |grad| = 2.59e+00 (4.76e-01s)
# [TST] iter = 2520, cost = 1.44e+02, RMSE = 1.02e+00 (3.38e-01s)
# [TRN] iter = 2530, cost = 9.28e-01, |grad| = 1.13e+00 (4.90e-01s)
# [TST] iter = 2530, cost = 1.40e+02, RMSE = 9.93e-01 (3.33e-01s)
# [TRN] iter = 2540, cost = 8.89e-01, |grad| = 1.40e+00 (4.72e-01s)
# [TST] iter = 2540, cost = 1.38e+02, RMSE = 9.76e-01 (3.41e-01s)
# [TRN] iter = 2550, cost = 8.68e-01, |grad| = 1.86e+00 (5.10e-01s)
# [TST] iter = 2550, cost = 1.38e+02, RMSE = 9.73e-01 (3.45e-01s)
# [TRN] iter = 2560, cost = 8.98e-01, |grad| = 4.29e+00 (4.89e-01s)
# [TST] iter = 2560, cost = 1.39e+02, RMSE = 9.83e-01 (3.28e-01s)
# [TRN] iter = 2570, cost = 8.71e-01, |grad| = 1.37e+00 (4.83e-01s)
# [TST] iter = 2570, cost = 1.37e+02, RMSE = 9.69e-01 (3.48e-01s)
# [TRN] iter = 2580, cost = 8.61e-01, |grad| = 9.11e-01 (5.06e-01s)
# [TST] iter = 2580, cost = 1.37e+02, RMSE = 9.67e-01 (3.56e-01s)
# [TRN] iter = 2590, cost = 8.54e-01, |grad| = 6.34e-01 (5.00e-01s)
# [TST] iter = 2590, cost = 1.37e+02, RMSE = 9.65e-01 (3.41e-01s)
# [TRN] iter = 2600, cost = 8.51e-01, |grad| = 6.47e-01 (4.89e-01s)
# [TST] iter = 2600, cost = 1.36e+02, RMSE = 9.64e-01 (3.45e-01s)
# [TRN] iter = 2610, cost = 8.48e-01, |grad| = 2.79e-01 (4.78e-01s)
# [TST] iter = 2610, cost = 1.36e+02, RMSE = 9.63e-01 (3.52e-01s)
# [TRN] iter = 2620, cost = 8.47e-01, |grad| = 4.70e-01 (4.95e-01s)
# [TST] iter = 2620, cost = 1.36e+02, RMSE = 9.62e-01 (3.40e-01s)
# [TRN] iter = 2630, cost = 8.64e-01, |grad| = 1.46e+00 (5.21e-01s)
# [TST] iter = 2630, cost = 1.37e+02, RMSE = 9.70e-01 (3.63e-01s)
# [TRN] iter = 2640, cost = 8.72e-01, |grad| = 2.10e+00 (5.37e-01s)
# [TST] iter = 2640, cost = 1.37e+02, RMSE = 9.70e-01 (3.65e-01s)
# [TRN] iter = 2650, cost = 8.95e-01, |grad| = 2.42e+00 (5.73e-01s)
# [TST] iter = 2650, cost = 1.38e+02, RMSE = 9.77e-01 (3.96e-01s)
# [TRN] iter = 2660, cost = 8.70e-01, |grad| = 1.17e+00 (4.96e-01s)
# [TST] iter = 2660, cost = 1.37e+02, RMSE = 9.71e-01 (3.52e-01s)
# [TRN] iter = 2670, cost = 8.61e-01, |grad| = 1.21e+00 (5.27e-01s)
# [TST] iter = 2670, cost = 1.37e+02, RMSE = 9.70e-01 (3.52e-01s)
# [TRN] iter = 2680, cost = 8.57e-01, |grad| = 1.43e+00 (4.69e-01s)
# [TST] iter = 2680, cost = 1.36e+02, RMSE = 9.65e-01 (3.48e-01s)
# [TRN] iter = 2690, cost = 8.55e-01, |grad| = 2.00e+00 (4.89e-01s)
# [TST] iter = 2690, cost = 1.36e+02, RMSE = 9.64e-01 (3.34e-01s)
# [TRN] iter = 2700, cost = 8.63e-01, |grad| = 1.23e+00 (5.21e-01s)
# [TST] iter = 2700, cost = 1.37e+02, RMSE = 9.68e-01 (3.33e-01s)
# [TRN] iter = 2710, cost = 8.62e-01, |grad| = 2.39e+00 (4.77e-01s)
# [TST] iter = 2710, cost = 1.37e+02, RMSE = 9.69e-01 (3.60e-01s)
# [TRN] iter = 2720, cost = 8.57e-01, |grad| = 1.15e+00 (4.86e-01s)
# [TST] iter = 2720, cost = 1.36e+02, RMSE = 9.65e-01 (3.51e-01s)
# [TRN] iter = 2730, cost = 8.54e-01, |grad| = 1.23e+00 (5.09e-01s)
# [TST] iter = 2730, cost = 1.36e+02, RMSE = 9.64e-01 (3.44e-01s)
# [TRN] iter = 2740, cost = 8.52e-01, |grad| = 1.16e+00 (4.78e-01s)
# [TST] iter = 2740, cost = 1.36e+02, RMSE = 9.64e-01 (3.56e-01s)
# [TRN] iter = 2750, cost = 8.53e-01, |grad| = 9.87e-01 (5.12e-01s)
# [TST] iter = 2750, cost = 1.36e+02, RMSE = 9.63e-01 (3.60e-01s)
# [TRN] iter = 2760, cost = 8.49e-01, |grad| = 1.98e+00 (5.00e-01s)
# [TST] iter = 2760, cost = 1.36e+02, RMSE = 9.64e-01 (3.56e-01s)
# [TRN] iter = 2770, cost = 8.47e-01, |grad| = 5.11e-01 (4.97e-01s)
# [TST] iter = 2770, cost = 1.36e+02, RMSE = 9.62e-01 (3.70e-01s)
# [TRN] iter = 2780, cost = 8.45e-01, |grad| = 8.99e-01 (5.48e-01s)
# [TST] iter = 2780, cost = 1.36e+02, RMSE = 9.62e-01 (3.55e-01s)
# [TRN] iter = 2790, cost = 8.46e-01, |grad| = 9.68e-01 (4.94e-01s)
# [TST] iter = 2790, cost = 1.36e+02, RMSE = 9.62e-01 (3.72e-01s)
# [TRN] iter = 2800, cost = 8.43e-01, |grad| = 6.55e-01 (5.02e-01s)
# [TST] iter = 2800, cost = 1.36e+02, RMSE = 9.61e-01 (3.36e-01s)
# [TRN] iter = 2810, cost = 8.50e-01, |grad| = 2.02e+00 (4.72e-01s)
# [TST] iter = 2810, cost = 1.36e+02, RMSE = 9.63e-01 (3.49e-01s)
# [TRN] iter = 2820, cost = 8.46e-01, |grad| = 1.03e+00 (5.17e-01s)
# [TST] iter = 2820, cost = 1.36e+02, RMSE = 9.61e-01 (3.49e-01s)
# [TRN] iter = 2830, cost = 8.47e-01, |grad| = 1.11e+00 (5.10e-01s)
# [TST] iter = 2830, cost = 1.36e+02, RMSE = 9.62e-01 (3.38e-01s)
# [TRN] iter = 2840, cost = 8.49e-01, |grad| = 1.17e+00 (5.62e-01s)
# [TST] iter = 2840, cost = 1.37e+02, RMSE = 9.69e-01 (3.95e-01s)
# [TRN] iter = 2850, cost = 8.54e-01, |grad| = 1.32e+00 (5.08e-01s)
# [TST] iter = 2850, cost = 1.37e+02, RMSE = 9.67e-01 (3.38e-01s)
# [TRN] iter = 2860, cost = 8.61e-01, |grad| = 1.71e+00 (4.92e-01s)
# [TST] iter = 2860, cost = 1.37e+02, RMSE = 9.67e-01 (3.53e-01s)
# [TRN] iter = 2870, cost = 8.60e-01, |grad| = 3.94e+00 (5.01e-01s)
# [TST] iter = 2870, cost = 1.37e+02, RMSE = 9.70e-01 (3.56e-01s)
# [TRN] iter = 2880, cost = 8.56e-01, |grad| = 1.74e+00 (5.10e-01s)
# [TST] iter = 2880, cost = 1.37e+02, RMSE = 9.72e-01 (3.41e-01s)
# [TRN] iter = 2890, cost = 8.57e-01, |grad| = 1.75e+00 (5.32e-01s)
# [TST] iter = 2890, cost = 1.37e+02, RMSE = 9.66e-01 (4.12e-01s)
# [TRN] iter = 2900, cost = 8.83e-01, |grad| = 1.58e+00 (4.95e-01s)
# [TST] iter = 2900, cost = 1.38e+02, RMSE = 9.74e-01 (3.40e-01s)
# [TRN] iter = 2910, cost = 8.66e-01, |grad| = 2.56e+00 (5.56e-01s)
# [TST] iter = 2910, cost = 1.38e+02, RMSE = 9.72e-01 (3.46e-01s)
# [TRN] iter = 2920, cost = 8.58e-01, |grad| = 1.60e+00 (4.95e-01s)
# [TST] iter = 2920, cost = 1.36e+02, RMSE = 9.63e-01 (3.53e-01s)
# [TRN] iter = 2930, cost = 8.54e-01, |grad| = 1.74e+00 (4.91e-01s)
# [TST] iter = 2930, cost = 1.36e+02, RMSE = 9.64e-01 (3.44e-01s)
# [TRN] iter = 2940, cost = 8.56e-01, |grad| = 3.36e+00 (4.95e-01s)
# [TST] iter = 2940, cost = 1.36e+02, RMSE = 9.64e-01 (3.64e-01s)
# [TRN] iter = 2950, cost = 8.57e-01, |grad| = 2.02e+00 (5.09e-01s)
# [TST] iter = 2950, cost = 1.36e+02, RMSE = 9.65e-01 (3.64e-01s)
# [TRN] iter = 2960, cost = 8.48e-01, |grad| = 1.58e+00 (5.36e-01s)
# [TST] iter = 2960, cost = 1.36e+02, RMSE = 9.62e-01 (3.48e-01s)
# [TRN] iter = 2970, cost = 8.50e-01, |grad| = 1.12e+00 (5.99e-01s)
# [TST] iter = 2970, cost = 1.36e+02, RMSE = 9.64e-01 (4.01e-01s)
# [TRN] iter = 2980, cost = 8.48e-01, |grad| = 1.37e+00 (4.80e-01s)
# [TST] iter = 2980, cost = 1.36e+02, RMSE = 9.60e-01 (3.40e-01s)
# [TRN] iter = 2990, cost = 8.45e-01, |grad| = 9.86e-01 (5.13e-01s)
# [TST] iter = 2990, cost = 1.36e+02, RMSE = 9.61e-01 (4.39e-01s)
# [TRN] iter = 3000, cost = 8.45e-01, |grad| = 1.00e+00 (6.04e-01s)
# [TST] iter = 3000, cost = 1.36e+02, RMSE = 9.60e-01 (3.99e-01s)
# [TRN] iter = 3010, cost = 8.42e-01, |grad| = 9.48e-01 (5.06e-01s)
# [TST] iter = 3010, cost = 1.36e+02, RMSE = 9.59e-01 (3.89e-01s)
# [TRN] iter = 3020, cost = 8.44e-01, |grad| = 1.00e+00 (5.04e-01s)
# [TST] iter = 3020, cost = 1.36e+02, RMSE = 9.61e-01 (3.35e-01s)
# [TRN] iter = 3030, cost = 8.40e-01, |grad| = 6.42e-01 (5.85e-01s)
# [TST] iter = 3030, cost = 1.36e+02, RMSE = 9.59e-01 (3.96e-01s)
# [TRN] iter = 3040, cost = 8.39e-01, |grad| = 4.55e-01 (5.11e-01s)
# [TST] iter = 3040, cost = 1.36e+02, RMSE = 9.59e-01 (3.30e-01s)
# [TRN] iter = 3050, cost = 8.38e-01, |grad| = 7.02e-01 (5.11e-01s)
# [TST] iter = 3050, cost = 1.35e+02, RMSE = 9.58e-01 (4.08e-01s)
# [TRN] iter = 3060, cost = 8.36e-01, |grad| = 4.07e-01 (5.20e-01s)
# [TST] iter = 3060, cost = 1.35e+02, RMSE = 9.58e-01 (3.52e-01s)
# [TRN] iter = 3070, cost = 8.36e-01, |grad| = 4.84e-01 (5.43e-01s)
# [TST] iter = 3070, cost = 1.36e+02, RMSE = 9.58e-01 (3.51e-01s)
# [TRN] iter = 3080, cost = 8.36e-01, |grad| = 8.10e-01 (6.30e-01s)
# [TST] iter = 3080, cost = 1.35e+02, RMSE = 9.58e-01 (3.77e-01s)
# [TRN] iter = 3090, cost = 8.38e-01, |grad| = 6.45e-01 (5.06e-01s)
# [TST] iter = 3090, cost = 1.36e+02, RMSE = 9.59e-01 (3.56e-01s)
# [TRN] iter = 3100, cost = 8.39e-01, |grad| = 9.30e-01 (5.07e-01s)
# [TST] iter = 3100, cost = 1.36e+02, RMSE = 9.60e-01 (3.53e-01s)
# [TRN] iter = 3110, cost = 8.40e-01, |grad| = 9.64e-01 (5.30e-01s)
# [TST] iter = 3110, cost = 1.36e+02, RMSE = 9.60e-01 (3.72e-01s)
# [TRN] iter = 3120, cost = 8.44e-01, |grad| = 9.59e-01 (5.46e-01s)
# [TST] iter = 3120, cost = 1.36e+02, RMSE = 9.63e-01 (3.53e-01s)
# [TRN] iter = 3130, cost = 8.46e-01, |grad| = 1.80e+00 (5.25e-01s)
# [TST] iter = 3130, cost = 1.36e+02, RMSE = 9.62e-01 (3.89e-01s)
# [TRN] iter = 3140, cost = 8.43e-01, |grad| = 2.05e+00 (5.13e-01s)
# [TST] iter = 3140, cost = 1.36e+02, RMSE = 9.59e-01 (3.87e-01s)
# [TRN] iter = 3150, cost = 8.39e-01, |grad| = 6.04e-01 (5.30e-01s)
# [TST] iter = 3150, cost = 1.36e+02, RMSE = 9.59e-01 (3.50e-01s)
# [TRN] iter = 3160, cost = 8.44e-01, |grad| = 2.59e+00 (4.92e-01s)
# [TST] iter = 3160, cost = 1.36e+02, RMSE = 9.59e-01 (3.43e-01s)
# [TRN] iter = 3170, cost = 8.42e-01, |grad| = 1.08e+00 (4.70e-01s)
# [TST] iter = 3170, cost = 1.36e+02, RMSE = 9.60e-01 (3.47e-01s)
# [TRN] iter = 3180, cost = 8.66e-01, |grad| = 2.36e+00 (4.76e-01s)
# [TST] iter = 3180, cost = 1.37e+02, RMSE = 9.67e-01 (3.30e-01s)
# [TRN] iter = 3190, cost = 8.57e-01, |grad| = 2.27e+00 (4.83e-01s)
# [TST] iter = 3190, cost = 1.37e+02, RMSE = 9.66e-01 (3.49e-01s)
# [TRN] iter = 3200, cost = 8.69e-01, |grad| = 4.23e+00 (4.88e-01s)
# [TST] iter = 3200, cost = 1.37e+02, RMSE = 9.67e-01 (3.41e-01s)
# [TRN] iter = 3210, cost = 8.56e-01, |grad| = 1.28e+00 (5.16e-01s)
# [TST] iter = 3210, cost = 1.36e+02, RMSE = 9.65e-01 (3.53e-01s)
# [TRN] iter = 3220, cost = 8.60e-01, |grad| = 1.93e+00 (4.93e-01s)
# [TST] iter = 3220, cost = 1.37e+02, RMSE = 9.69e-01 (3.45e-01s)
# [TRN] iter = 3230, cost = 8.55e-01, |grad| = 1.32e+00 (4.84e-01s)
# [TST] iter = 3230, cost = 1.37e+02, RMSE = 9.68e-01 (4.47e-01s)
# [TRN] iter = 3240, cost = 8.49e-01, |grad| = 1.32e+00 (4.75e-01s)
# [TST] iter = 3240, cost = 1.36e+02, RMSE = 9.64e-01 (3.42e-01s)
# [TRN] iter = 3250, cost = 8.49e-01, |grad| = 1.54e+00 (4.90e-01s)
# [TST] iter = 3250, cost = 1.36e+02, RMSE = 9.60e-01 (3.38e-01s)
# [TRN] iter = 3260, cost = 8.42e-01, |grad| = 1.34e+00 (5.43e-01s)
# [TST] iter = 3260, cost = 1.36e+02, RMSE = 9.58e-01 (3.61e-01s)
# [TRN] iter = 3270, cost = 8.38e-01, |grad| = 6.43e-01 (4.94e-01s)
# [TST] iter = 3270, cost = 1.35e+02, RMSE = 9.56e-01 (3.43e-01s)
# [TRN] iter = 3280, cost = 8.35e-01, |grad| = 6.51e-01 (4.80e-01s)
# [TST] iter = 3280, cost = 1.35e+02, RMSE = 9.56e-01 (3.40e-01s)
# [TRN] iter = 3290, cost = 8.34e-01, |grad| = 6.41e-01 (5.70e-01s)
# [TST] iter = 3290, cost = 1.35e+02, RMSE = 9.56e-01 (3.53e-01s)
# [TRN] iter = 3300, cost = 8.57e-01, |grad| = 2.57e+00 (5.05e-01s)
# [TST] iter = 3300, cost = 1.37e+02, RMSE = 9.68e-01 (3.67e-01s)
# [TRN] iter = 3310, cost = 8.48e-01, |grad| = 1.51e+00 (4.94e-01s)
# [TST] iter = 3310, cost = 1.36e+02, RMSE = 9.60e-01 (3.67e-01s)
# [TRN] iter = 3320, cost = 8.45e-01, |grad| = 1.02e+00 (4.89e-01s)
# [TST] iter = 3320, cost = 1.36e+02, RMSE = 9.60e-01 (3.56e-01s)
# [TRN] iter = 3330, cost = 8.49e-01, |grad| = 1.94e+00 (4.75e-01s)
# [TST] iter = 3330, cost = 1.36e+02, RMSE = 9.59e-01 (3.61e-01s)
# [TRN] iter = 3340, cost = 8.42e-01, |grad| = 1.49e+00 (4.94e-01s)
# [TST] iter = 3340, cost = 1.36e+02, RMSE = 9.59e-01 (3.54e-01s)
# [TRN] iter = 3350, cost = 8.38e-01, |grad| = 6.96e-01 (5.00e-01s)
# [TST] iter = 3350, cost = 1.35e+02, RMSE = 9.57e-01 (3.49e-01s)
# [TRN] iter = 3360, cost = 8.34e-01, |grad| = 7.44e-01 (4.77e-01s)
# [TST] iter = 3360, cost = 1.35e+02, RMSE = 9.58e-01 (3.63e-01s)
# [TRN] iter = 3370, cost = 8.38e-01, |grad| = 1.45e+00 (4.83e-01s)
# [TST] iter = 3370, cost = 1.36e+02, RMSE = 9.60e-01 (3.44e-01s)
# [TRN] iter = 3380, cost = 8.39e-01, |grad| = 2.93e+00 (4.84e-01s)
# [TST] iter = 3380, cost = 1.35e+02, RMSE = 9.57e-01 (3.51e-01s)
# [TRN] iter = 3390, cost = 8.39e-01, |grad| = 1.44e+00 (4.83e-01s)
# [TST] iter = 3390, cost = 1.36e+02, RMSE = 9.60e-01 (3.43e-01s)
# [TRN] iter = 3400, cost = 8.35e-01, |grad| = 8.95e-01 (4.82e-01s)
# [TST] iter = 3400, cost = 1.35e+02, RMSE = 9.57e-01 (3.55e-01s)
# [TRN] iter = 3410, cost = 8.36e-01, |grad| = 1.07e+00 (4.91e-01s)
# [TST] iter = 3410, cost = 1.36e+02, RMSE = 9.59e-01 (3.46e-01s)
# [TRN] iter = 3420, cost = 8.37e-01, |grad| = 1.59e+00 (4.96e-01s)
# [TST] iter = 3420, cost = 1.35e+02, RMSE = 9.57e-01 (3.63e-01s)
# [TRN] iter = 3430, cost = 8.35e-01, |grad| = 9.61e-01 (5.64e-01s)
# [TST] iter = 3430, cost = 1.35e+02, RMSE = 9.57e-01 (4.44e-01s)
# [TRN] iter = 3440, cost = 8.36e-01, |grad| = 9.34e-01 (9.16e-01s)
# [TST] iter = 3440, cost = 1.35e+02, RMSE = 9.57e-01 (4.06e-01s)
# [TRN] iter = 3450, cost = 8.39e-01, |grad| = 1.44e+00 (5.45e-01s)
# [TST] iter = 3450, cost = 1.35e+02, RMSE = 9.56e-01 (3.99e-01s)
# [TRN] iter = 3460, cost = 8.49e-01, |grad| = 1.39e+00 (5.68e-01s)
# [TST] iter = 3460, cost = 1.36e+02, RMSE = 9.63e-01 (3.68e-01s)
# [TRN] iter = 3470, cost = 9.05e-01, |grad| = 2.30e+00 (4.92e-01s)
# [TST] iter = 3470, cost = 1.40e+02, RMSE = 9.87e-01 (3.63e-01s)
# [TRN] iter = 3480, cost = 8.99e-01, |grad| = 6.47e+00 (4.88e-01s)
# [TST] iter = 3480, cost = 1.42e+02, RMSE = 1.01e+00 (3.52e-01s)
# [TRN] iter = 3490, cost = 8.80e-01, |grad| = 1.56e+00 (5.11e-01s)
# [TST] iter = 3490, cost = 1.37e+02, RMSE = 9.72e-01 (3.56e-01s)
# [TRN] iter = 3500, cost = 8.55e-01, |grad| = 9.06e-01 (5.05e-01s)
# [TST] iter = 3500, cost = 1.36e+02, RMSE = 9.61e-01 (3.53e-01s)
# [TRN] iter = 3510, cost = 8.45e-01, |grad| = 1.45e+00 (5.38e-01s)
# [TST] iter = 3510, cost = 1.36e+02, RMSE = 9.59e-01 (3.83e-01s)
# [TRN] iter = 3520, cost = 8.39e-01, |grad| = 1.00e+00 (4.89e-01s)
# [TST] iter = 3520, cost = 1.35e+02, RMSE = 9.56e-01 (3.54e-01s)
# [TRN] iter = 3530, cost = 8.49e-01, |grad| = 4.25e+00 (5.24e-01s)
# [TST] iter = 3530, cost = 1.36e+02, RMSE = 9.59e-01 (3.61e-01s)
# [TRN] iter = 3540, cost = 8.44e-01, |grad| = 3.02e+00 (6.17e-01s)
# [TST] iter = 3540, cost = 1.36e+02, RMSE = 9.58e-01 (3.62e-01s)
# [TRN] iter = 3550, cost = 8.39e-01, |grad| = 1.44e+00 (6.44e-01s)
# [TST] iter = 3550, cost = 1.35e+02, RMSE = 9.56e-01 (3.81e-01s)
# [TRN] iter = 3560, cost = 8.33e-01, |grad| = 4.81e-01 (5.18e-01s)
# [TST] iter = 3560, cost = 1.35e+02, RMSE = 9.55e-01 (3.63e-01s)
# [TRN] iter = 3570, cost = 8.31e-01, |grad| = 1.10e+00 (5.01e-01s)
# [TST] iter = 3570, cost = 1.35e+02, RMSE = 9.54e-01 (3.65e-01s)
# [TRN] iter = 3580, cost = 8.49e-01, |grad| = 1.83e+00 (5.12e-01s)
# [TST] iter = 3580, cost = 1.37e+02, RMSE = 9.65e-01 (3.52e-01s)
# [TRN] iter = 3590, cost = 8.50e-01, |grad| = 1.22e+00 (5.22e-01s)
# [TST] iter = 3590, cost = 1.36e+02, RMSE = 9.61e-01 (3.65e-01s)
# [TRN] iter = 3600, cost = 8.39e-01, |grad| = 1.11e+00 (5.17e-01s)
# [TST] iter = 3600, cost = 1.35e+02, RMSE = 9.56e-01 (3.68e-01s)
# [TRN] iter = 3610, cost = 8.35e-01, |grad| = 1.07e+00 (5.03e-01s)
# [TST] iter = 3610, cost = 1.35e+02, RMSE = 9.55e-01 (3.52e-01s)
# [TRN] iter = 3620, cost = 8.32e-01, |grad| = 1.14e+00 (4.88e-01s)
# [TST] iter = 3620, cost = 1.35e+02, RMSE = 9.56e-01 (3.64e-01s)
# [TRN] iter = 3630, cost = 8.39e-01, |grad| = 2.40e+00 (4.72e-01s)
# [TST] iter = 3630, cost = 1.35e+02, RMSE = 9.57e-01 (3.33e-01s)
# [TRN] iter = 3640, cost = 8.37e-01, |grad| = 1.26e+00 (4.72e-01s)
# [TST] iter = 3640, cost = 1.35e+02, RMSE = 9.55e-01 (3.39e-01s)
# [TRN] iter = 3650, cost = 8.33e-01, |grad| = 8.35e-01 (4.94e-01s)
# [TST] iter = 3650, cost = 1.35e+02, RMSE = 9.54e-01 (3.46e-01s)
# [TRN] iter = 3660, cost = 8.32e-01, |grad| = 1.18e+00 (5.01e-01s)
# [TST] iter = 3660, cost = 1.35e+02, RMSE = 9.55e-01 (3.61e-01s)
# [TRN] iter = 3670, cost = 8.42e-01, |grad| = 1.41e+00 (4.88e-01s)
# [TST] iter = 3670, cost = 1.36e+02, RMSE = 9.59e-01 (3.49e-01s)
# [TRN] iter = 3680, cost = 8.41e-01, |grad| = 1.64e+00 (4.89e-01s)
# [TST] iter = 3680, cost = 1.35e+02, RMSE = 9.58e-01 (3.78e-01s)
# [TRN] iter = 3690, cost = 8.39e-01, |grad| = 8.69e-01 (4.90e-01s)
# [TST] iter = 3690, cost = 1.35e+02, RMSE = 9.55e-01 (3.50e-01s)
# [TRN] iter = 3700, cost = 9.72e-01, |grad| = 2.28e+00 (5.17e-01s)
# ...
# [TRN] iter = 7270, cost = 8.33e-01, |grad| = 4.28e+00 (4.59e-01s)
# [TST] iter = 7270, cost = 1.34e+02, RMSE = 9.47e-01 (3.20e-01s)
# [TRN] iter = 7280, cost = 8.11e-01, |grad| = 1.00e+00 (4.69e-01s)
# [TST] iter = 7280, cost = 1.33e+02, RMSE = 9.44e-01 (3.18e-01s)
# [TRN] iter = 7290, cost = 8.02e-01, |grad| = 1.27e+00 (4.62e-01s)
# [TST] iter = 7290, cost = 1.33e+02, RMSE = 9.40e-01 (3.21e-01s)
# [TRN] iter = 7300, cost = 7.96e-01, |grad| = 1.32e+00 (4.54e-01s)
# [TST] iter = 7300, cost = 1.33e+02, RMSE = 9.39e-01 (3.13e-01s)
# [TRN] iter = 7310, cost = 7.93e-01, |grad| = 1.02e+00 (4.53e-01s)
# [TST] iter = 7310, cost = 1.33e+02, RMSE = 9.39e-01 (3.15e-01s)
# [TRN] iter = 7320, cost = 7.93e-01, |grad| = 1.32e+00 (4.62e-01s)
# [TST] iter = 7320, cost = 1.33e+02, RMSE = 9.39e-01 (3.15e-01s)
# [TRN] iter = 7330, cost = 7.91e-01, |grad| = 1.28e+00 (4.56e-01s)
# [TST] iter = 7330, cost = 1.33e+02, RMSE = 9.37e-01 (3.17e-01s)
# [TRN] iter = 7340, cost = 7.90e-01, |grad| = 7.40e-01 (4.51e-01s)
# [TST] iter = 7340, cost = 1.33e+02, RMSE = 9.37e-01 (3.24e-01s)
# [TRN] iter = 7350, cost = 7.89e-01, |grad| = 5.58e-01 (4.79e-01s)
# [TST] iter = 7350, cost = 1.33e+02, RMSE = 9.37e-01 (3.28e-01s)
# [TRN] iter = 7360, cost = 7.92e-01, |grad| = 3.03e+00 (4.57e-01s)
# [TST] iter = 7360, cost = 1.33e+02, RMSE = 9.37e-01 (3.16e-01s)
# [TRN] iter = 7370, cost = 7.93e-01, |grad| = 7.89e-01 (4.55e-01s)
# [TST] iter = 7370, cost = 1.33e+02, RMSE = 9.39e-01 (3.18e-01s)
# [TRN] iter = 7380, cost = 7.91e-01, |grad| = 1.27e+00 (4.52e-01s)
# [TST] iter = 7380, cost = 1.33e+02, RMSE = 9.38e-01 (3.18e-01s)
# [TRN] iter = 7390, cost = 7.90e-01, |grad| = 9.38e-01 (4.56e-01s)
# [TST] iter = 7390, cost = 1.33e+02, RMSE = 9.38e-01 (3.11e-01s)
# [TRN] iter = 7400, cost = 7.93e-01, |grad| = 1.77e+00 (4.57e-01s)
# [TST] iter = 7400, cost = 1.33e+02, RMSE = 9.39e-01 (3.26e-01s)
# [TRN] iter = 7410, cost = 7.92e-01, |grad| = 1.15e+00 (4.66e-01s)
# [TST] iter = 7410, cost = 1.33e+02, RMSE = 9.37e-01 (3.24e-01s)
# [TRN] iter = 7420, cost = 7.90e-01, |grad| = 1.53e+00 (4.52e-01s)
# [TST] iter = 7420, cost = 1.33e+02, RMSE = 9.37e-01 (3.15e-01s)
# [TRN] iter = 7430, cost = 7.89e-01, |grad| = 1.86e+00 (4.50e-01s)
# [TST] iter = 7430, cost = 1.33e+02, RMSE = 9.37e-01 (3.16e-01s)
# [TRN] iter = 7440, cost = 7.89e-01, |grad| = 8.77e-01 (4.50e-01s)
# [TST] iter = 7440, cost = 1.32e+02, RMSE = 9.36e-01 (3.23e-01s)
# [TRN] iter = 7450, cost = 7.88e-01, |grad| = 7.22e-01 (4.72e-01s)
# [TST] iter = 7450, cost = 1.32e+02, RMSE = 9.36e-01 (3.13e-01s)
# [TRN] iter = 7460, cost = 7.89e-01, |grad| = 9.88e-01 (4.52e-01s)
# [TST] iter = 7460, cost = 1.32e+02, RMSE = 9.37e-01 (3.17e-01s)
# [TRN] iter = 7470, cost = 7.89e-01, |grad| = 7.81e-01 (4.65e-01s)
# [TST] iter = 7470, cost = 1.32e+02, RMSE = 9.37e-01 (3.17e-01s)
# [TRN] iter = 7480, cost = 7.93e-01, |grad| = 9.73e-01 (4.66e-01s)
# [TST] iter = 7480, cost = 1.33e+02, RMSE = 9.38e-01 (3.22e-01s)
# [TRN] iter = 7490, cost = 7.91e-01, |grad| = 1.22e+00 (4.68e-01s)
# [TST] iter = 7490, cost = 1.33e+02, RMSE = 9.38e-01 (3.18e-01s)
# [TRN] iter = 7500, cost = 7.90e-01, |grad| = 1.68e+00 (4.56e-01s)
# [TST] iter = 7500, cost = 1.32e+02, RMSE = 9.36e-01 (3.17e-01s)
# [TRN] iter = 7510, cost = 7.90e-01, |grad| = 9.54e-01 (4.57e-01s)
# [TST] iter = 7510, cost = 1.32e+02, RMSE = 9.36e-01 (3.25e-01s)
# [TRN] iter = 7520, cost = 7.95e-01, |grad| = 3.02e+00 (4.51e-01s)
# [TST] iter = 7520, cost = 1.33e+02, RMSE = 9.37e-01 (2.97e-01s)
# [TRN] iter = 7530, cost = 8.02e-01, |grad| = 3.45e+00 (4.43e-01s)
# [TST] iter = 7530, cost = 1.34e+02, RMSE = 9.49e-01 (3.06e-01s)
# [TRN] iter = 7540, cost = 8.15e-01, |grad| = 1.59e+00 (4.61e-01s)
# [TST] iter = 7540, cost = 1.34e+02, RMSE = 9.49e-01 (3.09e-01s)
# [TRN] iter = 7550, cost = 7.99e-01, |grad| = 8.08e-01 (4.51e-01s)
# [TST] iter = 7550, cost = 1.33e+02, RMSE = 9.41e-01 (3.17e-01s)
# [TRN] iter = 7560, cost = 7.98e-01, |grad| = 1.09e+00 (4.58e-01s)
# [TST] iter = 7560, cost = 1.33e+02, RMSE = 9.40e-01 (3.17e-01s)
# [TRN] iter = 7570, cost = 7.92e-01, |grad| = 9.51e-01 (4.60e-01s)
# [TST] iter = 7570, cost = 1.33e+02, RMSE = 9.38e-01 (3.18e-01s)
# [TRN] iter = 7580, cost = 7.90e-01, |grad| = 1.02e+00 (4.66e-01s)
# [TST] iter = 7580, cost = 1.32e+02, RMSE = 9.36e-01 (3.16e-01s)
# [TRN] iter = 7590, cost = 7.88e-01, |grad| = 1.22e+00 (4.66e-01s)
# [TST] iter = 7590, cost = 1.32e+02, RMSE = 9.37e-01 (3.22e-01s)
# [TRN] iter = 7600, cost = 7.90e-01, |grad| = 1.14e+00 (4.56e-01s)
# [TST] iter = 7600, cost = 1.33e+02, RMSE = 9.39e-01 (3.24e-01s)
# [TRN] iter = 7610, cost = 7.93e-01, |grad| = 9.06e-01 (4.63e-01s)
# [TST] iter = 7610, cost = 1.32e+02, RMSE = 9.37e-01 (3.37e-01s)
# [TRN] iter = 7620, cost = 7.89e-01, |grad| = 8.10e-01 (4.62e-01s)
# [TST] iter = 7620, cost = 1.32e+02, RMSE = 9.36e-01 (3.38e-01s)
# [TRN] iter = 7630, cost = 7.87e-01, |grad| = 6.89e-01 (4.66e-01s)
# [TST] iter = 7630, cost = 1.32e+02, RMSE = 9.36e-01 (3.26e-01s)
# [TRN] iter = 7640, cost = 7.95e-01, |grad| = 1.89e+00 (4.62e-01s)
# [TST] iter = 7640, cost = 1.33e+02, RMSE = 9.40e-01 (3.32e-01s)
# [TRN] iter = 7650, cost = 8.06e-01, |grad| = 2.06e+00 (4.68e-01s)
# [TST] iter = 7650, cost = 1.34e+02, RMSE = 9.47e-01 (3.20e-01s)
# [TRN] iter = 7660, cost = 8.05e-01, |grad| = 1.32e+00 (4.72e-01s)
# [TST] iter = 7660, cost = 1.33e+02, RMSE = 9.44e-01 (3.15e-01s)
# [TRN] iter = 7670, cost = 8.18e-01, |grad| = 3.06e+00 (4.47e-01s)
# [TST] iter = 7670, cost = 1.34e+02, RMSE = 9.47e-01 (3.22e-01s)
# [TRN] iter = 7680, cost = 8.22e-01, |grad| = 1.67e+00 (4.58e-01s)
# [TST] iter = 7680, cost = 1.34e+02, RMSE = 9.50e-01 (3.19e-01s)
# [TRN] iter = 7690, cost = 8.11e-01, |grad| = 2.84e+00 (4.55e-01s)
# [TST] iter = 7690, cost = 1.34e+02, RMSE = 9.46e-01 (3.24e-01s)
# [TRN] iter = 7700, cost = 8.03e-01, |grad| = 1.87e+00 (4.59e-01s)
# [TST] iter = 7700, cost = 1.33e+02, RMSE = 9.43e-01 (3.17e-01s)
# [TRN] iter = 7710, cost = 7.99e-01, |grad| = 2.14e+00 (4.50e-01s)
# [TST] iter = 7710, cost = 1.33e+02, RMSE = 9.41e-01 (3.21e-01s)
# [TRN] iter = 7720, cost = 7.94e-01, |grad| = 9.72e-01 (4.52e-01s)
# [TST] iter = 7720, cost = 1.33e+02, RMSE = 9.38e-01 (3.20e-01s)
# [TRN] iter = 7730, cost = 7.90e-01, |grad| = 8.07e-01 (4.62e-01s)
# [TST] iter = 7730, cost = 1.33e+02, RMSE = 9.37e-01 (3.11e-01s)
# [TRN] iter = 7740, cost = 7.90e-01, |grad| = 1.29e+00 (4.53e-01s)
# [TST] iter = 7740, cost = 1.33e+02, RMSE = 9.38e-01 (3.24e-01s)
# [TRN] iter = 7750, cost = 7.89e-01, |grad| = 5.25e-01 (4.52e-01s)
# [TST] iter = 7750, cost = 1.33e+02, RMSE = 9.37e-01 (3.16e-01s)
# [TRN] iter = 7760, cost = 7.88e-01, |grad| = 1.69e+00 (4.83e-01s)
# [TST] iter = 7760, cost = 1.32e+02, RMSE = 9.36e-01 (3.28e-01s)
# [TRN] iter = 7770, cost = 7.88e-01, |grad| = 9.94e-01 (4.64e-01s)
# [TST] iter = 7770, cost = 1.33e+02, RMSE = 9.37e-01 (3.14e-01s)
# [TRN] iter = 7780, cost = 7.89e-01, |grad| = 1.17e+00 (4.67e-01s)
# [TST] iter = 7780, cost = 1.33e+02, RMSE = 9.37e-01 (3.17e-01s)
# [TRN] iter = 7790, cost = 7.93e-01, |grad| = 1.57e+00 (4.68e-01s)
# [TST] iter = 7790, cost = 1.33e+02, RMSE = 9.38e-01 (3.16e-01s)
# [TRN] iter = 7800, cost = 8.37e-01, |grad| = 6.15e+00 (4.47e-01s)
# [TST] iter = 7800, cost = 1.37e+02, RMSE = 9.71e-01 (3.19e-01s)
# [TRN] iter = 7810, cost = 8.36e-01, |grad| = 1.55e+00 (4.62e-01s)
# [TST] iter = 7810, cost = 1.35e+02, RMSE = 9.57e-01 (3.18e-01s)
# [TRN] iter = 7820, cost = 8.14e-01, |grad| = 1.77e+00 (4.41e-01s)
# [TST] iter = 7820, cost = 1.34e+02, RMSE = 9.45e-01 (3.24e-01s)
# [TRN] iter = 7830, cost = 8.02e-01, |grad| = 1.31e+00 (4.78e-01s)
# [TST] iter = 7830, cost = 1.33e+02, RMSE = 9.38e-01 (3.22e-01s)
# [TRN] iter = 7840, cost = 7.93e-01, |grad| = 8.40e-01 (4.65e-01s)
# [TST] iter = 7840, cost = 1.33e+02, RMSE = 9.37e-01 (3.27e-01s)
# [TRN] iter = 7850, cost = 7.90e-01, |grad| = 9.90e-01 (4.63e-01s)
# [TST] iter = 7850, cost = 1.32e+02, RMSE = 9.37e-01 (3.35e-01s)
# [TRN] iter = 7860, cost = 7.88e-01, |grad| = 7.68e-01 (4.71e-01s)
# [TST] iter = 7860, cost = 1.32e+02, RMSE = 9.36e-01 (3.28e-01s)
# [TRN] iter = 7870, cost = 7.87e-01, |grad| = 6.54e-01 (4.66e-01s)
# [TST] iter = 7870, cost = 1.32e+02, RMSE = 9.36e-01 (3.41e-01s)
# [TRN] iter = 7880, cost = 7.87e-01, |grad| = 1.29e+00 (4.70e-01s)
# [TST] iter = 7880, cost = 1.32e+02, RMSE = 9.36e-01 (3.39e-01s)
# [TRN] iter = 7890, cost = 7.87e-01, |grad| = 1.41e+00 (4.70e-01s)
# [TST] iter = 7890, cost = 1.32e+02, RMSE = 9.35e-01 (3.43e-01s)
# [TRN] iter = 7900, cost = 7.85e-01, |grad| = 8.08e-01 (4.66e-01s)
# [TST] iter = 7900, cost = 1.32e+02, RMSE = 9.35e-01 (3.45e-01s)
# [TRN] iter = 7910, cost = 7.85e-01, |grad| = 5.93e-01 (4.84e-01s)
# [TST] iter = 7910, cost = 1.32e+02, RMSE = 9.36e-01 (3.49e-01s)
# [TRN] iter = 7920, cost = 7.84e-01, |grad| = 8.94e-01 (4.61e-01s)
# [TST] iter = 7920, cost = 1.32e+02, RMSE = 9.36e-01 (3.33e-01s)
# [TRN] iter = 7930, cost = 7.86e-01, |grad| = 1.32e+00 (4.64e-01s)
# [TST] iter = 7930, cost = 1.32e+02, RMSE = 9.36e-01 (3.35e-01s)
# [TRN] iter = 7940, cost = 7.89e-01, |grad| = 1.29e+00 (4.59e-01s)
# [TST] iter = 7940, cost = 1.33e+02, RMSE = 9.37e-01 (3.34e-01s)
# [TRN] iter = 7950, cost = 7.87e-01, |grad| = 1.65e+00 (4.79e-01s)
# [TST] iter = 7950, cost = 1.33e+02, RMSE = 9.37e-01 (3.35e-01s)
# [TRN] iter = 7960, cost = 7.91e-01, |grad| = 1.94e+00 (4.65e-01s)
# [TST] iter = 7960, cost = 1.32e+02, RMSE = 9.35e-01 (3.34e-01s)
# [TRN] iter = 7970, cost = 7.89e-01, |grad| = 1.01e+00 (4.63e-01s)
# [TST] iter = 7970, cost = 1.32e+02, RMSE = 9.35e-01 (3.31e-01s)
# [TRN] iter = 7980, cost = 7.86e-01, |grad| = 1.79e+00 (4.65e-01s)
# [TST] iter = 7980, cost = 1.32e+02, RMSE = 9.34e-01 (3.41e-01s)
# [TRN] iter = 7990, cost = 7.89e-01, |grad| = 1.74e+00 (4.85e-01s)
# [TST] iter = 7990, cost = 1.32e+02, RMSE = 9.36e-01 (3.32e-01s)
# [TRN] iter = 8000, cost = 7.89e-01, |grad| = 2.04e+00 (4.48e-01s)
# [TST] iter = 8000, cost = 1.33e+02, RMSE = 9.37e-01 (3.62e-01s)
# [TRN] iter = 8010, cost = 7.87e-01, |grad| = 9.48e-01 (4.54e-01s)
# [TST] iter = 8010, cost = 1.33e+02, RMSE = 9.38e-01 (3.29e-01s)
# [TRN] iter = 8020, cost = 7.90e-01, |grad| = 1.56e+00 (4.50e-01s)
# [TST] iter = 8020, cost = 1.32e+02, RMSE = 9.36e-01 (3.22e-01s)
# [TRN] iter = 8030, cost = 7.91e-01, |grad| = 1.11e+00 (4.42e-01s)
# [TST] iter = 8030, cost = 1.33e+02, RMSE = 9.38e-01 (3.07e-01s)
# [TRN] iter = 8040, cost = 7.89e-01, |grad| = 9.58e-01 (4.72e-01s)
# [TST] iter = 8040, cost = 1.32e+02, RMSE = 9.36e-01 (3.20e-01s)
# [TRN] iter = 8050, cost = 7.89e-01, |grad| = 1.12e+00 (4.64e-01s)
# [TST] iter = 8050, cost = 1.32e+02, RMSE = 9.35e-01 (3.18e-01s)
# [TRN] iter = 8060, cost = 9.01e-01, |grad| = 1.93e+00 (1.80e+03s)
# [TST] iter = 8060, cost = 1.40e+02, RMSE = 9.90e-01 (2.79e-01s)
# [TRN] iter = 8070, cost = 8.68e-01, |grad| = 1.37e+00 (4.53e-01s)
# [TST] iter = 8070, cost = 1.36e+02, RMSE = 9.61e-01 (3.08e-01s)
# [TRN] iter = 8080, cost = 8.40e-01, |grad| = 2.20e+00 (4.48e-01s)
# [TST] iter = 8080, cost = 1.35e+02, RMSE = 9.57e-01 (2.99e-01s)
# [TRN] iter = 8090, cost = 8.21e-01, |grad| = 1.07e+00 (1.51e+00s)
# [TST] iter = 8090, cost = 1.34e+02, RMSE = 9.50e-01 (1.16e+00s)
# [TRN] iter = 8100, cost = 8.05e-01, |grad| = 8.58e-01 (1.51e+00s)
# [TST] iter = 8100, cost = 1.33e+02, RMSE = 9.40e-01 (1.13e+00s)
# [TRN] iter = 8110, cost = 7.96e-01, |grad| = 1.15e+00 (4.57e-01s)
# [TST] iter = 8110, cost = 1.33e+02, RMSE = 9.40e-01 (2.96e-01s)
# [TRN] iter = 8120, cost = 7.90e-01, |grad| = 7.55e-01 (4.73e-01s)
# [TST] iter = 8120, cost = 1.33e+02, RMSE = 9.38e-01 (2.92e-01s)
# [TRN] iter = 8130, cost = 7.93e-01, |grad| = 1.23e+00 (1.52e+00s)
# [TST] iter = 8130, cost = 1.33e+02, RMSE = 9.38e-01 (1.17e+00s)
# [TRN] iter = 8140, cost = 7.92e-01, |grad| = 8.12e-01 (1.52e+00s)
# [TST] iter = 8140, cost = 1.33e+02, RMSE = 9.38e-01 (1.17e+00s)
# [TRN] iter = 8150, cost = 7.89e-01, |grad| = 1.78e+00 (3.94e+03s)
# [TST] iter = 8150, cost = 1.33e+02, RMSE = 9.38e-01 (4.18e-01s)
# [TRN] iter = 8160, cost = 7.88e-01, |grad| = 1.03e+00 (5.31e-01s)
# [TST] iter = 8160, cost = 1.32e+02, RMSE = 9.36e-01 (3.92e-01s)
# [TRN] iter = 8170, cost = 7.88e-01, |grad| = 1.22e+00 (4.59e-01s)
# [TST] iter = 8170, cost = 1.33e+02, RMSE = 9.37e-01 (3.12e-01s)
# [TRN] iter = 8180, cost = 7.85e-01, |grad| = 7.86e-01 (4.46e-01s)
# [TST] iter = 8180, cost = 1.32e+02, RMSE = 9.36e-01 (3.17e-01s)
# [TRN] iter = 8190, cost = 7.87e-01, |grad| = 8.59e-01 (4.48e-01s)
# [TST] iter = 8190, cost = 1.32e+02, RMSE = 9.36e-01 (3.06e-01s)
# [TRN] iter = 8200, cost = 7.87e-01, |grad| = 1.22e+00 (4.36e-01s)
# [TST] iter = 8200, cost = 1.32e+02, RMSE = 9.36e-01 (3.24e-01s)
# [TRN] iter = 8210, cost = 7.86e-01, |grad| = 8.82e-01 (4.49e-01s)
# [TST] iter = 8210, cost = 1.32e+02, RMSE = 9.36e-01 (3.02e-01s)
# [TRN] iter = 8220, cost = 7.84e-01, |grad| = 5.98e-01 (4.48e-01s)
# [TST] iter = 8220, cost = 1.32e+02, RMSE = 9.36e-01 (3.18e-01s)
# [TRN] iter = 8230, cost = 7.84e-01, |grad| = 1.10e+00 (4.54e-01s)
# [TST] iter = 8230, cost = 1.32e+02, RMSE = 9.36e-01 (3.02e-01s)
# [TRN] iter = 8240, cost = 7.84e-01, |grad| = 8.93e-01 (4.36e-01s)
# [TST] iter = 8240, cost = 1.32e+02, RMSE = 9.35e-01 (3.05e-01s)
# [TRN] iter = 8250, cost = 7.87e-01, |grad| = 9.55e-01 (4.67e-01s)
# [TST] iter = 8250, cost = 1.32e+02, RMSE = 9.36e-01 (3.22e-01s)
# [TRN] iter = 8260, cost = 7.87e-01, |grad| = 1.43e+00 (4.42e-01s)
# [TST] iter = 8260, cost = 1.32e+02, RMSE = 9.37e-01 (3.14e-01s)
# [TRN] iter = 8270, cost = 7.85e-01, |grad| = 1.46e+00 (4.47e-01s)
# [TST] iter = 8270, cost = 1.32e+02, RMSE = 9.36e-01 (3.14e-01s)
# [TRN] iter = 8280, cost = 7.86e-01, |grad| = 9.01e-01 (4.35e-01s)
# [TST] iter = 8280, cost = 1.33e+02, RMSE = 9.37e-01 (3.13e-01s)
# [TRN] iter = 8290, cost = 7.87e-01, |grad| = 1.03e+00 (4.40e-01s)
# [TST] iter = 8290, cost = 1.33e+02, RMSE = 9.39e-01 (3.28e-01s)
# [TRN] iter = 8300, cost = 7.95e-01, |grad| = 1.92e+00 (4.34e-01s)
# [TST] iter = 8300, cost = 1.33e+02, RMSE = 9.39e-01 (3.11e-01s)
# [TRN] iter = 8310, cost = 7.87e-01, |grad| = 1.05e+00 (4.51e-01s)
# [TST] iter = 8310, cost = 1.32e+02, RMSE = 9.36e-01 (3.16e-01s)
# [TRN] iter = 8320, cost = 7.83e-01, |grad| = 7.18e-01 (4.67e-01s)
# [TST] iter = 8320, cost = 1.32e+02, RMSE = 9.35e-01 (3.21e-01s)
# [TRN] iter = 8330, cost = 7.82e-01, |grad| = 6.39e-01 (4.44e-01s)
# [TST] iter = 8330, cost = 1.32e+02, RMSE = 9.36e-01 (3.11e-01s)
# [TRN] iter = 8340, cost = 7.85e-01, |grad| = 9.06e-01 (4.47e-01s)
# [TST] iter = 8340, cost = 1.32e+02, RMSE = 9.37e-01 (3.23e-01s)
# [TRN] iter = 8350, cost = 7.88e-01, |grad| = 1.23e+00 (4.31e-01s)
# [TST] iter = 8350, cost = 1.33e+02, RMSE = 9.37e-01 (3.20e-01s)
# [TRN] iter = 8360, cost = 7.87e-01, |grad| = 1.02e+00 (4.49e-01s)
# [TST] iter = 8360, cost = 1.32e+02, RMSE = 9.36e-01 (3.08e-01s)
# [TRN] iter = 8370, cost = 7.85e-01, |grad| = 1.49e+00 (4.53e-01s)
# [TST] iter = 8370, cost = 1.32e+02, RMSE = 9.35e-01 (3.06e-01s)
# [TRN] iter = 8380, cost = 7.84e-01, |grad| = 1.17e+00 (4.45e-01s)
# [TST] iter = 8380, cost = 1.32e+02, RMSE = 9.34e-01 (3.10e-01s)
# [TRN] iter = 8390, cost = 7.81e-01, |grad| = 7.76e-01 (4.39e-01s)
# [TST] iter = 8390, cost = 1.32e+02, RMSE = 9.35e-01 (3.10e-01s)
# [TRN] iter = 8400, cost = 7.85e-01, |grad| = 1.69e+00 (4.36e-01s)
# [TST] iter = 8400, cost = 1.32e+02, RMSE = 9.37e-01 (3.23e-01s)
# [TRN] iter = 8410, cost = 7.92e-01, |grad| = 1.28e+00 (4.36e-01s)
# [TST] iter = 8410, cost = 1.33e+02, RMSE = 9.40e-01 (3.22e-01s)
# [TRN] iter = 8420, cost = 8.03e-01, |grad| = 2.97e+00 (4.41e-01s)
# [TST] iter = 8420, cost = 1.33e+02, RMSE = 9.41e-01 (3.15e-01s)
# [TRN] iter = 8430, cost = 7.95e-01, |grad| = 1.66e+00 (4.32e-01s)
# [TST] iter = 8430, cost = 1.32e+02, RMSE = 9.36e-01 (3.13e-01s)
# [TRN] iter = 8440, cost = 7.87e-01, |grad| = 8.66e-01 (4.54e-01s)
# [TST] iter = 8440, cost = 1.32e+02, RMSE = 9.35e-01 (3.19e-01s)
# [TRN] iter = 8450, cost = 7.89e-01, |grad| = 1.20e+00 (4.54e-01s)
# [TST] iter = 8450, cost = 1.33e+02, RMSE = 9.38e-01 (3.19e-01s)
# [TRN] iter = 8460, cost = 7.85e-01, |grad| = 1.45e+00 (4.58e-01s)
# [TST] iter = 8460, cost = 1.32e+02, RMSE = 9.36e-01 (3.15e-01s)
# [TRN] iter = 8470, cost = 7.85e-01, |grad| = 1.33e+00 (4.60e-01s)
# [TST] iter = 8470, cost = 1.32e+02, RMSE = 9.36e-01 (3.15e-01s)
# [TRN] iter = 8480, cost = 8.01e-01, |grad| = 2.97e+00 (4.75e-01s)
# [TST] iter = 8480, cost = 1.33e+02, RMSE = 9.41e-01 (3.21e-01s)
# [TRN] iter = 8490, cost = 7.95e-01, |grad| = 1.69e+00 (4.61e-01s)
# [TST] iter = 8490, cost = 1.33e+02, RMSE = 9.39e-01 (3.13e-01s)

# %%
fig, ax1 = plt.subplots(figsize=(20,10))
plt.title('Learning curves on Douban Dataset')
ax2 = ax1.twinx()
ax1.plot(np.arange(len(list_training_loss)), list_training_loss, 'g-')
ax2.plot(np.arange(len(list_test_pred_error))*num_iter_test, list_test_pred_error, 'b-')

ax1.set_xlabel('Iteration')
ax1.set_ylabel('Training loss', color='g')
ax2.set_ylabel('Test loss', color='b')

best_iter = (np.where(np.asarray(list_training_loss)==np.min(list_training_loss))[0][0]//num_iter_test)*num_iter_test
best_pred_error = list_test_pred_error[best_iter//num_iter_test]
print ('Best predictions at iter: %d (error: %f)' % (best_iter, best_pred_error))
RMSE = np.sqrt(np.square(best_pred_error)/np.sum(Otest))
print ('RMSE: %f' % RMSE)
# Out:
# Best predictions at iter: 8390 (error: 132.271820)
# RMSE: 0.935303

# %%
#last X generated
plt.figure(figsize=(20,10))
plt.imshow(X)
plt.title('Completed Douban dataset')
plt.colorbar()
