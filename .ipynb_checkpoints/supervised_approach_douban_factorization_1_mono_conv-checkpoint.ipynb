# %%
import os,sys,inspect
import os
import joblib
import tensorflow.compat.v1 as tf
import numpy as np
import h5py
import scipy.sparse.linalg as la
import scipy.sparse as sp
import scipy
import time

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
# %matplotlib inline

# %%
path_dataset = '/Users/liujiaoyang/tensorflow/MGCNN/Data/Douban/training_test_dataset.mat' #with only social network

# %%
# auxiliary functions:

# import matlab files in python
def load_matlab_file(path_file, name_field):
    """
    load '.mat' files
    inputs:
        path_file, string containing the file path
        name_field, string containig the field name (default='shape')
    warning:
        '.mat' files should be saved in the '-v7.3' format
    """
    db = h5py.File(path_file, 'r')
    ds = db[name_field]
    try:
        if 'ir' in ds.keys():
            data = np.asarray(ds['data'])
            ir   = np.asarray(ds['ir'])
            jc   = np.asarray(ds['jc'])
            out  = sp.csc_matrix((data, ir, jc)).astype(np.float32)
    except AttributeError:
        # Transpose in case is a dense matrix because of the row- vs column- major ordering between python and matlab
        out = np.asarray(ds).astype(np.float32).T

    db.close()

    return out

# %%
#loading of the required matrices
M = load_matlab_file(path_dataset, 'M')
Otraining = load_matlab_file(path_dataset, 'Otraining')
Otest = load_matlab_file(path_dataset, 'Otest')
Wrow = load_matlab_file(path_dataset, 'W_users') #dense

# %%
np.random.seed(0) #Initialize the random number generator.
pos_tr_samples = np.where(Otraining) #返回Otraining中不为零的值的坐标

num_tr_samples = len(pos_tr_samples[0]) #不为零的个数
list_idx = list(range(num_tr_samples))
np.random.shuffle(list_idx)
idx_data = list_idx[:num_tr_samples//2]
idx_train = list_idx[num_tr_samples//2:]

pos_data_samples = (pos_tr_samples[0][idx_data], pos_tr_samples[1][idx_data])
pos_tr_samples = (pos_tr_samples[0][idx_train], pos_tr_samples[1][idx_train])

Odata = np.zeros(M.shape)
Otraining = np.zeros(M.shape)

for k in range(len(pos_data_samples[0])):
    Odata[pos_data_samples[0][k], pos_data_samples[1][k]] = 1
    
for k in range(len(pos_tr_samples[0])):
    Otraining[pos_tr_samples[0][k], pos_tr_samples[1][k]] = 1
    
print ('Num data samples: %d' % (np.sum(Odata),))
print ('Num train samples: %d' % (np.sum(Otraining),))
print ('Num train+data samples: %d' % (np.sum(Odata+Otraining),))
# Out:
# Num data samples: 61601
# Num train samples: 61601
# Num train+data samples: 123202

# %%
#computation of the normalized laplacians
Lrow = sp.csgraph.laplacian(Wrow, normed=True)

# %%
#apply SVD initially for detecting the main components of our initialization
U, s, V = np.linalg.svd(Odata*M, full_matrices=0)

print (U.shape)
print (s.shape)
print (V.shape)
# Out:
# (3000, 3000)
# (3000,)
# (3000, 3000)

# %%
rank_W_H = 10
partial_s = s[:rank_W_H]
partial_S_sqrt = np.diag(np.sqrt(partial_s))
initial_W = np.dot(U[:, :rank_W_H], partial_S_sqrt)
initial_H = np.dot(partial_S_sqrt, V[:rank_W_H, :]).T

print (initial_W.shape)
print (initial_H.shape)
# Out:
# (3000, 10)
# (3000, 10)

# %%
print ('Original training matrix')
plt.figure()
plt.imshow(Odata*M)
plt.colorbar()

print ('Reconstructed training matrix')
plt.figure()
plt.imshow(np.dot(initial_W, initial_H.T))
plt.colorbar()
# Out:
# Original training matrix
# Reconstructed training matrix

# %%
class Train_test_matrix_completion:
    
    """
    The neural network model.
    """
    
    def frobenius_norm(self, tensor):
        square_tensor = tf.square(tensor)
        tensor_sum = tf.reduce_sum(square_tensor)
        frobenius_norm = tf.sqrt(tensor_sum)
        return frobenius_norm
    
    def mono_conv(self, list_lap, ord_conv, A, W, b):
        
        feat = []
        #collect features
        for k in range(ord_conv):
            c_lap = list_lap[k] 
                                                     
            #dense implementation
            c_feat = tf.matmul(c_lap, A, a_is_sparse=False)
            feat.append(c_feat)
            
        all_feat = tf.concat(feat,1)
        conv_feat = tf.matmul(all_feat, W) + b
        conv_feat = tf.nn.relu(conv_feat)
        
        return conv_feat
                
    def compute_cheb_polynomials(self, L, ord_cheb, list_cheb):
        for k in range(ord_cheb):
            if (k==0):
                list_cheb.append(tf.cast(tf.diag(tf.ones([tf.shape(L)[0],])), 'float32'))
            elif (k==1):
                list_cheb.append(tf.cast(L, 'float32'))
            else:
                list_cheb.append(2*tf.matmul(L, list_cheb[k-1])  - list_cheb[k-2])
                 
    def __init__(self, M, Lr, Odata, Otraining, Otest, initial_W, initial_H,
                 order_chebyshev_row = 5,
                 num_iterations = 10, gamma=1.0, gamma_H=1.0, gamma_W=1.0, learning_rate=1e-4, idx_gpu = '/gpu:1'):
        
        #order of the spectral filters
        self.ord_row = order_chebyshev_row
        self.num_iterations = num_iterations
        self.n_conv_feat = 32
        
        with tf.Graph().as_default() as g:
                tf.logging.set_verbosity(tf.logging.ERROR)
                self.graph = g
                tf.set_random_seed(0)
                with tf.device(idx_gpu):
                    
                        #loading of the laplacians
                        self.Lr = tf.cast(Lr, 'float32')
                        
                        self.norm_Lr = self.Lr - tf.diag(tf.ones([Lr.shape[0], ]))
                        
                        #compute all chebyshev polynomials a priori
                        self.list_row_cheb_pol = list()
                        self.compute_cheb_polynomials(self.norm_Lr, self.ord_row, self.list_row_cheb_pol)
                        
                        #definition of constant matrices
                        self.M = tf.constant(M, dtype=tf.float32)
                        self.Odata = tf.constant(Odata, dtype=tf.float32)
                        self.Otraining = tf.constant(Otraining, dtype=tf.float32) #training mask
                        self.Otest = tf.constant(Otest, dtype=tf.float32) #test mask
                         
                        ##################################definition of the NN variables#####################################
                        
                        #definition of the weights for extracting the global features
                        self.W_conv_W = tf.get_variable("W_conv_W", shape=[self.ord_row*initial_W.shape[1], self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.b_conv_W = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        
                        #recurrent N parameters
                        self.W_f_u = tf.get_variable("W_f_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.W_i_u = tf.get_variable("W_i_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.W_o_u = tf.get_variable("W_o_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.W_c_u = tf.get_variable("W_c_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_f_u = tf.get_variable("U_f_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_i_u = tf.get_variable("U_i_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_o_u = tf.get_variable("U_o_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.U_c_u = tf.get_variable("U_c_u", shape=[self.n_conv_feat, self.n_conv_feat], initializer=tf.glorot_uniform_initializer())
                        self.b_f_u = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        self.b_i_u = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        self.b_o_u = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        self.b_c_u = tf.Variable(tf.zeros([self.n_conv_feat,]))
                        
                        #output parameters
                        self.W_out_W = tf.get_variable("W_out_W", shape=[self.n_conv_feat, initial_W.shape[1]], initializer=tf.glorot_uniform_initializer()) 
                        self.b_out_W = tf.Variable(tf.zeros([initial_W.shape[1],]))
                        
                        #########definition of the NN
                        #definition of W and H
                        self.W = tf.constant(initial_W.astype('float32'))
                        self.H = tf.Variable(initial_H.astype('float32'))
                        
                        self.X = tf.matmul(self.W, self.H, transpose_b=True) #we may initialize it at random here
                        self.list_X = list()
                        self.list_X.append(tf.identity(self.X))
                        
                        #RNN
                        self.h_u = tf.zeros([M.shape[0], self.n_conv_feat])
                        self.c_u = tf.zeros([M.shape[0], self.n_conv_feat])
                        
                        
                        for k in range(self.num_iterations):
                            #extraction of global features vectors
                            self.final_feat_users = self.mono_conv(self.list_row_cheb_pol, self.ord_row, self.W, self.W_conv_W, self.b_conv_W)
                            
                            #here we have to split the features between users and movies LSTMs
                            
                            #users RNN
                            self.f_u = tf.sigmoid(tf.matmul(self.final_feat_users, self.W_f_u) + tf.matmul(self.h_u, self.U_f_u) + self.b_f_u)
                            self.i_u = tf.sigmoid(tf.matmul(self.final_feat_users, self.W_i_u) + tf.matmul(self.h_u, self.U_i_u) + self.b_i_u)
                            self.o_u = tf.sigmoid(tf.matmul(self.final_feat_users, self.W_o_u) + tf.matmul(self.h_u, self.U_o_u) + self.b_o_u)
                            
                            self.update_c_u = tf.sigmoid(tf.matmul(self.final_feat_users, self.W_c_u) + tf.matmul(self.h_u, self.U_c_u) + self.b_c_u)
                            self.c_u = tf.multiply(self.f_u, self.c_u) + tf.multiply(self.i_u, self.update_c_u)
                            self.h_u = tf.multiply(self.o_u, tf.sigmoid(self.c_u))
                            
                            #compute update of matrix X
                            self.delta_W = tf.tanh(tf.matmul(self.c_u, self.W_out_W) + self.b_out_W) #N x rank_W_H
                            
                            self.W += self.delta_W
                        
                            self.X = tf.matmul(self.W, self.H, transpose_b=True)
                            self.list_X.append(tf.identity(tf.reshape(self.X, [tf.shape(self.M)[0], tf.shape(self.M)[1]])))
                        self.X = tf.matmul(self.W, self.H, transpose_b=True)
                        #########loss definition
                        
                        #computation of the accuracy term
                        self.norm_X = 1+4*(self.X-tf.reduce_min(self.X))/(tf.reduce_max(self.X-tf.reduce_min(self.X)))
                        frob_tensor = tf.multiply(self.Otraining + self.Odata, self.norm_X - M)
                        self.loss_frob = tf.square(self.frobenius_norm(frob_tensor))/np.sum(Otraining+Odata)
                        
                        #computation of the regularization terms
                        trace_row_tensor = tf.matmul(tf.matmul(self.X, self.Lr, transpose_a=True), self.X)
                        self.loss_trace_row = tf.trace(trace_row_tensor)/tf.cast(tf.shape(self.X)[0]*tf.shape(self.X)[1],'float32')
                        
                        self.frob_norm_H = tf.square(self.frobenius_norm(self.H))/tf.cast(tf.shape(self.H)[0]*tf.shape(self.H)[1], 'float32')
                        self.frob_norm_W = tf.square(self.frobenius_norm(self.W))/tf.cast(tf.shape(self.W)[0]*tf.shape(self.W)[1], 'float32')
                        
                        
                        #training loss definition
                        self.loss = self.loss_frob + (gamma/2)*self.loss_trace_row + (gamma_H/2)*self.frob_norm_H + (gamma_W/2)*self.frob_norm_W
                        
                        #test loss definition
                        self.predictions = tf.multiply(self.Otest, self.norm_X - self.M)
                        self.predictions_error = self.frobenius_norm(self.predictions)

                        #definition of the solver
                        self.optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(self.loss)
                        
                        self.var_grad = tf.gradients(self.loss, tf.trainable_variables())
                        self.norm_grad = self.frobenius_norm(tf.concat([tf.reshape(g, [-1]) for g in self.var_grad],0))

                        # Create a session for running Ops on the Graph.
                        config = tf.ConfigProto(allow_soft_placement = True)
                        config.gpu_options.allow_growth = True
                        self.session = tf.Session(config=config)

                        # Run the Op to initialize the variables.
                        init = tf.initialize_all_variables()
                        self.session.run(init)

# %%
ord_col = 5
ord_row = 5

        
learning_obj = Train_test_matrix_completion(M, Lrow, Odata, Otraining, Otest, 
                                                    initial_W, initial_H,
                                                    order_chebyshev_row = ord_row, 
                                                    gamma=1e2, gamma_H=1e2, gamma_W=1e0,
                                                    learning_rate=1e-3)

num_iter_test = 10
num_total_iter_training = 5000

num_iter = 0

list_training_loss = list()
list_training_norm_grad = list()
list_test_pred_error = list()
list_predictions = list()
list_X = list()

list_training_times = list()
list_test_times = list()
list_grad_X = list()

list_X_evolutions = list()

# %%
num_iter = 0
for k in range(num_iter, num_total_iter_training):

    tic = time.time()
    _, current_training_loss, norm_grad, X_grad = learning_obj.session.run([learning_obj.optimizer, learning_obj.loss, 
                                                                                        learning_obj.norm_grad, learning_obj.var_grad]) 
    training_time = time.time() - tic

    list_training_loss.append(current_training_loss)
    list_training_norm_grad.append(norm_grad)
    list_training_times.append(training_time)

    if (np.mod(num_iter, num_iter_test)==0):
        msg = "[TRN] iter = %03i, cost = %3.2e, |grad| = %.2e (%3.2es)" \
                                    % (num_iter, list_training_loss[-1], list_training_norm_grad[-1], training_time)
        print (msg)

        #Test Code
        tic = time.time()
        pred_error, preds, X = learning_obj.session.run([learning_obj.predictions_error, learning_obj.predictions,
                                                                             learning_obj.norm_X]) 
        test_time = time.time() - tic

        list_test_pred_error.append(pred_error)
        list_test_times.append(test_time)
            
        RMSE = np.sqrt(np.square(pred_error)/np.sum(Otest))
        msg =  "[TST] iter = %03i, cost = %3.2e, RMSE = %3.2e (%3.2es)" % (num_iter, list_test_pred_error[-1], RMSE, test_time)
        print (msg)
            
    num_iter += 1
# Out:
# [TRN] iter = 000, cost = 3.31e+01, |grad| = 8.59e+01 (1.14e+01s)
# [TST] iter = 000, cost = 1.26e+02, RMSE = 1.07e+00 (5.54e+00s)
# [TRN] iter = 010, cost = 1.15e+01, |grad| = 3.41e+01 (1.93e+00s)
# [TST] iter = 010, cost = 1.21e+02, RMSE = 1.03e+00 (4.92e-01s)
# [TRN] iter = 020, cost = 4.85e+00, |grad| = 1.63e+01 (1.77e+00s)
# [TST] iter = 020, cost = 1.14e+02, RMSE = 9.71e-01 (4.90e-01s)
# [TRN] iter = 030, cost = 2.84e+00, |grad| = 9.30e+00 (1.77e+00s)
# [TST] iter = 030, cost = 1.10e+02, RMSE = 9.39e-01 (4.87e-01s)
# [TRN] iter = 040, cost = 2.24e+00, |grad| = 4.38e+00 (1.81e+00s)
# [TST] iter = 040, cost = 1.09e+02, RMSE = 9.31e-01 (4.94e-01s)
# [TRN] iter = 050, cost = 2.02e+00, |grad| = 2.70e+00 (1.82e+00s)
# [TST] iter = 050, cost = 1.07e+02, RMSE = 9.18e-01 (5.01e-01s)
# [TRN] iter = 060, cost = 1.92e+00, |grad| = 1.97e+00 (1.83e+00s)
# [TST] iter = 060, cost = 1.07e+02, RMSE = 9.16e-01 (5.01e-01s)
# [TRN] iter = 070, cost = 1.85e+00, |grad| = 1.73e+00 (1.81e+00s)
# [TST] iter = 070, cost = 1.07e+02, RMSE = 9.14e-01 (5.02e-01s)
# [TRN] iter = 080, cost = 1.80e+00, |grad| = 8.91e-01 (1.82e+00s)
# [TST] iter = 080, cost = 1.07e+02, RMSE = 9.11e-01 (5.01e-01s)
# [TRN] iter = 090, cost = 1.75e+00, |grad| = 1.03e+00 (1.84e+00s)
# [TST] iter = 090, cost = 1.06e+02, RMSE = 9.10e-01 (5.00e-01s)
# [TRN] iter = 100, cost = 1.72e+00, |grad| = 6.01e-01 (1.81e+00s)
# [TST] iter = 100, cost = 1.06e+02, RMSE = 9.09e-01 (5.10e-01s)
# [TRN] iter = 110, cost = 1.68e+00, |grad| = 5.12e-01 (1.81e+00s)
# [TST] iter = 110, cost = 1.06e+02, RMSE = 9.08e-01 (4.96e-01s)
# [TRN] iter = 120, cost = 1.65e+00, |grad| = 4.80e-01 (1.82e+00s)
# [TST] iter = 120, cost = 1.06e+02, RMSE = 9.07e-01 (4.90e-01s)
# [TRN] iter = 130, cost = 1.62e+00, |grad| = 4.02e-01 (1.81e+00s)
# [TST] iter = 130, cost = 1.06e+02, RMSE = 9.06e-01 (4.95e-01s)
# [TRN] iter = 140, cost = 1.60e+00, |grad| = 5.12e-01 (1.83e+00s)
# [TST] iter = 140, cost = 1.06e+02, RMSE = 9.05e-01 (4.93e-01s)
# [TRN] iter = 150, cost = 1.57e+00, |grad| = 3.95e-01 (1.83e+00s)
# [TST] iter = 150, cost = 1.06e+02, RMSE = 9.04e-01 (4.89e-01s)
# [TRN] iter = 160, cost = 1.55e+00, |grad| = 1.00e+00 (1.84e+00s)
# [TST] iter = 160, cost = 1.06e+02, RMSE = 9.04e-01 (4.95e-01s)
# [TRN] iter = 170, cost = 1.53e+00, |grad| = 5.96e-01 (1.82e+00s)
# [TST] iter = 170, cost = 1.06e+02, RMSE = 9.03e-01 (4.95e-01s)
# [TRN] iter = 180, cost = 1.51e+00, |grad| = 5.55e-01 (1.84e+00s)
# [TST] iter = 180, cost = 1.06e+02, RMSE = 9.03e-01 (4.92e-01s)
# [TRN] iter = 190, cost = 1.49e+00, |grad| = 5.15e-01 (1.84e+00s)
# [TST] iter = 190, cost = 1.06e+02, RMSE = 9.02e-01 (4.93e-01s)
# [TRN] iter = 200, cost = 1.47e+00, |grad| = 4.49e-01 (1.84e+00s)
# [TST] iter = 200, cost = 1.05e+02, RMSE = 9.01e-01 (4.97e-01s)
# [TRN] iter = 210, cost = 1.45e+00, |grad| = 6.53e-01 (1.81e+00s)
# [TST] iter = 210, cost = 1.05e+02, RMSE = 9.00e-01 (4.93e-01s)
# [TRN] iter = 220, cost = 1.44e+00, |grad| = 1.21e+00 (1.82e+00s)
# [TST] iter = 220, cost = 1.05e+02, RMSE = 8.99e-01 (4.94e-01s)
# [TRN] iter = 230, cost = 1.42e+00, |grad| = 2.32e+00 (1.84e+00s)
# [TST] iter = 230, cost = 1.05e+02, RMSE = 9.00e-01 (4.91e-01s)
# [TRN] iter = 240, cost = 1.40e+00, |grad| = 4.76e-01 (1.84e+00s)
# [TST] iter = 240, cost = 1.05e+02, RMSE = 8.98e-01 (4.93e-01s)
# [TRN] iter = 250, cost = 1.39e+00, |grad| = 1.29e+00 (1.83e+00s)
# [TST] iter = 250, cost = 1.05e+02, RMSE = 8.98e-01 (4.93e-01s)
# [TRN] iter = 260, cost = 1.38e+00, |grad| = 4.17e+00 (1.83e+00s)
# [TST] iter = 260, cost = 1.05e+02, RMSE = 8.97e-01 (4.94e-01s)
# [TRN] iter = 270, cost = 1.36e+00, |grad| = 1.38e+00 (1.82e+00s)
# [TST] iter = 270, cost = 1.05e+02, RMSE = 9.01e-01 (4.91e-01s)
# [TRN] iter = 280, cost = 1.36e+00, |grad| = 2.79e+00 (1.84e+00s)
# [TST] iter = 280, cost = 1.05e+02, RMSE = 8.99e-01 (4.97e-01s)
# [TRN] iter = 290, cost = 1.34e+00, |grad| = 5.00e+00 (1.84e+00s)
# [TST] iter = 290, cost = 1.05e+02, RMSE = 8.97e-01 (4.92e-01s)
# [TRN] iter = 300, cost = 1.32e+00, |grad| = 7.05e-01 (1.83e+00s)
# [TST] iter = 300, cost = 1.05e+02, RMSE = 8.96e-01 (4.99e-01s)
# [TRN] iter = 310, cost = 1.31e+00, |grad| = 7.59e-01 (1.85e+00s)
# [TST] iter = 310, cost = 1.05e+02, RMSE = 8.94e-01 (4.95e-01s)
# [TRN] iter = 320, cost = 1.30e+00, |grad| = 3.75e+00 (1.83e+00s)
# [TST] iter = 320, cost = 1.05e+02, RMSE = 8.95e-01 (4.97e-01s)
# [TRN] iter = 330, cost = 1.29e+00, |grad| = 1.29e+00 (1.85e+00s)
# [TST] iter = 330, cost = 1.04e+02, RMSE = 8.93e-01 (4.92e-01s)
# [TRN] iter = 340, cost = 1.29e+00, |grad| = 2.93e+00 (1.80e+00s)
# [TST] iter = 340, cost = 1.05e+02, RMSE = 8.97e-01 (4.81e-01s)
# [TRN] iter = 350, cost = 1.27e+00, |grad| = 1.68e+00 (1.77e+00s)
# [TST] iter = 350, cost = 1.04e+02, RMSE = 8.93e-01 (4.77e-01s)
# [TRN] iter = 360, cost = 1.26e+00, |grad| = 2.10e+00 (4.92e+00s)
# [TST] iter = 360, cost = 1.04e+02, RMSE = 8.90e-01 (1.62e+00s)
# [TRN] iter = 370, cost = 1.25e+00, |grad| = 1.24e+00 (1.69e+00s)
# [TST] iter = 370, cost = 1.04e+02, RMSE = 8.90e-01 (4.51e-01s)
# [TRN] iter = 380, cost = 1.25e+00, |grad| = 2.37e+00 (2.86e+02s)
# [TST] iter = 380, cost = 1.04e+02, RMSE = 8.92e-01 (4.47e-01s)
# [TRN] iter = 390, cost = 1.26e+00, |grad| = 2.69e+00 (4.93e+00s)
# [TST] iter = 390, cost = 1.06e+02, RMSE = 9.07e-01 (1.62e+00s)
# [TRN] iter = 400, cost = 1.25e+00, |grad| = 2.32e+00 (4.84e+00s)
# [TST] iter = 400, cost = 1.05e+02, RMSE = 9.00e-01 (1.62e+00s)
# [TRN] iter = 410, cost = 1.25e+00, |grad| = 3.06e+00 (1.68e+00s)
# [TST] iter = 410, cost = 1.06e+02, RMSE = 9.04e-01 (4.53e-01s)
# [TRN] iter = 420, cost = 1.23e+00, |grad| = 3.07e+00 (5.00e+00s)
# [TST] iter = 420, cost = 1.05e+02, RMSE = 9.01e-01 (2.84e+02s)
# [TRN] iter = 430, cost = 1.21e+00, |grad| = 1.82e+00 (4.88e+00s)
# [TST] iter = 430, cost = 1.05e+02, RMSE = 8.93e-01 (1.63e+00s)
# [TRN] iter = 440, cost = 1.21e+00, |grad| = 2.69e+00 (1.85e+00s)
# [TST] iter = 440, cost = 1.05e+02, RMSE = 8.98e-01 (4.88e-01s)
# [TRN] iter = 450, cost = 1.19e+00, |grad| = 1.01e+00 (1.68e+00s)
# [TST] iter = 450, cost = 1.05e+02, RMSE = 8.96e-01 (4.77e-01s)
# [TRN] iter = 460, cost = 1.19e+00, |grad| = 3.31e+00 (1.69e+00s)
# [TST] iter = 460, cost = 1.04e+02, RMSE = 8.89e-01 (4.69e-01s)
# [TRN] iter = 470, cost = 1.17e+00, |grad| = 2.24e+00 (1.70e+00s)
# [TST] iter = 470, cost = 1.04e+02, RMSE = 8.90e-01 (4.65e-01s)
# [TRN] iter = 480, cost = 1.17e+00, |grad| = 5.36e+00 (1.68e+00s)
# [TST] iter = 480, cost = 1.04e+02, RMSE = 8.89e-01 (4.69e-01s)
# [TRN] iter = 490, cost = 1.16e+00, |grad| = 1.41e+00 (1.73e+00s)
# [TST] iter = 490, cost = 1.04e+02, RMSE = 8.85e-01 (4.78e-01s)
# [TRN] iter = 500, cost = 1.15e+00, |grad| = 1.58e+00 (1.73e+00s)
# [TST] iter = 500, cost = 1.03e+02, RMSE = 8.83e-01 (4.78e-01s)
# [TRN] iter = 510, cost = 1.14e+00, |grad| = 1.97e+00 (1.72e+00s)
# [TST] iter = 510, cost = 1.03e+02, RMSE = 8.81e-01 (4.77e-01s)
# [TRN] iter = 520, cost = 1.13e+00, |grad| = 1.76e+00 (1.74e+00s)
# [TST] iter = 520, cost = 1.02e+02, RMSE = 8.74e-01 (4.75e-01s)
# [TRN] iter = 530, cost = 1.13e+00, |grad| = 4.73e+00 (1.72e+00s)
# [TST] iter = 530, cost = 1.02e+02, RMSE = 8.73e-01 (4.75e-01s)
# [TRN] iter = 540, cost = 1.12e+00, |grad| = 4.78e+00 (1.74e+00s)
# [TST] iter = 540, cost = 1.02e+02, RMSE = 8.69e-01 (4.78e-01s)
# [TRN] iter = 550, cost = 1.11e+00, |grad| = 2.53e+00 (1.74e+00s)
# [TST] iter = 550, cost = 1.01e+02, RMSE = 8.67e-01 (4.77e-01s)
# [TRN] iter = 560, cost = 1.11e+00, |grad| = 5.01e+00 (1.74e+00s)
# [TST] iter = 560, cost = 1.02e+02, RMSE = 8.74e-01 (4.75e-01s)
# [TRN] iter = 570, cost = 1.11e+00, |grad| = 2.40e+01 (1.77e+00s)
# [TST] iter = 570, cost = 1.02e+02, RMSE = 8.68e-01 (4.81e-01s)
# [TRN] iter = 580, cost = 1.17e+00, |grad| = 3.22e+00 (1.73e+00s)
# [TST] iter = 580, cost = 1.04e+02, RMSE = 8.91e-01 (4.80e-01s)
# [TRN] iter = 590, cost = 1.11e+00, |grad| = 2.13e+00 (1.74e+00s)
# [TST] iter = 590, cost = 1.02e+02, RMSE = 8.70e-01 (4.78e-01s)
# [TRN] iter = 600, cost = 1.08e+00, |grad| = 1.60e+00 (1.74e+00s)
# [TST] iter = 600, cost = 1.01e+02, RMSE = 8.63e-01 (4.78e-01s)
# [TRN] iter = 610, cost = 1.09e+00, |grad| = 3.79e+00 (1.72e+00s)
# [TST] iter = 610, cost = 1.01e+02, RMSE = 8.67e-01 (4.75e-01s)
# [TRN] iter = 620, cost = 1.10e+00, |grad| = 7.86e+00 (1.72e+00s)
# [TST] iter = 620, cost = 1.03e+02, RMSE = 8.77e-01 (4.74e-01s)
# [TRN] iter = 630, cost = 1.07e+00, |grad| = 7.82e+00 (1.73e+00s)
# [TST] iter = 630, cost = 1.01e+02, RMSE = 8.59e-01 (4.74e-01s)
# [TRN] iter = 640, cost = 1.16e+00, |grad| = 1.76e+01 (1.72e+00s)
# [TST] iter = 640, cost = 1.04e+02, RMSE = 8.90e-01 (4.74e-01s)
# [TRN] iter = 650, cost = 1.08e+00, |grad| = 2.58e+00 (1.75e+00s)
# [TST] iter = 650, cost = 1.01e+02, RMSE = 8.64e-01 (4.67e-01s)
# [TRN] iter = 660, cost = 1.05e+00, |grad| = 1.58e+00 (1.72e+00s)
# [TST] iter = 660, cost = 9.95e+01, RMSE = 8.50e-01 (4.76e-01s)
# [TRN] iter = 670, cost = 1.03e+00, |grad| = 7.42e+00 (1.74e+00s)
# [TST] iter = 670, cost = 9.88e+01, RMSE = 8.45e-01 (4.80e-01s)
# [TRN] iter = 680, cost = 1.03e+00, |grad| = 2.88e+00 (1.72e+00s)
# [TST] iter = 680, cost = 9.85e+01, RMSE = 8.42e-01 (4.75e-01s)
# [TRN] iter = 690, cost = 1.02e+00, |grad| = 4.59e+00 (1.73e+00s)
# [TST] iter = 690, cost = 9.87e+01, RMSE = 8.44e-01 (4.76e-01s)
# [TRN] iter = 700, cost = 1.01e+00, |grad| = 9.69e+00 (1.74e+00s)
# [TST] iter = 700, cost = 1.00e+02, RMSE = 8.54e-01 (4.77e-01s)
# [TRN] iter = 710, cost = 9.97e-01, |grad| = 1.94e+00 (1.74e+00s)
# [TST] iter = 710, cost = 9.75e+01, RMSE = 8.34e-01 (4.71e-01s)
# [TRN] iter = 720, cost = 9.89e-01, |grad| = 5.04e+00 (1.73e+00s)
# [TST] iter = 720, cost = 9.72e+01, RMSE = 8.31e-01 (4.75e-01s)
# [TRN] iter = 730, cost = 9.80e-01, |grad| = 3.70e+00 (1.75e+00s)
# [TST] iter = 730, cost = 9.64e+01, RMSE = 8.24e-01 (4.76e-01s)
# [TRN] iter = 740, cost = 9.69e-01, |grad| = 1.67e+00 (1.72e+00s)
# [TST] iter = 740, cost = 9.59e+01, RMSE = 8.19e-01 (4.74e-01s)
# [TRN] iter = 750, cost = 9.64e-01, |grad| = 7.01e+00 (1.72e+00s)
# [TST] iter = 750, cost = 9.57e+01, RMSE = 8.18e-01 (4.77e-01s)
# [TRN] iter = 760, cost = 9.97e-01, |grad| = 7.29e+00 (1.75e+00s)
# [TST] iter = 760, cost = 9.62e+01, RMSE = 8.22e-01 (4.77e-01s)
# [TRN] iter = 770, cost = 9.73e-01, |grad| = 6.35e+00 (1.72e+00s)
# [TST] iter = 770, cost = 9.58e+01, RMSE = 8.19e-01 (4.71e-01s)
# [TRN] iter = 780, cost = 1.00e+00, |grad| = 2.52e+00 (1.73e+00s)
# [TST] iter = 780, cost = 1.00e+02, RMSE = 8.58e-01 (4.73e-01s)
# [TRN] iter = 790, cost = 1.00e+00, |grad| = 4.47e+00 (1.92e+00s)
# [TST] iter = 790, cost = 9.81e+01, RMSE = 8.39e-01 (4.81e-01s)
# [TRN] iter = 800, cost = 9.67e-01, |grad| = 2.35e+00 (2.85e+02s)
# [TST] iter = 800, cost = 9.52e+01, RMSE = 8.14e-01 (8.00e-01s)
# [TRN] iter = 810, cost = 9.69e-01, |grad| = 5.33e+00 (5.02e+00s)
# [TST] iter = 810, cost = 9.67e+01, RMSE = 8.26e-01 (1.63e+00s)
# [TRN] iter = 820, cost = 9.66e-01, |grad| = 3.62e+00 (4.94e+00s)
# [TST] iter = 820, cost = 9.62e+01, RMSE = 8.22e-01 (1.63e+00s)
# [TRN] iter = 830, cost = 9.42e-01, |grad| = 3.75e+00 (1.68e+00s)
# [TST] iter = 830, cost = 9.50e+01, RMSE = 8.12e-01 (4.56e-01s)
# [TRN] iter = 840, cost = 9.19e-01, |grad| = 2.55e+00 (4.94e+00s)
# [TST] iter = 840, cost = 9.58e+01, RMSE = 8.19e-01 (1.51e+02s)
# [TRN] iter = 850, cost = 9.15e-01, |grad| = 2.13e+00 (4.98e+00s)
# [TST] iter = 850, cost = 9.41e+01, RMSE = 8.04e-01 (1.63e+00s)
# [TRN] iter = 860, cost = 9.10e-01, |grad| = 2.95e+00 (2.43e+00s)
# [TST] iter = 860, cost = 9.42e+01, RMSE = 8.05e-01 (1.63e+00s)
# [TRN] iter = 870, cost = 9.61e-01, |grad| = 2.80e+00 (1.72e+00s)
# [TST] iter = 870, cost = 9.70e+01, RMSE = 8.29e-01 (4.50e-01s)
# [TRN] iter = 880, cost = 9.12e-01, |grad| = 2.25e+00 (4.89e+00s)
# [TST] iter = 880, cost = 9.49e+01, RMSE = 8.11e-01 (1.62e+00s)
# [TRN] iter = 890, cost = 9.19e-01, |grad| = 9.58e+00 (4.96e+00s)
# [TST] iter = 890, cost = 9.54e+01, RMSE = 8.16e-01 (1.63e+00s)
# [TRN] iter = 900, cost = 8.99e-01, |grad| = 3.48e+00 (1.67e+00s)
# [TST] iter = 900, cost = 9.41e+01, RMSE = 8.04e-01 (4.55e-01s)
# [TRN] iter = 910, cost = 8.83e-01, |grad| = 4.46e+00 (1.91e+00s)
# [TST] iter = 910, cost = 9.43e+01, RMSE = 8.06e-01 (4.53e-01s)
# [TRN] iter = 920, cost = 8.94e-01, |grad| = 4.92e+00 (4.93e+00s)
# [TST] iter = 920, cost = 9.38e+01, RMSE = 8.02e-01 (1.62e+00s)
# [TRN] iter = 930, cost = 9.12e-01, |grad| = 2.83e+00 (4.97e+00s)
# [TST] iter = 930, cost = 9.47e+01, RMSE = 8.09e-01 (1.65e+00s)
# [TRN] iter = 940, cost = 9.36e-01, |grad| = 8.23e+00 (1.71e+00s)
# [TST] iter = 940, cost = 9.58e+01, RMSE = 8.19e-01 (4.57e-01s)
# [TRN] iter = 950, cost = 8.92e-01, |grad| = 2.83e+00 (1.75e+00s)
# [TST] iter = 950, cost = 9.45e+01, RMSE = 8.07e-01 (4.63e-01s)
# [TRN] iter = 960, cost = 9.19e-01, |grad| = 4.03e+00 (4.93e+00s)
# [TST] iter = 960, cost = 9.67e+01, RMSE = 8.27e-01 (1.63e+00s)
# [TRN] iter = 970, cost = 9.10e-01, |grad| = 5.69e+00 (4.95e+00s)
# [TST] iter = 970, cost = 9.51e+01, RMSE = 8.13e-01 (1.64e+00s)
# [TRN] iter = 980, cost = 8.79e-01, |grad| = 1.08e+01 (1.68e+00s)
# [TST] iter = 980, cost = 9.53e+01, RMSE = 8.15e-01 (4.51e-01s)
# [TRN] iter = 990, cost = 8.96e-01, |grad| = 2.85e+00 (4.90e+00s)
# [TST] iter = 990, cost = 9.48e+01, RMSE = 8.10e-01 (1.66e+00s)
# [TRN] iter = 1000, cost = 8.78e-01, |grad| = 2.68e+00 (5.01e+00s)
# [TST] iter = 1000, cost = 9.60e+01, RMSE = 8.21e-01 (1.62e+00s)
# [TRN] iter = 1010, cost = 9.01e-01, |grad| = 2.01e+00 (2.01e+00s)
# [TST] iter = 1010, cost = 9.47e+01, RMSE = 8.09e-01 (1.66e+00s)
# [TRN] iter = 1020, cost = 8.65e-01, |grad| = 2.19e+00 (1.70e+00s)
# [TST] iter = 1020, cost = 9.47e+01, RMSE = 8.10e-01 (4.52e-01s)
# [TRN] iter = 1030, cost = 8.49e-01, |grad| = 6.76e+00 (4.91e+00s)
# [TST] iter = 1030, cost = 9.36e+01, RMSE = 8.00e-01 (1.62e+00s)
# [TRN] iter = 1040, cost = 8.58e-01, |grad| = 1.61e+00 (4.93e+00s)
# [TST] iter = 1040, cost = 9.41e+01, RMSE = 8.04e-01 (1.68e+00s)
# [TRN] iter = 1050, cost = 8.48e-01, |grad| = 3.11e+00 (1.68e+00s)
# [TST] iter = 1050, cost = 9.38e+01, RMSE = 8.02e-01 (4.55e-01s)
# [TRN] iter = 1060, cost = 8.45e-01, |grad| = 5.62e+00 (1.69e+00s)
# [TST] iter = 1060, cost = 9.46e+01, RMSE = 8.09e-01 (4.50e-01s)
# [TRN] iter = 1070, cost = 8.66e-01, |grad| = 3.81e+00 (4.99e+00s)
# [TST] iter = 1070, cost = 9.43e+01, RMSE = 8.06e-01 (1.63e+00s)
# [TRN] iter = 1080, cost = 8.36e-01, |grad| = 1.44e+00 (4.95e+00s)
# [TST] iter = 1080, cost = 9.34e+01, RMSE = 7.98e-01 (1.64e+00s)
# [TRN] iter = 1090, cost = 8.46e-01, |grad| = 1.85e+00 (1.71e+00s)
# [TST] iter = 1090, cost = 9.42e+01, RMSE = 8.05e-01 (4.60e-01s)
# [TRN] iter = 1100, cost = 8.29e-01, |grad| = 2.99e+00 (1.77e+00s)
# [TST] iter = 1100, cost = 9.41e+01, RMSE = 8.04e-01 (4.50e-01s)
# [TRN] iter = 1110, cost = 8.45e-01, |grad| = 2.11e+01 (5.00e+00s)
# [TST] iter = 1110, cost = 9.40e+01, RMSE = 8.03e-01 (1.66e+00s)
# [TRN] iter = 1120, cost = 8.42e-01, |grad| = 2.70e+00 (4.95e+00s)
# [TST] iter = 1120, cost = 9.40e+01, RMSE = 8.03e-01 (1.61e+00s)
# [TRN] iter = 1130, cost = 8.36e-01, |grad| = 4.88e+00 (1.69e+00s)
# [TST] iter = 1130, cost = 9.40e+01, RMSE = 8.03e-01 (4.57e-01s)
# [TRN] iter = 1140, cost = 8.16e-01, |grad| = 1.55e+00 (4.98e+00s)
# [TST] iter = 1140, cost = 9.37e+01, RMSE = 8.01e-01 (2.84e+02s)
# [TRN] iter = 1150, cost = 8.38e-01, |grad| = 3.04e+00 (4.94e+00s)
# [TST] iter = 1150, cost = 9.33e+01, RMSE = 7.97e-01 (1.69e+00s)
# [TRN] iter = 1160, cost = 8.25e-01, |grad| = 3.49e+00 (3.43e+00s)
# [TST] iter = 1160, cost = 9.42e+01, RMSE = 8.05e-01 (1.64e+00s)
# [TRN] iter = 1170, cost = 9.14e-01, |grad| = 2.71e+01 (1.68e+00s)
# [TST] iter = 1170, cost = 9.77e+01, RMSE = 8.35e-01 (4.51e-01s)
# [TRN] iter = 1180, cost = 8.98e-01, |grad| = 2.48e+00 (4.98e+00s)
# [TST] iter = 1180, cost = 9.54e+01, RMSE = 8.15e-01 (1.66e+00s)
# [TRN] iter = 1190, cost = 8.28e-01, |grad| = 2.53e+00 (5.01e+00s)
# [TST] iter = 1190, cost = 9.36e+01, RMSE = 8.00e-01 (1.64e+00s)
# [TRN] iter = 1200, cost = 8.26e-01, |grad| = 2.50e+00 (1.70e+00s)
# [TST] iter = 1200, cost = 9.36e+01, RMSE = 8.00e-01 (4.58e-01s)
# [TRN] iter = 1210, cost = 9.66e-01, |grad| = 1.62e+01 (1.73e+00s)
# [TST] iter = 1210, cost = 9.83e+01, RMSE = 8.40e-01 (4.47e-01s)
# [TRN] iter = 1220, cost = 9.61e-01, |grad| = 3.08e+00 (4.95e+00s)
# [TST] iter = 1220, cost = 9.95e+01, RMSE = 8.51e-01 (1.62e+00s)
# [TRN] iter = 1230, cost = 8.53e-01, |grad| = 3.43e+00 (4.96e+00s)
# [TST] iter = 1230, cost = 9.46e+01, RMSE = 8.09e-01 (1.63e+00s)
# [TRN] iter = 1240, cost = 8.29e-01, |grad| = 1.06e+01 (1.69e+00s)
# [TST] iter = 1240, cost = 9.39e+01, RMSE = 8.03e-01 (4.54e-01s)
# [TRN] iter = 1250, cost = 8.07e-01, |grad| = 2.39e+00 (1.78e+00s)
# [TST] iter = 1250, cost = 9.40e+01, RMSE = 8.03e-01 (4.52e-01s)
# [TRN] iter = 1260, cost = 8.03e-01, |grad| = 1.50e+00 (4.96e+00s)
# [TST] iter = 1260, cost = 9.34e+01, RMSE = 7.98e-01 (1.63e+00s)
# [TRN] iter = 1270, cost = 7.96e-01, |grad| = 1.26e+00 (4.92e+00s)
# [TST] iter = 1270, cost = 9.34e+01, RMSE = 7.99e-01 (1.63e+00s)
# [TRN] iter = 1280, cost = 7.85e-01, |grad| = 1.02e+00 (1.70e+00s)
# [TST] iter = 1280, cost = 9.33e+01, RMSE = 7.97e-01 (4.51e-01s)
# [TRN] iter = 1290, cost = 7.81e-01, |grad| = 2.17e+00 (2.88e+02s)
# [TST] iter = 1290, cost = 9.32e+01, RMSE = 7.97e-01 (4.80e-01s)
# [TRN] iter = 1300, cost = 7.84e-01, |grad| = 3.72e+00 (5.03e+00s)
# [TST] iter = 1300, cost = 9.32e+01, RMSE = 7.96e-01 (1.69e+00s)
# [TRN] iter = 1310, cost = 7.87e-01, |grad| = 1.59e+00 (3.45e+00s)
# [TST] iter = 1310, cost = 9.34e+01, RMSE = 7.98e-01 (1.62e+00s)
# [TRN] iter = 1320, cost = 7.90e-01, |grad| = 1.51e+00 (1.68e+00s)
# [TST] iter = 1320, cost = 9.35e+01, RMSE = 7.99e-01 (4.51e-01s)
# [TRN] iter = 1330, cost = 7.84e-01, |grad| = 1.78e+00 (4.96e+00s)
# [TST] iter = 1330, cost = 9.34e+01, RMSE = 7.98e-01 (1.66e+00s)
# [TRN] iter = 1340, cost = 7.80e-01, |grad| = 3.40e+00 (5.11e+00s)
# [TST] iter = 1340, cost = 9.33e+01, RMSE = 7.97e-01 (1.64e+00s)
# [TRN] iter = 1350, cost = 7.76e-01, |grad| = 3.93e+00 (1.71e+00s)
# [TST] iter = 1350, cost = 9.31e+01, RMSE = 7.95e-01 (9.42e-01s)
# [TRN] iter = 1360, cost = 7.85e-01, |grad| = 8.65e+00 (1.70e+00s)
# [TST] iter = 1360, cost = 9.80e+01, RMSE = 8.37e-01 (4.53e-01s)
# [TRN] iter = 1370, cost = 8.78e-01, |grad| = 3.11e+00 (4.91e+00s)
# [TST] iter = 1370, cost = 9.49e+01, RMSE = 8.11e-01 (1.62e+00s)
# [TRN] iter = 1380, cost = 7.91e-01, |grad| = 6.63e+00 (5.02e+00s)
# [TST] iter = 1380, cost = 9.39e+01, RMSE = 8.03e-01 (1.63e+00s)
# [TRN] iter = 1390, cost = 9.32e-01, |grad| = 2.14e+00 (1.69e+00s)
# [TST] iter = 1390, cost = 1.01e+02, RMSE = 8.66e-01 (4.54e-01s)
# [TRN] iter = 1400, cost = 8.78e-01, |grad| = 1.52e+00 (2.01e+00s)
# [TST] iter = 1400, cost = 9.65e+01, RMSE = 8.25e-01 (4.61e-01s)
# [TRN] iter = 1410, cost = 8.25e-01, |grad| = 5.23e+00 (4.96e+00s)
# [TST] iter = 1410, cost = 9.40e+01, RMSE = 8.04e-01 (1.63e+00s)
# [TRN] iter = 1420, cost = 7.88e-01, |grad| = 3.43e+00 (4.92e+00s)
# [TST] iter = 1420, cost = 9.34e+01, RMSE = 7.98e-01 (1.64e+00s)
# [TRN] iter = 1430, cost = 7.81e-01, |grad| = 1.13e+00 (1.70e+00s)
# [TST] iter = 1430, cost = 9.42e+01, RMSE = 8.05e-01 (4.52e-01s)
# [TRN] iter = 1440, cost = 7.75e-01, |grad| = 1.13e+00 (2.93e+02s)
# [TST] iter = 1440, cost = 9.34e+01, RMSE = 7.99e-01 (4.85e-01s)
# [TRN] iter = 1450, cost = 7.59e-01, |grad| = 9.71e-01 (4.93e+00s)
# [TST] iter = 1450, cost = 9.30e+01, RMSE = 7.94e-01 (1.63e+00s)
# [TRN] iter = 1460, cost = 7.57e-01, |grad| = 1.35e+01 (4.91e+00s)
# [TST] iter = 1460, cost = 9.30e+01, RMSE = 7.95e-01 (1.62e+00s)
# [TRN] iter = 1470, cost = 7.58e-01, |grad| = 1.59e+00 (1.68e+00s)
# [TST] iter = 1470, cost = 9.30e+01, RMSE = 7.95e-01 (4.60e-01s)
# [TRN] iter = 1480, cost = 7.55e-01, |grad| = 1.16e+00 (4.93e+00s)
# [TST] iter = 1480, cost = 9.31e+01, RMSE = 7.95e-01 (1.66e+00s)
# [TRN] iter = 1490, cost = 7.63e-01, |grad| = 1.83e+00 (5.03e+00s)
# [TST] iter = 1490, cost = 9.31e+01, RMSE = 7.95e-01 (1.64e+00s)
# [TRN] iter = 1500, cost = 7.48e-01, |grad| = 8.44e+00 (1.69e+00s)
# [TST] iter = 1500, cost = 9.29e+01, RMSE = 7.94e-01 (9.06e-01s)
# [TRN] iter = 1510, cost = 7.59e-01, |grad| = 3.04e+00 (1.71e+00s)
# [TST] iter = 1510, cost = 9.29e+01, RMSE = 7.94e-01 (4.52e-01s)
# [TRN] iter = 1520, cost = 7.41e-01, |grad| = 7.90e-01 (4.94e+00s)
# [TST] iter = 1520, cost = 9.31e+01, RMSE = 7.95e-01 (1.64e+00s)
# [TRN] iter = 1530, cost = 7.44e-01, |grad| = 2.22e+00 (4.97e+00s)
# [TST] iter = 1530, cost = 9.28e+01, RMSE = 7.93e-01 (1.63e+00s)
# [TRN] iter = 1540, cost = 7.37e-01, |grad| = 2.19e+00 (1.70e+00s)
# [TST] iter = 1540, cost = 9.28e+01, RMSE = 7.93e-01 (4.60e-01s)
# [TRN] iter = 1550, cost = 7.47e-01, |grad| = 1.85e+00 (1.69e+00s)
# [TST] iter = 1550, cost = 9.28e+01, RMSE = 7.93e-01 (4.51e-01s)
# [TRN] iter = 1560, cost = 7.63e-01, |grad| = 8.24e+00 (4.97e+00s)
# [TST] iter = 1560, cost = 9.34e+01, RMSE = 7.98e-01 (1.63e+00s)
# [TRN] iter = 1570, cost = 7.46e-01, |grad| = 1.36e+00 (5.04e+00s)
# [TST] iter = 1570, cost = 9.37e+01, RMSE = 8.01e-01 (1.66e+00s)
# [TRN] iter = 1580, cost = 7.39e-01, |grad| = 9.06e-01 (1.71e+00s)
# [TST] iter = 1580, cost = 9.33e+01, RMSE = 7.97e-01 (4.53e-01s)
# [TRN] iter = 1590, cost = 7.35e-01, |grad| = 1.01e+00 (2.11e+00s)
# [TST] iter = 1590, cost = 9.29e+01, RMSE = 7.94e-01 (4.50e-01s)
# [TRN] iter = 1600, cost = 8.75e-01, |grad| = 1.93e+01 (4.95e+00s)
# [TST] iter = 1600, cost = 1.12e+02, RMSE = 9.55e-01 (1.63e+00s)
# [TRN] iter = 1610, cost = 9.80e-01, |grad| = 7.41e+00 (5.00e+00s)
# [TST] iter = 1610, cost = 1.02e+02, RMSE = 8.76e-01 (1.63e+00s)
# [TRN] iter = 1620, cost = 8.60e-01, |grad| = 8.84e+00 (1.69e+00s)
# [TST] iter = 1620, cost = 9.73e+01, RMSE = 8.31e-01 (4.47e-01s)
# [TRN] iter = 1630, cost = 8.03e-01, |grad| = 5.98e+00 (2.87e+02s)
# [TST] iter = 1630, cost = 9.38e+01, RMSE = 8.02e-01 (4.77e-01s)
# [TRN] iter = 1640, cost = 7.63e-01, |grad| = 2.09e+00 (5.04e+00s)
# [TST] iter = 1640, cost = 9.42e+01, RMSE = 8.06e-01 (1.65e+00s)
# [TRN] iter = 1650, cost = 7.56e-01, |grad| = 1.15e+01 (4.93e+00s)
# [TST] iter = 1650, cost = 9.41e+01, RMSE = 8.05e-01 (1.64e+00s)
# [TRN] iter = 1660, cost = 7.56e-01, |grad| = 4.67e+00 (1.70e+00s)
# [TST] iter = 1660, cost = 9.44e+01, RMSE = 8.06e-01 (4.54e-01s)
# [TRN] iter = 1670, cost = 7.85e-01, |grad| = 4.97e+00 (2.88e+02s)
# [TST] iter = 1670, cost = 9.37e+01, RMSE = 8.01e-01 (5.03e-01s)
# [TRN] iter = 1680, cost = 7.46e-01, |grad| = 4.37e+00 (4.96e+00s)
# [TST] iter = 1680, cost = 9.28e+01, RMSE = 7.93e-01 (1.64e+00s)
# [TRN] iter = 1690, cost = 7.36e-01, |grad| = 5.85e+00 (1.97e+00s)
# [TST] iter = 1690, cost = 9.34e+01, RMSE = 7.98e-01 (1.62e+00s)
# [TRN] iter = 1700, cost = 7.40e-01, |grad| = 1.55e+00 (1.70e+00s)
# [TST] iter = 1700, cost = 9.28e+01, RMSE = 7.93e-01 (4.54e-01s)
# [TRN] iter = 1710, cost = 7.23e-01, |grad| = 2.08e+00 (4.96e+00s)
# [TST] iter = 1710, cost = 9.29e+01, RMSE = 7.94e-01 (1.62e+00s)
# [TRN] iter = 1720, cost = 7.19e-01, |grad| = 2.10e+00 (4.99e+00s)
# [TST] iter = 1720, cost = 9.31e+01, RMSE = 7.96e-01 (1.63e+00s)
# [TRN] iter = 1730, cost = 7.19e-01, |grad| = 1.63e+00 (1.69e+00s)
# [TST] iter = 1730, cost = 9.28e+01, RMSE = 7.93e-01 (4.54e-01s)
# [TRN] iter = 1740, cost = 7.12e-01, |grad| = 7.56e-01 (1.76e+00s)
# [TST] iter = 1740, cost = 9.26e+01, RMSE = 7.92e-01 (4.56e-01s)
# [TRN] iter = 1750, cost = 7.23e-01, |grad| = 1.27e+00 (4.87e+00s)
# [TST] iter = 1750, cost = 9.34e+01, RMSE = 7.98e-01 (1.62e+00s)
# [TRN] iter = 1760, cost = 7.14e-01, |grad| = 8.52e-01 (4.94e+00s)
# [TST] iter = 1760, cost = 9.32e+01, RMSE = 7.97e-01 (1.65e+00s)
# [TRN] iter = 1770, cost = 7.43e-01, |grad| = 3.97e+00 (1.71e+00s)
# [TST] iter = 1770, cost = 9.32e+01, RMSE = 7.96e-01 (4.54e-01s)
# [TRN] iter = 1780, cost = 7.27e-01, |grad| = 8.14e+00 (2.50e+00s)
# [TST] iter = 1780, cost = 9.28e+01, RMSE = 7.93e-01 (4.83e-01s)
# [TRN] iter = 1790, cost = 7.22e-01, |grad| = 2.05e+00 (1.79e+00s)
# [TST] iter = 1790, cost = 9.31e+01, RMSE = 7.96e-01 (4.78e-01s)
# [TRN] iter = 1800, cost = 7.08e-01, |grad| = 7.65e-01 (1.74e+00s)
# [TST] iter = 1800, cost = 9.27e+01, RMSE = 7.92e-01 (4.75e-01s)
# [TRN] iter = 1810, cost = 7.11e-01, |grad| = 5.65e+00 (1.73e+00s)
# [TST] iter = 1810, cost = 9.31e+01, RMSE = 7.95e-01 (4.61e-01s)
# [TRN] iter = 1820, cost = 7.27e-01, |grad| = 1.71e+00 (1.66e+00s)
# [TST] iter = 1820, cost = 9.33e+01, RMSE = 7.98e-01 (4.67e-01s)
# [TRN] iter = 1830, cost = 7.07e-01, |grad| = 4.22e+00 (1.70e+00s)
# [TST] iter = 1830, cost = 9.27e+01, RMSE = 7.93e-01 (4.70e-01s)
# [TRN] iter = 1840, cost = 7.09e-01, |grad| = 1.56e+00 (1.70e+00s)
# [TST] iter = 1840, cost = 9.29e+01, RMSE = 7.94e-01 (4.69e-01s)
# [TRN] iter = 1850, cost = 7.06e-01, |grad| = 1.25e+00 (1.73e+00s)
# [TST] iter = 1850, cost = 9.40e+01, RMSE = 8.03e-01 (4.80e-01s)
# [TRN] iter = 1860, cost = 7.41e-01, |grad| = 2.98e+00 (1.74e+00s)
# [TST] iter = 1860, cost = 9.36e+01, RMSE = 8.00e-01 (4.78e-01s)
# [TRN] iter = 1870, cost = 7.16e-01, |grad| = 1.12e+00 (1.75e+00s)
# [TST] iter = 1870, cost = 9.32e+01, RMSE = 7.96e-01 (4.75e-01s)
# [TRN] iter = 1880, cost = 7.36e-01, |grad| = 7.11e+00 (1.75e+00s)
# [TST] iter = 1880, cost = 9.43e+01, RMSE = 8.06e-01 (4.75e-01s)
# [TRN] iter = 1890, cost = 7.18e-01, |grad| = 2.88e+00 (1.74e+00s)
# [TST] iter = 1890, cost = 9.32e+01, RMSE = 7.97e-01 (4.75e-01s)
# [TRN] iter = 1900, cost = 7.31e-01, |grad| = 1.54e+00 (1.73e+00s)
# [TST] iter = 1900, cost = 9.30e+01, RMSE = 7.95e-01 (4.77e-01s)
# [TRN] iter = 1910, cost = 7.14e-01, |grad| = 8.95e-01 (1.75e+00s)
# [TST] iter = 1910, cost = 9.29e+01, RMSE = 7.94e-01 (4.79e-01s)
# [TRN] iter = 1920, cost = 7.01e-01, |grad| = 7.39e-01 (1.75e+00s)
# [TST] iter = 1920, cost = 9.27e+01, RMSE = 7.92e-01 (4.71e-01s)
# [TRN] iter = 1930, cost = 6.97e-01, |grad| = 8.61e-01 (1.73e+00s)
# [TST] iter = 1930, cost = 9.27e+01, RMSE = 7.92e-01 (4.78e-01s)
# [TRN] iter = 1940, cost = 6.94e-01, |grad| = 8.95e+00 (1.75e+00s)
# [TST] iter = 1940, cost = 9.29e+01, RMSE = 7.94e-01 (4.72e-01s)
# [TRN] iter = 1950, cost = 6.94e-01, |grad| = 4.03e+00 (1.73e+00s)
# [TST] iter = 1950, cost = 9.28e+01, RMSE = 7.93e-01 (4.75e-01s)
# [TRN] iter = 1960, cost = 7.11e-01, |grad| = 4.19e+00 (1.74e+00s)
# [TST] iter = 1960, cost = 9.40e+01, RMSE = 8.04e-01 (4.76e-01s)
# [TRN] iter = 1970, cost = 7.12e-01, |grad| = 1.80e+00 (1.74e+00s)
# [TST] iter = 1970, cost = 9.34e+01, RMSE = 7.98e-01 (4.75e-01s)
# [TRN] iter = 1980, cost = 6.93e-01, |grad| = 1.09e+01 (1.74e+00s)
# [TST] iter = 1980, cost = 9.27e+01, RMSE = 7.92e-01 (4.80e-01s)
# [TRN] iter = 1990, cost = 7.41e-01, |grad| = 2.76e+00 (1.74e+00s)
# [TST] iter = 1990, cost = 9.38e+01, RMSE = 8.01e-01 (4.70e-01s)
# [TRN] iter = 2000, cost = 7.14e-01, |grad| = 1.70e+00 (1.73e+00s)
# [TST] iter = 2000, cost = 9.32e+01, RMSE = 7.97e-01 (4.77e-01s)
# [TRN] iter = 2010, cost = 7.35e-01, |grad| = 9.10e+00 (1.75e+00s)
# [TST] iter = 2010, cost = 9.33e+01, RMSE = 7.97e-01 (4.75e-01s)
# [TRN] iter = 2020, cost = 8.11e-01, |grad| = 2.38e+01 (1.75e+00s)
# [TST] iter = 2020, cost = 9.62e+01, RMSE = 8.22e-01 (4.74e-01s)
# [TRN] iter = 2030, cost = 7.83e-01, |grad| = 3.24e+00 (1.75e+00s)
# [TST] iter = 2030, cost = 9.53e+01, RMSE = 8.14e-01 (4.77e-01s)
# [TRN] iter = 2040, cost = 7.34e-01, |grad| = 1.32e+00 (1.73e+00s)
# [TST] iter = 2040, cost = 9.35e+01, RMSE = 7.99e-01 (4.72e-01s)
# [TRN] iter = 2050, cost = 7.13e-01, |grad| = 6.85e+00 (1.75e+00s)
# [TST] iter = 2050, cost = 9.38e+01, RMSE = 8.02e-01 (4.77e-01s)
# [TRN] iter = 2060, cost = 6.93e-01, |grad| = 3.08e+00 (1.75e+00s)
# [TST] iter = 2060, cost = 9.27e+01, RMSE = 7.92e-01 (4.72e-01s)
# [TRN] iter = 2070, cost = 6.89e-01, |grad| = 1.14e+00 (1.75e+00s)
# [TST] iter = 2070, cost = 9.29e+01, RMSE = 7.94e-01 (4.70e-01s)
# [TRN] iter = 2080, cost = 7.04e-01, |grad| = 1.95e+00 (1.74e+00s)
# [TST] iter = 2080, cost = 9.29e+01, RMSE = 7.94e-01 (4.77e-01s)
# [TRN] iter = 2090, cost = 7.01e-01, |grad| = 2.14e+00 (1.75e+00s)
# [TST] iter = 2090, cost = 9.28e+01, RMSE = 7.93e-01 (4.74e-01s)
# [TRN] iter = 2100, cost = 6.88e-01, |grad| = 3.48e+00 (1.73e+00s)
# [TST] iter = 2100, cost = 9.26e+01, RMSE = 7.92e-01 (4.78e-01s)
# [TRN] iter = 2110, cost = 7.05e-01, |grad| = 2.94e+00 (1.77e+00s)
# [TST] iter = 2110, cost = 9.33e+01, RMSE = 7.97e-01 (4.75e-01s)
# [TRN] iter = 2120, cost = 7.04e-01, |grad| = 2.38e+01 (1.73e+00s)
# [TST] iter = 2120, cost = 9.27e+01, RMSE = 7.93e-01 (4.73e-01s)
# [TRN] iter = 2130, cost = 7.30e-01, |grad| = 1.34e+00 (1.75e+00s)
# [TST] iter = 2130, cost = 9.32e+01, RMSE = 7.96e-01 (4.77e-01s)
# [TRN] iter = 2140, cost = 6.94e-01, |grad| = 1.96e+00 (1.75e+00s)
# [TST] iter = 2140, cost = 9.27e+01, RMSE = 7.92e-01 (4.67e-01s)
# [TRN] iter = 2150, cost = 6.86e-01, |grad| = 1.00e+00 (1.67e+00s)
# [TST] iter = 2150, cost = 9.27e+01, RMSE = 7.92e-01 (4.53e-01s)
# [TRN] iter = 2160, cost = 6.83e-01, |grad| = 6.24e+00 (2.97e+02s)
# [TST] iter = 2160, cost = 9.26e+01, RMSE = 7.91e-01 (5.33e-01s)
# [TRN] iter = 2170, cost = 6.83e-01, |grad| = 9.04e-01 (4.99e+00s)
# [TST] iter = 2170, cost = 9.26e+01, RMSE = 7.92e-01 (1.61e+00s)
# [TRN] iter = 2180, cost = 6.80e-01, |grad| = 9.77e-01 (4.87e+00s)
# [TST] iter = 2180, cost = 9.26e+01, RMSE = 7.92e-01 (1.64e+00s)
# [TRN] iter = 2190, cost = 6.79e-01, |grad| = 7.36e-01 (1.70e+00s)
# [TST] iter = 2190, cost = 9.25e+01, RMSE = 7.91e-01 (4.55e-01s)
# [TRN] iter = 2200, cost = 6.84e-01, |grad| = 1.17e+00 (4.91e+00s)
# [TST] iter = 2200, cost = 9.30e+01, RMSE = 7.95e-01 (1.66e+00s)
# [TRN] iter = 2210, cost = 1.62e+00, |grad| = 7.41e+01 (4.98e+00s)
# [TST] iter = 2210, cost = 9.34e+01, RMSE = 7.98e-01 (1.63e+00s)
# [TRN] iter = 2220, cost = 9.40e-01, |grad| = 4.54e+00 (1.73e+00s)
# [TST] iter = 2220, cost = 9.73e+01, RMSE = 8.31e-01 (1.64e+00s)
# [TRN] iter = 2230, cost = 8.74e-01, |grad| = 2.74e+00 (1.69e+00s)
# [TST] iter = 2230, cost = 9.87e+01, RMSE = 8.44e-01 (4.55e-01s)
# [TRN] iter = 2240, cost = 7.94e-01, |grad| = 7.76e+00 (4.94e+00s)
# [TST] iter = 2240, cost = 9.46e+01, RMSE = 8.08e-01 (1.62e+00s)
# [TRN] iter = 2250, cost = 7.51e-01, |grad| = 1.88e+00 (5.00e+00s)
# [TST] iter = 2250, cost = 9.35e+01, RMSE = 7.99e-01 (1.68e+00s)
# [TRN] iter = 2260, cost = 7.26e-01, |grad| = 1.78e+00 (1.69e+00s)
# [TST] iter = 2260, cost = 9.32e+01, RMSE = 7.96e-01 (4.54e-01s)
# [TRN] iter = 2270, cost = 7.11e-01, |grad| = 8.79e-01 (1.88e+00s)
# [TST] iter = 2270, cost = 9.27e+01, RMSE = 7.92e-01 (4.56e-01s)
# [TRN] iter = 2280, cost = 7.43e-01, |grad| = 1.90e+00 (4.95e+00s)
# [TST] iter = 2280, cost = 9.34e+01, RMSE = 7.98e-01 (1.62e+00s)
# [TRN] iter = 2290, cost = 7.07e-01, |grad| = 8.36e+00 (4.91e+00s)
# [TST] iter = 2290, cost = 9.31e+01, RMSE = 7.96e-01 (1.63e+00s)
# [TRN] iter = 2300, cost = 6.96e-01, |grad| = 1.00e+00 (1.69e+00s)
# [TST] iter = 2300, cost = 9.28e+01, RMSE = 7.93e-01 (4.50e-01s)
# [TRN] iter = 2310, cost = 6.89e-01, |grad| = 5.67e-01 (2.86e+02s)
# [TST] iter = 2310, cost = 9.26e+01, RMSE = 7.92e-01 (4.71e-01s)
# [TRN] iter = 2320, cost = 6.83e-01, |grad| = 7.71e-01 (4.98e+00s)
# [TST] iter = 2320, cost = 9.26e+01, RMSE = 7.92e-01 (1.63e+00s)
# [TRN] iter = 2330, cost = 6.88e-01, |grad| = 1.08e+00 (4.92e+00s)
# [TST] iter = 2330, cost = 9.28e+01, RMSE = 7.93e-01 (1.64e+00s)
# [TRN] iter = 2340, cost = 6.79e-01, |grad| = 1.02e+00 (1.70e+00s)
# [TST] iter = 2340, cost = 9.27e+01, RMSE = 7.92e-01 (4.52e-01s)
# [TRN] iter = 2350, cost = 6.78e-01, |grad| = 8.11e-01 (2.87e+02s)
# [TST] iter = 2350, cost = 9.28e+01, RMSE = 7.93e-01 (8.03e-01s)
# [TRN] iter = 2360, cost = 6.75e-01, |grad| = 4.28e+00 (5.00e+00s)
# [TST] iter = 2360, cost = 9.27e+01, RMSE = 7.92e-01 (1.63e+00s)
# [TRN] iter = 2370, cost = 6.69e-01, |grad| = 1.89e+00 (4.93e+00s)
# [TST] iter = 2370, cost = 9.26e+01, RMSE = 7.91e-01 (1.63e+00s)
# [TRN] iter = 2380, cost = 6.67e-01, |grad| = 7.44e-01 (1.69e+00s)
# [TST] iter = 2380, cost = 9.26e+01, RMSE = 7.91e-01 (4.53e-01s)
# [TRN] iter = 2390, cost = 6.64e-01, |grad| = 7.18e-01 (2.15e+00s)
# [TST] iter = 2390, cost = 9.25e+01, RMSE = 7.91e-01 (4.89e-01s)
# [TRN] iter = 2400, cost = 6.62e-01, |grad| = 1.96e+00 (1.76e+00s)
# [TST] iter = 2400, cost = 9.26e+01, RMSE = 7.91e-01 (4.83e-01s)
# [TRN] iter = 2410, cost = 6.81e-01, |grad| = 2.82e+00 (1.75e+00s)
# [TST] iter = 2410, cost = 9.37e+01, RMSE = 8.01e-01 (4.81e-01s)
# [TRN] iter = 2420, cost = 6.84e-01, |grad| = 4.49e+00 (1.79e+00s)
# [TST] iter = 2420, cost = 9.25e+01, RMSE = 7.91e-01 (4.84e-01s)
# [TRN] iter = 2430, cost = 6.67e-01, |grad| = 9.00e-01 (1.79e+00s)
# [TST] iter = 2430, cost = 9.34e+01, RMSE = 7.99e-01 (4.81e-01s)
# [TRN] iter = 2440, cost = 6.66e-01, |grad| = 1.53e+00 (1.79e+00s)
# [TST] iter = 2440, cost = 9.24e+01, RMSE = 7.90e-01 (4.84e-01s)
# [TRN] iter = 2450, cost = 6.68e-01, |grad| = 1.49e+00 (1.82e+00s)
# [TST] iter = 2450, cost = 9.26e+01, RMSE = 7.92e-01 (4.91e-01s)
# [TRN] iter = 2460, cost = 6.69e-01, |grad| = 1.39e+00 (1.84e+00s)
# [TST] iter = 2460, cost = 9.30e+01, RMSE = 7.95e-01 (4.94e-01s)
# [TRN] iter = 2470, cost = 6.73e-01, |grad| = 1.33e+00 (1.84e+00s)
# [TST] iter = 2470, cost = 9.26e+01, RMSE = 7.92e-01 (4.97e-01s)
# [TRN] iter = 2480, cost = 6.76e-01, |grad| = 6.46e+00 (1.82e+00s)
# [TST] iter = 2480, cost = 9.29e+01, RMSE = 7.94e-01 (4.89e-01s)
# [TRN] iter = 2490, cost = 6.67e-01, |grad| = 9.61e-01 (1.82e+00s)
# [TST] iter = 2490, cost = 9.26e+01, RMSE = 7.91e-01 (4.89e-01s)
# [TRN] iter = 2500, cost = 6.58e-01, |grad| = 2.96e+00 (1.83e+00s)
# [TST] iter = 2500, cost = 9.26e+01, RMSE = 7.92e-01 (4.94e-01s)
# [TRN] iter = 2510, cost = 6.54e-01, |grad| = 7.02e-01 (1.85e+00s)
# [TST] iter = 2510, cost = 9.25e+01, RMSE = 7.91e-01 (4.94e-01s)
# [TRN] iter = 2520, cost = 7.02e-01, |grad| = 5.10e+00 (1.86e+00s)
# [TST] iter = 2520, cost = 9.36e+01, RMSE = 8.00e-01 (4.99e-01s)
# [TRN] iter = 2530, cost = 6.67e-01, |grad| = 1.00e+00 (1.85e+00s)
# [TST] iter = 2530, cost = 9.26e+01, RMSE = 7.92e-01 (4.97e-01s)
# [TRN] iter = 2540, cost = 6.59e-01, |grad| = 8.79e-01 (1.84e+00s)
# [TST] iter = 2540, cost = 9.26e+01, RMSE = 7.91e-01 (4.94e-01s)
# [TRN] iter = 2550, cost = 6.58e-01, |grad| = 1.23e+00 (1.84e+00s)
# [TST] iter = 2550, cost = 9.26e+01, RMSE = 7.91e-01 (4.91e-01s)
# [TRN] iter = 2560, cost = 6.52e-01, |grad| = 6.69e-01 (1.83e+00s)
# [TST] iter = 2560, cost = 9.25e+01, RMSE = 7.91e-01 (4.94e-01s)
# [TRN] iter = 2570, cost = 6.52e-01, |grad| = 1.32e+00 (1.83e+00s)
# [TST] iter = 2570, cost = 9.26e+01, RMSE = 7.92e-01 (4.87e-01s)
# [TRN] iter = 2580, cost = 6.55e-01, |grad| = 2.86e+00 (1.84e+00s)
# [TST] iter = 2580, cost = 9.27e+01, RMSE = 7.92e-01 (4.92e-01s)
# [TRN] iter = 2590, cost = 6.49e-01, |grad| = 9.85e-01 (1.82e+00s)
# [TST] iter = 2590, cost = 9.25e+01, RMSE = 7.91e-01 (4.87e-01s)
# [TRN] iter = 2600, cost = 6.59e-01, |grad| = 1.97e+00 (1.85e+00s)
# [TST] iter = 2600, cost = 9.26e+01, RMSE = 7.91e-01 (4.87e-01s)
# [TRN] iter = 2610, cost = 6.48e-01, |grad| = 8.45e-01 (1.83e+00s)
# [TST] iter = 2610, cost = 9.28e+01, RMSE = 7.93e-01 (4.86e-01s)
# [TRN] iter = 2620, cost = 7.74e-01, |grad| = 2.10e+00 (1.83e+00s)
# [TST] iter = 2620, cost = 9.37e+01, RMSE = 8.01e-01 (4.91e-01s)
# [TRN] iter = 2630, cost = 7.19e-01, |grad| = 1.36e+00 (1.82e+00s)
# [TST] iter = 2630, cost = 9.27e+01, RMSE = 7.92e-01 (4.86e-01s)
# [TRN] iter = 2640, cost = 6.76e-01, |grad| = 1.60e+00 (1.83e+00s)
# [TST] iter = 2640, cost = 9.27e+01, RMSE = 7.92e-01 (4.92e-01s)
# [TRN] iter = 2650, cost = 6.60e-01, |grad| = 6.84e-01 (1.84e+00s)
# [TST] iter = 2650, cost = 9.26e+01, RMSE = 7.91e-01 (4.89e-01s)
# [TRN] iter = 2660, cost = 6.54e-01, |grad| = 1.85e+00 (1.81e+00s)
# [TST] iter = 2660, cost = 9.26e+01, RMSE = 7.91e-01 (4.91e-01s)
# [TRN] iter = 2670, cost = 6.50e-01, |grad| = 9.63e-01 (1.82e+00s)
# [TST] iter = 2670, cost = 9.27e+01, RMSE = 7.93e-01 (4.92e-01s)
# [TRN] iter = 2680, cost = 6.55e-01, |grad| = 2.11e+00 (1.82e+00s)
# [TST] iter = 2680, cost = 9.27e+01, RMSE = 7.92e-01 (4.87e-01s)
# [TRN] iter = 2690, cost = 6.49e-01, |grad| = 1.09e+00 (1.82e+00s)
# [TST] iter = 2690, cost = 9.27e+01, RMSE = 7.92e-01 (4.89e-01s)
# [TRN] iter = 2700, cost = 6.45e-01, |grad| = 9.77e-01 (1.82e+00s)
# [TST] iter = 2700, cost = 9.26e+01, RMSE = 7.92e-01 (4.95e-01s)
# [TRN] iter = 2710, cost = 6.72e-01, |grad| = 2.63e+00 (1.84e+00s)
# [TST] iter = 2710, cost = 9.36e+01, RMSE = 8.00e-01 (4.94e-01s)
# [TRN] iter = 2720, cost = 6.89e-01, |grad| = 1.41e+00 (1.81e+00s)
# [TST] iter = 2720, cost = 9.24e+01, RMSE = 7.90e-01 (4.77e-01s)
# [TRN] iter = 2730, cost = 6.68e-01, |grad| = 1.23e+00 (1.76e+00s)
# [TST] iter = 2730, cost = 9.27e+01, RMSE = 7.92e-01 (4.86e-01s)
# [TRN] iter = 2740, cost = 6.58e-01, |grad| = 1.14e+00 (1.74e+00s)
# [TST] iter = 2740, cost = 9.29e+01, RMSE = 7.94e-01 (4.58e-01s)
# [TRN] iter = 2750, cost = 6.54e-01, |grad| = 5.98e+00 (5.03e+00s)
# [TST] iter = 2750, cost = 9.26e+01, RMSE = 7.91e-01 (1.63e+00s)
# [TRN] iter = 2760, cost = 6.49e-01, |grad| = 1.83e+00 (5.08e+00s)
# [TST] iter = 2760, cost = 9.26e+01, RMSE = 7.91e-01 (1.65e+00s)
# [TRN] iter = 2770, cost = 6.44e-01, |grad| = 4.32e+00 (1.85e+00s)
# [TST] iter = 2770, cost = 9.27e+01, RMSE = 7.93e-01 (4.75e-01s)
# [TRN] iter = 2780, cost = 8.32e-01, |grad| = 4.96e+00 (5.08e+00s)
# [TST] iter = 2780, cost = 9.77e+01, RMSE = 8.35e-01 (1.66e+00s)
# [TRN] iter = 2790, cost = 8.11e-01, |grad| = 2.57e+00 (4.96e+00s)
# [TST] iter = 2790, cost = 9.41e+01, RMSE = 8.04e-01 (1.65e+00s)
# [TRN] iter = 2800, cost = 7.26e-01, |grad| = 3.70e+00 (4.93e+00s)
# [TST] iter = 2800, cost = 9.34e+01, RMSE = 7.98e-01 (1.64e+00s)
# [TRN] iter = 2810, cost = 6.83e-01, |grad| = 1.66e+00 (4.95e+00s)
# [TST] iter = 2810, cost = 9.27e+01, RMSE = 7.93e-01 (1.63e+00s)
# [TRN] iter = 2820, cost = 6.67e-01, |grad| = 1.16e+00 (4.93e+00s)
# [TST] iter = 2820, cost = 9.27e+01, RMSE = 7.92e-01 (1.63e+00s)
# [TRN] iter = 2830, cost = 6.59e-01, |grad| = 2.11e+00 (4.91e+00s)
# [TST] iter = 2830, cost = 9.26e+01, RMSE = 7.92e-01 (1.62e+00s)
# [TRN] iter = 2840, cost = 6.52e-01, |grad| = 6.39e-01 (4.89e+00s)
# [TST] iter = 2840, cost = 9.26e+01, RMSE = 7.92e-01 (1.63e+00s)
# [TRN] iter = 2850, cost = 6.49e-01, |grad| = 1.35e+00 (4.91e+00s)
# [TST] iter = 2850, cost = 9.26e+01, RMSE = 7.91e-01 (1.62e+00s)
# [TRN] iter = 2860, cost = 6.44e-01, |grad| = 1.79e+00 (4.83e+00s)
# [TST] iter = 2860, cost = 9.26e+01, RMSE = 7.91e-01 (1.63e+00s)
# [TRN] iter = 2870, cost = 6.42e-01, |grad| = 6.31e-01 (4.90e+00s)
# [TST] iter = 2870, cost = 9.26e+01, RMSE = 7.91e-01 (1.63e+00s)
# [TRN] iter = 2880, cost = 6.39e-01, |grad| = 5.23e-01 (4.93e+00s)
# [TST] iter = 2880, cost = 9.25e+01, RMSE = 7.91e-01 (1.65e+00s)
# [TRN] iter = 2890, cost = 6.60e-01, |grad| = 3.34e+00 (1.69e+00s)
# [TST] iter = 2890, cost = 9.27e+01, RMSE = 7.92e-01 (4.62e-01s)
# [TRN] iter = 2900, cost = 6.60e-01, |grad| = 1.21e+00 (1.73e+00s)
# [TST] iter = 2900, cost = 9.26e+01, RMSE = 7.91e-01 (4.63e-01s)
# [TRN] iter = 2910, cost = 6.50e-01, |grad| = 3.98e+00 (1.70e+00s)
# [TST] iter = 2910, cost = 9.27e+01, RMSE = 7.93e-01 (4.63e-01s)
# [TRN] iter = 2920, cost = 6.56e-01, |grad| = 1.29e+01 (1.73e+00s)
# [TST] iter = 2920, cost = 9.27e+01, RMSE = 7.92e-01 (4.71e-01s)
# [TRN] iter = 2930, cost = 6.52e-01, |grad| = 2.61e+00 (1.72e+00s)
# [TST] iter = 2930, cost = 9.34e+01, RMSE = 7.98e-01 (4.69e-01s)
# [TRN] iter = 2940, cost = 6.85e-01, |grad| = 7.01e+00 (1.74e+00s)
# [TST] iter = 2940, cost = 9.47e+01, RMSE = 8.09e-01 (4.70e-01s)
# [TRN] iter = 2950, cost = 6.63e-01, |grad| = 1.05e+00 (1.73e+00s)
# [TST] iter = 2950, cost = 9.32e+01, RMSE = 7.96e-01 (4.67e-01s)
# [TRN] iter = 2960, cost = 6.48e-01, |grad| = 5.70e-01 (1.77e+00s)
# [TST] iter = 2960, cost = 9.29e+01, RMSE = 7.94e-01 (4.74e-01s)
# [TRN] iter = 2970, cost = 6.45e-01, |grad| = 9.21e+00 (1.75e+00s)
# [TST] iter = 2970, cost = 9.28e+01, RMSE = 7.93e-01 (4.70e-01s)
# [TRN] iter = 2980, cost = 6.41e-01, |grad| = 5.82e-01 (1.75e+00s)
# [TST] iter = 2980, cost = 9.28e+01, RMSE = 7.93e-01 (4.67e-01s)
# [TRN] iter = 2990, cost = 6.35e-01, |grad| = 1.20e+00 (1.76e+00s)
# [TST] iter = 2990, cost = 9.26e+01, RMSE = 7.92e-01 (4.73e-01s)
# [TRN] iter = 3000, cost = 6.31e-01, |grad| = 1.35e+00 (1.75e+00s)
# [TST] iter = 3000, cost = 9.27e+01, RMSE = 7.92e-01 (4.77e-01s)
# [TRN] iter = 3010, cost = 1.02e+00, |grad| = 5.02e+01 (1.74e+00s)
# [TST] iter = 3010, cost = 1.12e+02, RMSE = 9.61e-01 (4.65e-01s)
# [TRN] iter = 3020, cost = 8.43e-01, |grad| = 2.68e+00 (1.75e+00s)
# [TST] iter = 3020, cost = 9.56e+01, RMSE = 8.17e-01 (4.66e-01s)
# [TRN] iter = 3030, cost = 7.63e-01, |grad| = 4.61e+00 (1.74e+00s)
# [TST] iter = 3030, cost = 9.48e+01, RMSE = 8.10e-01 (4.68e-01s)
# [TRN] iter = 3040, cost = 6.98e-01, |grad| = 1.81e+00 (1.75e+00s)
# [TST] iter = 3040, cost = 9.34e+01, RMSE = 7.99e-01 (4.68e-01s)
# [TRN] iter = 3050, cost = 6.79e-01, |grad| = 6.27e-01 (1.74e+00s)
# [TST] iter = 3050, cost = 9.33e+01, RMSE = 7.98e-01 (4.65e-01s)
# [TRN] iter = 3060, cost = 6.63e-01, |grad| = 2.28e+00 (1.74e+00s)
# [TST] iter = 3060, cost = 9.29e+01, RMSE = 7.94e-01 (4.68e-01s)
# [TRN] iter = 3070, cost = 6.62e-01, |grad| = 2.06e+00 (1.74e+00s)
# [TST] iter = 3070, cost = 9.32e+01, RMSE = 7.96e-01 (4.63e-01s)
# [TRN] iter = 3080, cost = 6.56e-01, |grad| = 1.58e+00 (1.73e+00s)
# [TST] iter = 3080, cost = 9.31e+01, RMSE = 7.96e-01 (4.65e-01s)
# [TRN] iter = 3090, cost = 6.48e-01, |grad| = 1.87e+00 (1.72e+00s)
# [TST] iter = 3090, cost = 9.27e+01, RMSE = 7.93e-01 (4.66e-01s)
# [TRN] iter = 3100, cost = 6.48e-01, |grad| = 2.03e+00 (1.72e+00s)
# [TST] iter = 3100, cost = 9.36e+01, RMSE = 8.00e-01 (4.67e-01s)
# [TRN] iter = 3110, cost = 6.50e-01, |grad| = 1.07e+00 (1.73e+00s)
# [TST] iter = 3110, cost = 9.30e+01, RMSE = 7.95e-01 (4.72e-01s)
# [TRN] iter = 3120, cost = 6.48e-01, |grad| = 2.17e+00 (1.74e+00s)
# [TST] iter = 3120, cost = 9.26e+01, RMSE = 7.91e-01 (4.67e-01s)
# [TRN] iter = 3130, cost = 6.42e-01, |grad| = 2.10e+00 (1.73e+00s)
# [TST] iter = 3130, cost = 9.27e+01, RMSE = 7.92e-01 (4.66e-01s)
# [TRN] iter = 3140, cost = 6.41e-01, |grad| = 4.45e+00 (1.74e+00s)
# [TST] iter = 3140, cost = 9.27e+01, RMSE = 7.92e-01 (4.68e-01s)
# [TRN] iter = 3150, cost = 6.36e-01, |grad| = 1.04e+00 (1.73e+00s)
# [TST] iter = 3150, cost = 9.27e+01, RMSE = 7.92e-01 (4.67e-01s)
# [TRN] iter = 3160, cost = 6.39e-01, |grad| = 1.44e+01 (1.73e+00s)
# [TST] iter = 3160, cost = 9.25e+01, RMSE = 7.91e-01 (4.66e-01s)
# [TRN] iter = 3170, cost = 6.52e-01, |grad| = 1.11e+00 (1.75e+00s)
# [TST] iter = 3170, cost = 9.27e+01, RMSE = 7.93e-01 (4.64e-01s)
# [TRN] iter = 3180, cost = 6.44e-01, |grad| = 3.65e+00 (1.75e+00s)
# [TST] iter = 3180, cost = 9.25e+01, RMSE = 7.91e-01 (4.66e-01s)
# [TRN] iter = 3190, cost = 6.37e-01, |grad| = 3.19e+00 (1.74e+00s)
# [TST] iter = 3190, cost = 9.27e+01, RMSE = 7.93e-01 (4.70e-01s)
# [TRN] iter = 3200, cost = 6.39e-01, |grad| = 8.30e-01 (1.73e+00s)
# [TST] iter = 3200, cost = 9.29e+01, RMSE = 7.94e-01 (4.71e-01s)
# [TRN] iter = 3210, cost = 6.32e-01, |grad| = 5.54e-01 (1.73e+00s)
# [TST] iter = 3210, cost = 9.27e+01, RMSE = 7.92e-01 (4.74e-01s)
# [TRN] iter = 3220, cost = 6.31e-01, |grad| = 5.48e-01 (1.73e+00s)
# [TST] iter = 3220, cost = 9.28e+01, RMSE = 7.94e-01 (4.70e-01s)
# [TRN] iter = 3230, cost = 6.63e-01, |grad| = 1.17e+01 (1.73e+00s)
# [TST] iter = 3230, cost = 9.38e+01, RMSE = 8.01e-01 (4.72e-01s)
# [TRN] iter = 3240, cost = 6.46e-01, |grad| = 1.24e+00 (1.71e+00s)
# [TST] iter = 3240, cost = 9.25e+01, RMSE = 7.91e-01 (4.72e-01s)
# [TRN] iter = 3250, cost = 6.39e-01, |grad| = 2.49e+00 (1.76e+00s)
# [TST] iter = 3250, cost = 9.26e+01, RMSE = 7.92e-01 (4.69e-01s)
# [TRN] iter = 3260, cost = 6.31e-01, |grad| = 6.57e+00 (1.75e+00s)
# [TST] iter = 3260, cost = 9.27e+01, RMSE = 7.92e-01 (4.74e-01s)
# [TRN] iter = 3270, cost = 6.37e-01, |grad| = 9.50e-01 (1.74e+00s)
# [TST] iter = 3270, cost = 9.27e+01, RMSE = 7.92e-01 (4.71e-01s)
# [TRN] iter = 3280, cost = 6.30e-01, |grad| = 1.33e+00 (1.74e+00s)
# [TST] iter = 3280, cost = 9.25e+01, RMSE = 7.91e-01 (4.72e-01s)
# [TRN] iter = 3290, cost = 6.28e-01, |grad| = 1.41e+00 (1.74e+00s)
# [TST] iter = 3290, cost = 9.26e+01, RMSE = 7.91e-01 (4.74e-01s)
# [TRN] iter = 3300, cost = 6.26e-01, |grad| = 1.61e+00 (1.74e+00s)
# [TST] iter = 3300, cost = 9.26e+01, RMSE = 7.92e-01 (4.74e-01s)
# [TRN] iter = 3310, cost = 6.23e-01, |grad| = 1.29e+00 (1.72e+00s)
# [TST] iter = 3310, cost = 9.26e+01, RMSE = 7.91e-01 (4.72e-01s)
# [TRN] iter = 3320, cost = 6.45e-01, |grad| = 9.46e-01 (1.76e+00s)
# [TST] iter = 3320, cost = 9.26e+01, RMSE = 7.91e-01 (4.73e-01s)
# [TRN] iter = 3330, cost = 6.40e-01, |grad| = 7.00e-01 (1.73e+00s)
# [TST] iter = 3330, cost = 9.26e+01, RMSE = 7.91e-01 (4.77e-01s)
# [TRN] iter = 3340, cost = 6.33e-01, |grad| = 1.10e+01 (1.75e+00s)
# [TST] iter = 3340, cost = 9.28e+01, RMSE = 7.93e-01 (4.88e-01s)
# [TRN] iter = 3350, cost = 6.31e-01, |grad| = 7.40e-01 (1.76e+00s)
# [TST] iter = 3350, cost = 9.28e+01, RMSE = 7.93e-01 (4.93e-01s)
# [TRN] iter = 3360, cost = 6.23e-01, |grad| = 2.01e+00 (1.74e+00s)
# [TST] iter = 3360, cost = 9.26e+01, RMSE = 7.92e-01 (4.77e-01s)
# [TRN] iter = 3370, cost = 6.45e-01, |grad| = 5.98e+00 (1.76e+00s)
# [TST] iter = 3370, cost = 9.51e+01, RMSE = 8.13e-01 (4.84e-01s)
# [TRN] iter = 3380, cost = 6.57e-01, |grad| = 8.84e+00 (1.74e+00s)
# [TST] iter = 3380, cost = 9.30e+01, RMSE = 7.95e-01 (4.77e-01s)
# [TRN] iter = 3390, cost = 6.55e-01, |grad| = 9.14e+00 (1.75e+00s)
# [TST] iter = 3390, cost = 9.29e+01, RMSE = 7.94e-01 (4.78e-01s)
# [TRN] iter = 3400, cost = 6.49e-01, |grad| = 2.48e+00 (1.72e+00s)
# [TST] iter = 3400, cost = 9.27e+01, RMSE = 7.92e-01 (4.79e-01s)
# [TRN] iter = 3410, cost = 6.37e-01, |grad| = 1.03e+00 (1.74e+00s)
# [TST] iter = 3410, cost = 9.28e+01, RMSE = 7.93e-01 (4.87e-01s)
# [TRN] iter = 3420, cost = 6.28e-01, |grad| = 8.31e-01 (1.78e+00s)
# [TST] iter = 3420, cost = 9.25e+01, RMSE = 7.91e-01 (4.87e-01s)
# [TRN] iter = 3430, cost = 6.23e-01, |grad| = 8.95e-01 (1.75e+00s)
# [TST] iter = 3430, cost = 9.26e+01, RMSE = 7.91e-01 (4.81e-01s)
# [TRN] iter = 3440, cost = 6.23e-01, |grad| = 2.37e+00 (1.74e+00s)
# [TST] iter = 3440, cost = 9.26e+01, RMSE = 7.92e-01 (4.84e-01s)
# [TRN] iter = 3450, cost = 6.27e-01, |grad| = 2.38e+00 (1.74e+00s)
# [TST] iter = 3450, cost = 9.34e+01, RMSE = 7.98e-01 (4.81e-01s)
# [TRN] iter = 3460, cost = 6.31e-01, |grad| = 2.41e+00 (1.75e+00s)
# [TST] iter = 3460, cost = 9.26e+01, RMSE = 7.91e-01 (4.83e-01s)
# [TRN] iter = 3470, cost = 6.34e-01, |grad| = 2.69e+00 (1.75e+00s)
# [TST] iter = 3470, cost = 9.30e+01, RMSE = 7.95e-01 (4.86e-01s)
# [TRN] iter = 3480, cost = 6.25e-01, |grad| = 7.49e-01 (1.77e+00s)
# [TST] iter = 3480, cost = 9.26e+01, RMSE = 7.92e-01 (4.85e-01s)
# [TRN] iter = 3490, cost = 6.18e-01, |grad| = 8.31e-01 (1.75e+00s)
# [TST] iter = 3490, cost = 9.26e+01, RMSE = 7.92e-01 (4.79e-01s)
# [TRN] iter = 3500, cost = 6.23e-01, |grad| = 2.12e+00 (1.77e+00s)
# [TST] iter = 3500, cost = 9.29e+01, RMSE = 7.94e-01 (4.76e-01s)
# [TRN] iter = 3510, cost = 6.18e-01, |grad| = 2.46e+00 (1.76e+00s)
# [TST] iter = 3510, cost = 9.28e+01, RMSE = 7.93e-01 (4.86e-01s)
# [TRN] iter = 3520, cost = 6.50e-01, |grad| = 2.10e+00 (1.77e+00s)
# [TST] iter = 3520, cost = 9.33e+01, RMSE = 7.97e-01 (4.85e-01s)
# [TRN] iter = 3530, cost = 6.41e-01, |grad| = 1.18e+00 (1.75e+00s)
# [TST] iter = 3530, cost = 9.27e+01, RMSE = 7.93e-01 (4.84e-01s)
# [TRN] iter = 3540, cost = 6.28e-01, |grad| = 1.36e+00 (1.75e+00s)
# [TST] iter = 3540, cost = 9.25e+01, RMSE = 7.91e-01 (4.86e-01s)
# [TRN] iter = 3550, cost = 6.23e-01, |grad| = 1.31e+00 (1.77e+00s)
# [TST] iter = 3550, cost = 9.29e+01, RMSE = 7.94e-01 (4.81e-01s)
# [TRN] iter = 3560, cost = 6.23e-01, |grad| = 1.18e+00 (1.75e+00s)
# [TST] iter = 3560, cost = 9.27e+01, RMSE = 7.92e-01 (4.73e-01s)
# [TRN] iter = 3570, cost = 6.18e-01, |grad| = 7.51e-01 (1.70e+00s)
# [TST] iter = 3570, cost = 9.27e+01, RMSE = 7.92e-01 (4.65e-01s)
# [TRN] iter = 3580, cost = 6.20e-01, |grad| = 1.70e+00 (2.88e+02s)
# [TST] iter = 3580, cost = 9.28e+01, RMSE = 7.93e-01 (4.70e-01s)
# [TRN] iter = 3590, cost = 6.53e-01, |grad| = 8.65e+00 (4.94e+00s)
# [TST] iter = 3590, cost = 9.34e+01, RMSE = 7.98e-01 (1.64e+00s)
# [TRN] iter = 3600, cost = 6.61e-01, |grad| = 1.26e+00 (4.48e+00s)
# [TST] iter = 3600, cost = 9.32e+01, RMSE = 7.96e-01 (1.63e+00s)
# [TRN] iter = 3610, cost = 6.48e-01, |grad| = 1.35e+00 (1.68e+00s)
# [TST] iter = 3610, cost = 9.29e+01, RMSE = 7.94e-01 (4.50e-01s)
# [TRN] iter = 3620, cost = 6.30e-01, |grad| = 7.28e-01 (4.95e+00s)
# [TST] iter = 3620, cost = 9.27e+01, RMSE = 7.92e-01 (1.61e+00s)
# [TRN] iter = 3630, cost = 6.22e-01, |grad| = 1.12e+00 (5.05e+00s)
# [TST] iter = 3630, cost = 9.26e+01, RMSE = 7.92e-01 (1.64e+00s)
# [TRN] iter = 3640, cost = 6.22e-01, |grad| = 1.84e+00 (1.93e+00s)
# [TST] iter = 3640, cost = 9.29e+01, RMSE = 7.94e-01 (1.63e+00s)
# [TRN] iter = 3650, cost = 6.17e-01, |grad| = 3.29e+00 (1.71e+00s)
# [TST] iter = 3650, cost = 9.29e+01, RMSE = 7.94e-01 (4.53e-01s)
# [TRN] iter = 3660, cost = 6.97e-01, |grad| = 4.85e+00 (4.95e+00s)
# [TST] iter = 3660, cost = 9.77e+01, RMSE = 8.35e-01 (1.63e+00s)
# [TRN] iter = 3670, cost = 6.81e-01, |grad| = 7.81e+00 (4.91e+00s)
# [TST] iter = 3670, cost = 9.31e+01, RMSE = 7.96e-01 (1.62e+00s)
# [TRN] iter = 3680, cost = 6.58e-01, |grad| = 7.54e-01 (1.82e+00s)
# [TST] iter = 3680, cost = 9.34e+01, RMSE = 7.98e-01 (1.63e+00s)
# [TRN] iter = 3690, cost = 6.41e-01, |grad| = 5.79e-01 (1.72e+00s)
# [TST] iter = 3690, cost = 9.28e+01, RMSE = 7.93e-01 (4.51e-01s)
# [TRN] iter = 3700, cost = 6.27e-01, |grad| = 1.22e+00 (4.97e+00s)
# ...
# [TRN] iter = 3770, cost = 6.40e-01, |grad| = 1.12e+00 (1.72e+00s)
# [TST] iter = 3770, cost = 9.26e+01, RMSE = 7.92e-01 (4.54e-01s)
# [TRN] iter = 3780, cost = 6.29e-01, |grad| = 2.18e+00 (4.95e+00s)
# [TST] iter = 3780, cost = 9.25e+01, RMSE = 7.91e-01 (1.63e+00s)
# [TRN] iter = 3790, cost = 6.22e-01, |grad| = 1.13e+00 (4.91e+00s)
# [TST] iter = 3790, cost = 9.26e+01, RMSE = 7.92e-01 (1.64e+00s)
# [TRN] iter = 3800, cost = 6.18e-01, |grad| = 2.60e+00 (1.69e+00s)
# [TST] iter = 3800, cost = 9.27e+01, RMSE = 7.93e-01 (4.50e-01s)
# [TRN] iter = 3810, cost = 6.17e-01, |grad| = 2.50e+00 (1.73e+00s)
# [TST] iter = 3810, cost = 9.29e+01, RMSE = 7.94e-01 (4.55e-01s)
# [TRN] iter = 3820, cost = 6.22e-01, |grad| = 3.03e+00 (4.94e+00s)
# [TST] iter = 3820, cost = 9.27e+01, RMSE = 7.93e-01 (1.65e+00s)
# [TRN] iter = 3830, cost = 6.18e-01, |grad| = 8.76e-01 (5.01e+00s)
# [TST] iter = 3830, cost = 9.26e+01, RMSE = 7.92e-01 (1.63e+00s)
# [TRN] iter = 3840, cost = 6.17e-01, |grad| = 6.60e+00 (1.72e+00s)
# [TST] iter = 3840, cost = 9.28e+01, RMSE = 7.93e-01 (4.50e-01s)
# [TRN] iter = 3850, cost = 6.18e-01, |grad| = 1.11e+00 (1.75e+00s)
# [TST] iter = 3850, cost = 9.32e+01, RMSE = 7.97e-01 (4.60e-01s)
# [TRN] iter = 3860, cost = 6.14e-01, |grad| = 9.87e-01 (5.02e+00s)
# [TST] iter = 3860, cost = 9.32e+01, RMSE = 7.96e-01 (1.69e+00s)
# [TRN] iter = 3870, cost = 6.20e-01, |grad| = 2.44e+00 (4.96e+00s)
# [TST] iter = 3870, cost = 9.31e+01, RMSE = 7.96e-01 (1.64e+00s)
# [TRN] iter = 3880, cost = 6.16e-01, |grad| = 2.04e+00 (1.70e+00s)
# [TST] iter = 3880, cost = 9.29e+01, RMSE = 7.94e-01 (4.61e-01s)
# [TRN] iter = 3890, cost = 6.11e-01, |grad| = 1.27e+00 (1.79e+00s)
# [TST] iter = 3890, cost = 9.28e+01, RMSE = 7.93e-01 (4.60e-01s)
# [TRN] iter = 3900, cost = 6.12e-01, |grad| = 1.31e+00 (5.04e+00s)
# [TST] iter = 3900, cost = 9.28e+01, RMSE = 7.93e-01 (1.64e+00s)
# [TRN] iter = 3910, cost = 6.41e-01, |grad| = 8.33e+00 (4.95e+00s)
# [TST] iter = 3910, cost = 9.30e+01, RMSE = 7.95e-01 (1.63e+00s)
# [TRN] iter = 3920, cost = 6.24e-01, |grad| = 9.85e-01 (1.71e+00s)
# [TST] iter = 3920, cost = 9.29e+01, RMSE = 7.94e-01 (4.62e-01s)
# [TRN] iter = 3930, cost = 6.25e-01, |grad| = 4.04e+00 (1.80e+00s)
# [TST] iter = 3930, cost = 9.29e+01, RMSE = 7.94e-01 (4.55e-01s)
# [TRN] iter = 3940, cost = 6.16e-01, |grad| = 7.62e-01 (5.13e+00s)
# [TST] iter = 3940, cost = 9.32e+01, RMSE = 7.97e-01 (1.64e+00s)
# [TRN] iter = 3950, cost = 6.08e-01, |grad| = 1.23e+00 (5.01e+00s)
# [TST] iter = 3950, cost = 9.29e+01, RMSE = 7.94e-01 (1.64e+00s)
# [TRN] iter = 3960, cost = 6.21e-01, |grad| = 2.63e+00 (1.68e+00s)
# [TST] iter = 3960, cost = 9.32e+01, RMSE = 7.96e-01 (4.54e-01s)
# [TRN] iter = 3970, cost = 6.19e-01, |grad| = 2.27e+00 (2.86e+02s)
# [TST] iter = 3970, cost = 9.29e+01, RMSE = 7.94e-01 (4.71e-01s)
# [TRN] iter = 3980, cost = 6.09e-01, |grad| = 8.55e-01 (4.99e+00s)
# [TST] iter = 3980, cost = 9.29e+01, RMSE = 7.94e-01 (1.63e+00s)
# [TRN] iter = 3990, cost = 6.07e-01, |grad| = 1.00e+00 (4.97e+00s)
# [TST] iter = 3990, cost = 9.30e+01, RMSE = 7.95e-01 (1.62e+00s)
# [TRN] iter = 4000, cost = 6.06e-01, |grad| = 1.49e+00 (1.68e+00s)
# [TST] iter = 4000, cost = 9.31e+01, RMSE = 7.95e-01 (4.53e-01s)
# [TRN] iter = 4010, cost = 6.05e-01, |grad| = 3.81e+00 (2.87e+02s)
# [TST] iter = 4010, cost = 9.31e+01, RMSE = 7.96e-01 (4.87e-01s)
# [TRN] iter = 4020, cost = 6.23e-01, |grad| = 1.60e+00 (4.97e+00s)
# [TST] iter = 4020, cost = 9.36e+01, RMSE = 8.00e-01 (1.63e+00s)
# [TRN] iter = 4030, cost = 6.29e-01, |grad| = 1.48e+00 (4.96e+00s)
# [TST] iter = 4030, cost = 9.30e+01, RMSE = 7.95e-01 (1.62e+00s)
# [TRN] iter = 4040, cost = 6.20e-01, |grad| = 1.67e+00 (1.69e+00s)
# [TST] iter = 4040, cost = 9.28e+01, RMSE = 7.93e-01 (4.49e-01s)
# [TRN] iter = 4050, cost = 6.18e-01, |grad| = 2.39e+00 (2.88e+02s)
# [TST] iter = 4050, cost = 9.30e+01, RMSE = 7.95e-01 (4.69e-01s)
# [TRN] iter = 4060, cost = 6.11e-01, |grad| = 8.25e-01 (5.02e+00s)
# [TST] iter = 4060, cost = 9.30e+01, RMSE = 7.95e-01 (1.63e+00s)
# [TRN] iter = 4070, cost = 6.07e-01, |grad| = 1.97e+00 (4.93e+00s)
# [TST] iter = 4070, cost = 9.35e+01, RMSE = 7.99e-01 (1.63e+00s)
# [TRN] iter = 4080, cost = 7.45e-01, |grad| = 9.52e+00 (1.69e+00s)
# [TST] iter = 4080, cost = 9.58e+01, RMSE = 8.19e-01 (4.52e-01s)
# [TRN] iter = 4090, cost = 6.99e-01, |grad| = 2.21e+00 (5.05e+00s)
# [TST] iter = 4090, cost = 9.38e+01, RMSE = 8.01e-01 (2.85e+02s)
# [TRN] iter = 4100, cost = 6.75e-01, |grad| = 8.13e-01 (5.14e+00s)
# [TST] iter = 4100, cost = 9.34e+01, RMSE = 7.98e-01 (1.67e+00s)
# [TRN] iter = 4110, cost = 6.54e-01, |grad| = 1.79e+00 (4.39e+00s)
# [TST] iter = 4110, cost = 9.30e+01, RMSE = 7.95e-01 (1.65e+00s)
# [TRN] iter = 4120, cost = 6.39e-01, |grad| = 2.07e+00 (1.69e+00s)
# [TST] iter = 4120, cost = 9.28e+01, RMSE = 7.94e-01 (4.58e-01s)
# [TRN] iter = 4130, cost = 6.28e-01, |grad| = 4.08e-01 (5.01e+00s)
# [TST] iter = 4130, cost = 9.28e+01, RMSE = 7.94e-01 (2.85e+02s)
# [TRN] iter = 4140, cost = 6.20e-01, |grad| = 1.77e+00 (5.06e+00s)
# [TST] iter = 4140, cost = 9.27e+01, RMSE = 7.93e-01 (1.67e+00s)
# [TRN] iter = 4150, cost = 6.17e-01, |grad| = 8.62e-01 (3.50e+00s)
# [TST] iter = 4150, cost = 9.27e+01, RMSE = 7.92e-01 (1.62e+00s)
# [TRN] iter = 4160, cost = 6.11e-01, |grad| = 3.99e-01 (1.71e+00s)
# [TST] iter = 4160, cost = 9.27e+01, RMSE = 7.92e-01 (4.52e-01s)
# [TRN] iter = 4170, cost = 6.08e-01, |grad| = 9.21e-01 (4.97e+00s)
# [TST] iter = 4170, cost = 9.29e+01, RMSE = 7.94e-01 (1.65e+00s)
# [TRN] iter = 4180, cost = 6.06e-01, |grad| = 2.99e+00 (5.07e+00s)
# [TST] iter = 4180, cost = 9.30e+01, RMSE = 7.95e-01 (1.64e+00s)
# [TRN] iter = 4190, cost = 6.23e-01, |grad| = 3.52e+00 (2.76e+00s)
# [TST] iter = 4190, cost = 9.30e+01, RMSE = 7.94e-01 (1.63e+00s)
# [TRN] iter = 4200, cost = 6.28e-01, |grad| = 5.00e+00 (1.70e+00s)
# [TST] iter = 4200, cost = 9.33e+01, RMSE = 7.98e-01 (4.64e-01s)
# [TRN] iter = 4210, cost = 6.61e-01, |grad| = 1.10e+01 (4.93e+00s)
# [TST] iter = 4210, cost = 9.50e+01, RMSE = 8.12e-01 (1.66e+00s)
# [TRN] iter = 4220, cost = 6.54e-01, |grad| = 7.18e-01 (5.06e+00s)
# [TST] iter = 4220, cost = 9.28e+01, RMSE = 7.93e-01 (1.63e+00s)
# [TRN] iter = 4230, cost = 6.49e-01, |grad| = 1.36e+00 (1.89e+00s)
# [TST] iter = 4230, cost = 9.28e+01, RMSE = 7.93e-01 (1.63e+00s)
# [TRN] iter = 4240, cost = 6.33e-01, |grad| = 1.26e+00 (1.69e+00s)
# [TST] iter = 4240, cost = 9.28e+01, RMSE = 7.93e-01 (4.55e-01s)
# [TRN] iter = 4250, cost = 6.23e-01, |grad| = 1.33e+00 (4.92e+00s)
# [TST] iter = 4250, cost = 9.29e+01, RMSE = 7.94e-01 (1.64e+00s)
# [TRN] iter = 4260, cost = 6.14e-01, |grad| = 1.74e+00 (4.98e+00s)
# [TST] iter = 4260, cost = 9.28e+01, RMSE = 7.93e-01 (1.67e+00s)
# [TRN] iter = 4270, cost = 6.08e-01, |grad| = 9.77e-01 (1.69e+00s)
# [TST] iter = 4270, cost = 9.29e+01, RMSE = 7.94e-01 (4.64e-01s)
# [TRN] iter = 4280, cost = 6.06e-01, |grad| = 6.50e-01 (1.71e+00s)
# [TST] iter = 4280, cost = 9.30e+01, RMSE = 7.95e-01 (4.54e-01s)
# [TRN] iter = 4290, cost = 6.02e-01, |grad| = 5.66e-01 (4.97e+00s)
# [TST] iter = 4290, cost = 9.29e+01, RMSE = 7.94e-01 (1.64e+00s)
# [TRN] iter = 4300, cost = 6.02e-01, |grad| = 6.34e-01 (4.96e+00s)
# [TST] iter = 4300, cost = 9.30e+01, RMSE = 7.95e-01 (1.65e+00s)
# [TRN] iter = 4310, cost = 6.02e-01, |grad| = 8.75e-01 (1.69e+00s)
# [TST] iter = 4310, cost = 9.27e+01, RMSE = 7.92e-01 (4.50e-01s)
# [TRN] iter = 4320, cost = 6.09e-01, |grad| = 3.51e+00 (1.75e+00s)
# [TST] iter = 4320, cost = 9.33e+01, RMSE = 7.97e-01 (4.56e-01s)
# [TRN] iter = 4330, cost = 6.06e-01, |grad| = 1.35e+00 (4.94e+00s)
# [TST] iter = 4330, cost = 9.28e+01, RMSE = 7.94e-01 (1.63e+00s)
# [TRN] iter = 4340, cost = 6.16e-01, |grad| = 1.11e+00 (4.96e+00s)
# [TST] iter = 4340, cost = 9.36e+01, RMSE = 8.00e-01 (1.63e+00s)
# [TRN] iter = 4350, cost = 6.15e-01, |grad| = 9.35e-01 (1.70e+00s)
# [TST] iter = 4350, cost = 9.27e+01, RMSE = 7.92e-01 (4.56e-01s)
# [TRN] iter = 4360, cost = 6.06e-01, |grad| = 1.07e+00 (1.77e+00s)
# [TST] iter = 4360, cost = 9.29e+01, RMSE = 7.94e-01 (4.49e-01s)
# [TRN] iter = 4370, cost = 6.01e-01, |grad| = 1.91e+00 (4.97e+00s)
# [TST] iter = 4370, cost = 9.29e+01, RMSE = 7.94e-01 (1.63e+00s)
# [TRN] iter = 4380, cost = 8.35e-01, |grad| = 6.88e+01 (5.00e+00s)
# [TST] iter = 4380, cost = 9.41e+01, RMSE = 8.05e-01 (1.62e+00s)
# [TRN] iter = 4390, cost = 7.36e-01, |grad| = 2.05e+00 (1.69e+00s)
# [TST] iter = 4390, cost = 9.35e+01, RMSE = 7.99e-01 (4.52e-01s)
# [TRN] iter = 4400, cost = 7.10e-01, |grad| = 2.38e+00 (2.86e+02s)
# [TST] iter = 4400, cost = 9.30e+01, RMSE = 7.95e-01 (4.68e-01s)
# [TRN] iter = 4410, cost = 6.65e-01, |grad| = 5.72e-01 (5.00e+00s)
# [TST] iter = 4410, cost = 9.29e+01, RMSE = 7.94e-01 (1.64e+00s)
# [TRN] iter = 4420, cost = 6.42e-01, |grad| = 9.90e-01 (5.00e+00s)
# [TST] iter = 4420, cost = 9.28e+01, RMSE = 7.93e-01 (1.63e+00s)
# [TRN] iter = 4430, cost = 6.29e-01, |grad| = 4.91e-01 (1.70e+00s)
# [TST] iter = 4430, cost = 9.26e+01, RMSE = 7.91e-01 (4.58e-01s)
# [TRN] iter = 4440, cost = 6.20e-01, |grad| = 5.20e-01 (2.86e+02s)
# [TST] iter = 4440, cost = 9.26e+01, RMSE = 7.91e-01 (4.68e-01s)
# [TRN] iter = 4450, cost = 6.13e-01, |grad| = 3.56e-01 (5.01e+00s)
# [TST] iter = 4450, cost = 9.26e+01, RMSE = 7.91e-01 (1.64e+00s)
# [TRN] iter = 4460, cost = 6.08e-01, |grad| = 4.94e-01 (5.01e+00s)
# [TST] iter = 4460, cost = 9.27e+01, RMSE = 7.92e-01 (1.63e+00s)
# [TRN] iter = 4470, cost = 6.05e-01, |grad| = 7.36e-01 (1.72e+00s)
# [TST] iter = 4470, cost = 9.29e+01, RMSE = 7.94e-01 (4.54e-01s)
# [TRN] iter = 4480, cost = 6.05e-01, |grad| = 1.88e+00 (2.86e+02s)
# [TST] iter = 4480, cost = 9.29e+01, RMSE = 7.94e-01 (4.80e-01s)
# [TRN] iter = 4490, cost = 5.99e-01, |grad| = 2.83e+00 (4.97e+00s)
# [TST] iter = 4490, cost = 9.30e+01, RMSE = 7.95e-01 (1.60e+00s)
# [TRN] iter = 4500, cost = 6.01e-01, |grad| = 1.29e+00 (5.01e+00s)
# [TST] iter = 4500, cost = 9.32e+01, RMSE = 7.96e-01 (1.64e+00s)
# [TRN] iter = 4510, cost = 6.03e-01, |grad| = 1.69e+00 (1.70e+00s)
# [TST] iter = 4510, cost = 9.30e+01, RMSE = 7.95e-01 (4.55e-01s)
# [TRN] iter = 4520, cost = 6.44e-01, |grad| = 2.09e+00 (2.89e+02s)
# [TST] iter = 4520, cost = 9.39e+01, RMSE = 8.02e-01 (4.82e-01s)
# [TRN] iter = 4530, cost = 6.53e-01, |grad| = 5.10e+00 (4.96e+00s)
# [TST] iter = 4530, cost = 9.28e+01, RMSE = 7.94e-01 (1.63e+00s)
# [TRN] iter = 4540, cost = 6.36e-01, |grad| = 1.09e+00 (4.98e+00s)
# [TST] iter = 4540, cost = 9.26e+01, RMSE = 7.92e-01 (1.64e+00s)
# [TRN] iter = 4550, cost = 6.23e-01, |grad| = 1.13e+00 (1.71e+00s)
# [TST] iter = 4550, cost = 9.26e+01, RMSE = 7.91e-01 (4.55e-01s)
# [TRN] iter = 4560, cost = 6.13e-01, |grad| = 6.89e-01 (4.99e+00s)
# [TST] iter = 4560, cost = 9.28e+01, RMSE = 7.93e-01 (2.85e+02s)
# [TRN] iter = 4570, cost = 6.05e-01, |grad| = 2.43e+00 (5.01e+00s)
# [TST] iter = 4570, cost = 9.29e+01, RMSE = 7.94e-01 (1.64e+00s)
# [TRN] iter = 4580, cost = 6.03e-01, |grad| = 3.34e+00 (3.66e+00s)
# [TST] iter = 4580, cost = 9.28e+01, RMSE = 7.93e-01 (1.63e+00s)
# [TRN] iter = 4590, cost = 5.98e-01, |grad| = 6.60e-01 (1.69e+00s)
# [TST] iter = 4590, cost = 9.29e+01, RMSE = 7.94e-01 (4.55e-01s)
# [TRN] iter = 4600, cost = 5.96e-01, |grad| = 1.95e+00 (5.04e+00s)
# [TST] iter = 4600, cost = 9.31e+01, RMSE = 7.96e-01 (1.66e+00s)
# [TRN] iter = 4610, cost = 5.93e-01, |grad| = 1.54e+00 (5.11e+00s)
# [TST] iter = 4610, cost = 9.31e+01, RMSE = 7.95e-01 (1.64e+00s)
# [TRN] iter = 4620, cost = 6.00e-01, |grad| = 2.60e+00 (1.87e+00s)
# [TST] iter = 4620, cost = 9.37e+01, RMSE = 8.01e-01 (1.63e+00s)
# [TRN] iter = 4630, cost = 6.00e-01, |grad| = 1.02e+00 (1.72e+00s)
# [TST] iter = 4630, cost = 9.31e+01, RMSE = 7.96e-01 (4.59e-01s)
# [TRN] iter = 4640, cost = 5.97e-01, |grad| = 2.67e+00 (4.97e+00s)
# [TST] iter = 4640, cost = 9.32e+01, RMSE = 7.97e-01 (1.63e+00s)
# [TRN] iter = 4650, cost = 6.93e-01, |grad| = 1.30e+01 (5.03e+00s)
# [TST] iter = 4650, cost = 9.45e+01, RMSE = 8.08e-01 (1.70e+00s)
# [TRN] iter = 4660, cost = 6.81e-01, |grad| = 1.65e+00 (2.73e+00s)
# [TST] iter = 4660, cost = 9.34e+01, RMSE = 7.98e-01 (1.63e+00s)
# [TRN] iter = 4670, cost = 6.60e-01, |grad| = 1.73e+00 (1.71e+00s)
# [TST] iter = 4670, cost = 9.34e+01, RMSE = 7.98e-01 (4.56e-01s)
# [TRN] iter = 4680, cost = 6.45e-01, |grad| = 2.80e+00 (5.00e+00s)
# [TST] iter = 4680, cost = 9.29e+01, RMSE = 7.94e-01 (1.64e+00s)
# [TRN] iter = 4690, cost = 6.28e-01, |grad| = 1.41e+00 (5.00e+00s)
# [TST] iter = 4690, cost = 9.31e+01, RMSE = 7.95e-01 (1.62e+00s)
# [TRN] iter = 4700, cost = 6.23e-01, |grad| = 2.32e+00 (2.38e+00s)
# [TST] iter = 4700, cost = 9.28e+01, RMSE = 7.93e-01 (1.63e+00s)
# [TRN] iter = 4710, cost = 6.13e-01, |grad| = 5.11e-01 (1.69e+00s)
# [TST] iter = 4710, cost = 9.28e+01, RMSE = 7.93e-01 (4.52e-01s)
# [TRN] iter = 4720, cost = 6.06e-01, |grad| = 7.99e-01 (5.00e+00s)
# [TST] iter = 4720, cost = 9.28e+01, RMSE = 7.93e-01 (1.61e+00s)
# [TRN] iter = 4730, cost = 6.01e-01, |grad| = 5.03e-01 (5.03e+00s)
# [TST] iter = 4730, cost = 9.29e+01, RMSE = 7.94e-01 (1.64e+00s)
# [TRN] iter = 4740, cost = 6.01e-01, |grad| = 1.98e+00 (1.93e+00s)
# [TST] iter = 4740, cost = 9.31e+01, RMSE = 7.95e-01 (1.64e+00s)
# [TRN] iter = 4750, cost = 5.98e-01, |grad| = 8.78e-01 (1.70e+00s)
# [TST] iter = 4750, cost = 9.33e+01, RMSE = 7.97e-01 (4.50e-01s)
# [TRN] iter = 4760, cost = 5.96e-01, |grad| = 2.21e+00 (5.00e+00s)
# [TST] iter = 4760, cost = 9.32e+01, RMSE = 7.97e-01 (1.62e+00s)
# [TRN] iter = 4770, cost = 5.94e-01, |grad| = 2.68e+00 (4.97e+00s)
# [TST] iter = 4770, cost = 9.32e+01, RMSE = 7.96e-01 (1.63e+00s)
# [TRN] iter = 4780, cost = 5.94e-01, |grad| = 3.03e+00 (1.77e+00s)
# [TST] iter = 4780, cost = 9.43e+01, RMSE = 8.06e-01 (1.63e+00s)
# [TRN] iter = 4790, cost = 6.00e-01, |grad| = 3.11e+00 (1.71e+00s)
# [TST] iter = 4790, cost = 9.33e+01, RMSE = 7.98e-01 (4.63e-01s)
# [TRN] iter = 4800, cost = 6.06e-01, |grad| = 2.45e+00 (4.90e+00s)
# [TST] iter = 4800, cost = 9.40e+01, RMSE = 8.04e-01 (1.62e+00s)
# [TRN] iter = 4810, cost = 6.21e-01, |grad| = 5.36e+00 (5.07e+00s)
# [TST] iter = 4810, cost = 9.33e+01, RMSE = 7.97e-01 (1.63e+00s)
# [TRN] iter = 4820, cost = 6.22e-01, |grad| = 2.38e+00 (1.92e+00s)
# [TST] iter = 4820, cost = 9.41e+01, RMSE = 8.04e-01 (1.64e+00s)
# [TRN] iter = 4830, cost = 6.28e-01, |grad| = 1.83e+00 (1.69e+00s)
# [TST] iter = 4830, cost = 9.39e+01, RMSE = 8.02e-01 (4.52e-01s)
# [TRN] iter = 4840, cost = 6.14e-01, |grad| = 1.05e+00 (4.95e+00s)
# [TST] iter = 4840, cost = 9.31e+01, RMSE = 7.96e-01 (1.64e+00s)
# [TRN] iter = 4850, cost = 6.01e-01, |grad| = 6.04e-01 (5.08e+00s)
# [TST] iter = 4850, cost = 9.28e+01, RMSE = 7.93e-01 (1.67e+00s)
# [TRN] iter = 4860, cost = 5.93e-01, |grad| = 4.50e-01 (1.71e+00s)
# [TST] iter = 4860, cost = 9.30e+01, RMSE = 7.95e-01 (8.59e-01s)
# [TRN] iter = 4870, cost = 6.03e-01, |grad| = 1.22e+01 (1.70e+00s)
# [TST] iter = 4870, cost = 9.33e+01, RMSE = 7.98e-01 (4.55e-01s)
# [TRN] iter = 4880, cost = 6.43e-01, |grad| = 8.26e+00 (4.96e+00s)
# [TST] iter = 4880, cost = 9.37e+01, RMSE = 8.01e-01 (1.63e+00s)
# [TRN] iter = 4890, cost = 6.33e-01, |grad| = 3.28e+00 (1.77e+00s)
# [TST] iter = 4890, cost = 9.35e+01, RMSE = 7.99e-01 (4.95e-01s)
# [TRN] iter = 4900, cost = 6.34e-01, |grad| = 7.19e+00 (1.74e+00s)
# [TST] iter = 4900, cost = 9.34e+01, RMSE = 7.99e-01 (5.98e-01s)
# [TRN] iter = 4910, cost = 6.31e-01, |grad| = 1.17e+01 (1.73e+00s)
# [TST] iter = 4910, cost = 9.32e+01, RMSE = 7.97e-01 (4.63e-01s)
# [TRN] iter = 4920, cost = 6.09e-01, |grad| = 1.60e+00 (1.72e+00s)
# [TST] iter = 4920, cost = 9.25e+01, RMSE = 7.91e-01 (4.62e-01s)
# [TRN] iter = 4930, cost = 5.99e-01, |grad| = 9.43e-01 (1.71e+00s)
# [TST] iter = 4930, cost = 9.30e+01, RMSE = 7.95e-01 (4.56e-01s)
# [TRN] iter = 4940, cost = 5.99e-01, |grad| = 2.79e+00 (1.73e+00s)
# [TST] iter = 4940, cost = 9.34e+01, RMSE = 7.98e-01 (4.59e-01s)
# [TRN] iter = 4950, cost = 5.94e-01, |grad| = 1.00e+00 (1.75e+00s)
# [TST] iter = 4950, cost = 9.35e+01, RMSE = 7.99e-01 (4.69e-01s)
# [TRN] iter = 4960, cost = 5.91e-01, |grad| = 2.21e+00 (1.73e+00s)
# [TST] iter = 4960, cost = 9.31e+01, RMSE = 7.96e-01 (4.72e-01s)
# [TRN] iter = 4970, cost = 5.89e-01, |grad| = 7.53e-01 (1.75e+00s)
# [TST] iter = 4970, cost = 9.32e+01, RMSE = 7.96e-01 (4.72e-01s)
# [TRN] iter = 4980, cost = 5.89e-01, |grad| = 1.33e+00 (1.78e+00s)
# [TST] iter = 4980, cost = 9.34e+01, RMSE = 7.98e-01 (4.66e-01s)
# [TRN] iter = 4990, cost = 5.99e-01, |grad| = 2.98e+00 (1.76e+00s)
# [TST] iter = 4990, cost = 9.32e+01, RMSE = 7.97e-01 (4.71e-01s)

# %%
fig, ax1 = plt.subplots(figsize=(20,10))

ax2 = ax1.twinx()
ax1.plot(np.arange(len(list_training_loss)), list_training_loss, 'g-')
ax2.plot(np.arange(len(list_test_pred_error))*num_iter_test, list_test_pred_error, 'b-')

ax1.set_xlabel('Iteration')
ax1.set_ylabel('Training loss', color='g')
ax2.set_ylabel('Test loss', color='b')

best_iter = (np.where(np.asarray(list_training_loss)==np.min(list_training_loss))[0][0]//num_iter_test)*num_iter_test
best_pred_error = list_test_pred_error[best_iter//num_iter_test]

print ('Best predictions at iter: %d (error: %f)' % (best_iter, best_pred_error))
RMSE = np.sqrt(np.square(best_pred_error)/np.sum(Otest))
print ('RMSE: %f' % RMSE)
# Out:
# Best predictions at iter: 4970 (error: 93.182961)
# RMSE: 0.796436

# %%
#last X generated
plt.figure(figsize=(20,10))
plt.imshow(X)
plt.colorbar()
